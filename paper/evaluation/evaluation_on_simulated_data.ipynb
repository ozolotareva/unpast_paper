# %%
import numpy as np
import pandas as pd
import sys,os
import random
import copy

import matplotlib.pyplot as plt
import seaborn as sns

from utils.eval import calculate_perfromance, generate_exprs
from utils.method import read_bic_table

# %% [markdown]
# # Simulated expression data
#
# * 10000 genes x 200 samples
# * background ~N(0,1), bicluster ~ N(4,1)
# * four biclusters with fraction [0.05,0.1,0.25,0.5] of all samples simulate four subtypes
# * three scenarios A,B,C
#     * for each scenario, bicluster sizes in genes were 5,50,500
#     * 3 scenarios x 3 gene sizes = 9 expression matrices in total
#
# ### scenario A:
#  * biclusters are not overlapping in genes and samples
#  * all other genes are independent  ~N(0,1)
#
# ### scenario B:
#  * biclusters are overlapping in genes and samples
#  * all other genes are independent  ~N(0,1)
#
# ### scenario C:
#  * overlapping in genes and samples
#  * four co-expressed modules of 500 genes each

# %% [markdown]
# # Evaluation

# %% [markdown]
# # 1. Example: scenario C,50 and k-means
#
# #### Inputs:

# %%
exprs_file = "data/simulated_m=4,std=1/C/C.n_genes=500.exprs_z.tsv" 
exprs = pd.read_csv(exprs_file,sep = "\t",index_col=0)
exprs.head(5)
# Out:
#           s_0       s_1       s_2       s_3       s_4       s_5       s_6  \
# g_0  3.234252 -0.537743 -0.145318  2.122808 -0.585620  1.945721  0.319790
# g_1  0.275500  0.481170  1.010313  0.980679 -1.482808 -1.037173  0.434818
# g_2 -1.119433 -1.541442 -0.106289 -0.109311 -0.560576  0.087471 -0.642202
# g_3  0.266405 -0.849287  0.095549  1.942929  0.280191  0.875908 -1.490424
# g_4  0.847373 -0.673997 -0.033612 -0.617749 -0.588689 -0.457588  0.098210
#
#           s_7       s_8       s_9  ...     s_190     s_191     s_192  \
# g_0  1.776159 -0.703115 -0.197809  ... -0.691652 -0.041110  2.058545
# g_1  0.433552  0.434831  3.816463  ... -0.997243  0.411398 -1.424616
# g_2 -0.955568  0.935068  0.425404  ... -0.456908 -0.574621  0.257983
# g_3 -1.769411 -1.592939  1.915069  ...  0.222925  0.069257  0.057946
# g_4 -0.634982  1.179481 -1.070011  ...  0.083825 -2.270019 -0.392735
#
#         s_193     s_194     s_195     s_196     s_197     s_198     s_199
# g_0 -1.090703 -0.382239 -0.276320  0.936099 -0.391953 -0.439644 -1.039390
# g_1  1.768575  1.107971 -0.562352 -1.822691  1.284700 -0.203047  1.167116
# g_2  1.475459  0.894755 -1.273852 -0.015582 -1.586488 -1.036009  0.365994
# g_3 -0.020052 -0.330713  1.711180  0.242721  0.358030  0.165320  0.274322
# g_4 -0.847586 -1.181957 -0.428222  1.746393  0.536221 -0.731673  0.464814
#
# [5 rows x 200 columns]

# %%
ground_truth_file = "data/simulated/C/C.n_genes=500,m=4,std=1,overlap=yes.biclusters.tsv"
ground_truth = pd.read_csv(ground_truth_file,sep ="\t",index_col=0)
ground_truth["samples"] = ground_truth["samples"].apply(lambda x: set(x.split(" ")))
if "genes" in ground_truth.columns.values:
    ground_truth["genes"] = ground_truth["genes"].apply(lambda x: set(x.split(" ")))

ground_truth.head(5)
# Out:
#                                                   genes  \
# 0.05  {g_7454, g_3572, g_6430, g_7875, g_1951, g_361...
# 0.10  {g_1053, g_9722, g_8360, g_2824, g_3694, g_455...
# 0.25  {g_6281, g_9302, g_5355, g_3922, g_1948, g_297...
# 0.50  {g_5242, g_5840, g_2251, g_1210, g_2719, g_931...
#
#                                                 samples  frac  n_genes  \
# 0.05  {s_75, s_197, s_131, s_144, s_46, s_194, s_26,...  0.05      500
# 0.10  {s_159, s_45, s_149, s_88, s_19, s_32, s_184, ...  0.10      500
# 0.25  {s_120, s_130, s_46, s_88, s_34, s_196, s_20, ...  0.25      500
# 0.50  {s_118, s_120, s_191, s_150, s_149, s_183, s_1...  0.50      500
#
#       n_samples:  n_samples
# 0.05          10         10
# 0.10          20         20
# 0.25          50         50
# 0.50         100        100

# %%
# prepare a dict with sample groups corresponding to known bicluster
known_groups = {}
known_groups["simulated"] = {}
for group in ground_truth.index.values:
    known_groups["simulated"][group] = ground_truth.loc[group,"samples"]

# %% [markdown]
# ### Method output
# * must be a dataFrame with (bi-)cluster index and "samples" coulum
# * "samples" column contrain sets of samples

# %%
from sklearn.cluster import KMeans

model = KMeans(n_clusters=5)
labels = model.fit_predict(exprs.T)


result = {}
sample_names = exprs.columns.values
for clust in set(labels):
    s = set(sample_names[labels == clust])
    result[clust] = {"samples":s,"n_samples":len(s)}
result = pd.DataFrame.from_dict(result).T
result
# Out:
# /home/olya/anaconda3/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
#                                              samples n_samples
# 0  {s_159, s_45, s_88, s_149, s_19, s_32, s_184, ...        19
# 1  {s_160, s_118, s_191, s_92, s_136, s_150, s_12...        69
# 2  {s_120, s_130, s_34, s_196, s_20, s_13, s_115,...        44
# 3  {s_74, s_99, s_180, s_1, s_28, s_190, s_12, s_...        58
# 4  {s_75, s_197, s_131, s_144, s_46, s_194, s_24,...        10

# %%
all_samples = set(exprs.columns.values)
performance, best_matches = calculate_perfromance(result,known_groups,all_samples,adjust_pvals="B")
print("Sum of weighted Jaccard indexes:",performance[0])
best_matches
# Out:
# Sum of weighted Jaccard indexes: 0.79679186228482
#      bm_id         J    weight adj_pval is_enriched  \
# 0.05     4       1.0  0.055556      0.0        True
# 0.10     0      0.95  0.111111      0.0        True
# 0.25     2      0.88  0.277778      0.0        True
# 0.50     3  0.704225  0.555556      0.0       False
#
#                                                 samples n_samples  \
# 0.05  {s_75, s_197, s_131, s_144, s_46, s_194, s_24,...        10
# 0.10  {s_159, s_45, s_88, s_149, s_19, s_32, s_184, ...        19
# 0.25  {s_120, s_130, s_34, s_196, s_20, s_13, s_115,...        44
# 0.50  {s_74, s_99, s_180, s_1, s_28, s_190, s_12, s_...        58
#
#      classification
# 0.05      simulated
# 0.10      simulated
# 0.25      simulated
# 0.50      simulated

# %% [markdown]
# # Running DESMOND2 with multiple parameter combinations

# %%
from time import time
from run_unpast import run

out_dir= "results_on_simulated_data/"
fname_prefix = "data/simulated_m=4,std=1/"

# number of runs and seeds - set to 5 
n_runs = 5
seeds =  [85822412, 14942603, 3356886, 99529223, 36913810]

# method parameters to try
pvals = [0.001, 0.005,0.01,0.05,]
bin_methods = ["kmeans","ward","GMM"] 

directions =   [["UP","DOWN"]]

# %%
clust_method = "Louvain"
modularities = [0,0.3,0.4,0.5,0.6,0.7,0.8,0.9]

df = []
for scenario in ["A","B","C"]:
    for gsize in [500,50,5]:
        exprs_file = fname_prefix + "/"+scenario+"/"+scenario+".n_genes="+str(gsize)+".exprs_z.tsv"
        all_samples = set(pd.read_csv(exprs_file,sep="\t",index_col=0, nrows=0).columns.values)

        ground_truth_file =fname_prefix + "/"+scenario+"/"+scenario+".n_genes="+str(gsize)+".biclusters.tsv"
        ground_truth = pd.read_csv(ground_truth_file,sep ="\t",index_col=0)
        ground_truth["samples"] = ground_truth["samples"].apply(lambda x: set(x.split(" ")))
        if "genes" in ground_truth.columns.values:
            ground_truth["genes"] = ground_truth["genes"].apply(lambda x: set(x.split(" ")))
        # make dictionary with sample sets for calculate_perforamce()
        known_groups = {}
        known_groups["simulated"] = {}
        for group in ground_truth.index.values:
            known_groups["simulated"][group] = ground_truth.loc[group,"samples"]
            
        basename = scenario+".n_genes="+str(gsize)
        print(scenario,gsize)
        
        for n_run in range(n_runs):
            seed = seeds[n_run]
            for pval in pvals:
                for bin_method in bin_methods:
                    for m in modularities:
                        for d in directions:
                            # save parameters as a ;-separated string
                            params = "bin="+bin_method+";pval="+str(pval)+";direction="+str("-".join(d))
                            params += ";clust="+clust_method+";m="+str(m)
                            
                            fname = out_dir+basename+".seed="+str(seed)+\
                                ".bin="+bin_method +",pval="+str(pval)+",clust="+clust_method+",direction="+\
                                str("-".join(d))+",m="+str(m)+".biclusters.tsv"
                            try:
                                t0 = time()
                                if os.path.exists(fname):
                                    result = read_bic_table(fname)
                                else:
                                    result = run(exprs_file, basename , out_dir=out_dir,
                                                                    save=True, load = True,
                                                                    min_n_samples = 5,
                                                                    bin_method = bin_method, pval = pval,
                                                                    directions = d,
                                                                    clust_method = clust_method,
                                                                    modularity=m,
                                                                    seed = seed,
                                                                    verbose = False)
                                # find best matches and calculate performance 
                                performance, best_matches = calculate_perfromance(result, known_groups,all_samples, adjust_pvals = "BH",pval_cutoff=0.05)

                                #print("\trun",run,params,performance)

                                d = {"scenario":scenario,"gsize":gsize,
                                     "n_run":n_run,"seed":seed,
                                     "parameters":params, 
                                     "performance":performance["simulated"]}
                                d["runtime"] = time()-t0
                                df.append(d)
                            except:
                                print("\t failed",n_run,seed, params, file = sys.stderr)
# Out:
# A 500
# file results_on_simulated_data/A.n_genes=500.seed=85822412.bin_method=kmeans.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=500.seed=85822412.bin_method=kmeans.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=500.seed=85822412.n=10000.min_ns=5.background.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=500.seed=85822412.bin_method=ward.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=500.seed=85822412.bin_method=ward.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=500.seed=85822412.bin_method=GMM.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=500.seed=85822412.bin_method=GMM.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=500.seed=14942603.bin_method=kmeans.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=500.seed=14942603.bin_method=kmeans.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=500.seed=14942603.n=10000.min_ns=5.background.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=500.seed=14942603.bin_method=ward.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=500.seed=14942603.bin_method=ward.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=500.seed=14942603.bin_method=GMM.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=500.seed=14942603.bin_method=GMM.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=500.seed=3356886.bin_method=kmeans.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=500.seed=3356886.bin_method=kmeans.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=500.seed=3356886.n=10000.min_ns=5.background.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=500.seed=3356886.bin_method=ward.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=500.seed=3356886.bin_method=ward.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=500.seed=3356886.bin_method=GMM.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=500.seed=3356886.bin_method=GMM.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=500.seed=99529223.bin_method=kmeans.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=500.seed=99529223.bin_method=kmeans.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=500.seed=99529223.n=10000.min_ns=5.background.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=500.seed=99529223.bin_method=ward.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=500.seed=99529223.bin_method=ward.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=500.seed=99529223.bin_method=GMM.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=500.seed=99529223.bin_method=GMM.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=500.seed=36913810.bin_method=kmeans.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=500.seed=36913810.bin_method=kmeans.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=500.seed=36913810.n=10000.min_ns=5.background.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=500.seed=36913810.bin_method=ward.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=500.seed=36913810.bin_method=ward.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=500.seed=36913810.bin_method=GMM.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=500.seed=36913810.bin_method=GMM.min_ns=5.binarization_stats.tsv is not found and will be created
# A 50
# file results_on_simulated_data/A.n_genes=50.seed=85822412.bin_method=kmeans.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=50.seed=85822412.bin_method=kmeans.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=50.seed=85822412.n=10000.min_ns=5.background.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=50.seed=85822412.bin_method=ward.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=50.seed=85822412.bin_method=ward.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=50.seed=85822412.bin_method=GMM.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=50.seed=85822412.bin_method=GMM.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=50.seed=14942603.bin_method=kmeans.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=50.seed=14942603.bin_method=kmeans.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=50.seed=14942603.n=10000.min_ns=5.background.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=50.seed=14942603.bin_method=ward.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=50.seed=14942603.bin_method=ward.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=50.seed=14942603.bin_method=GMM.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=50.seed=14942603.bin_method=GMM.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=50.seed=3356886.bin_method=kmeans.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=50.seed=3356886.bin_method=kmeans.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=50.seed=3356886.n=10000.min_ns=5.background.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=50.seed=3356886.bin_method=ward.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=50.seed=3356886.bin_method=ward.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=50.seed=3356886.bin_method=GMM.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=50.seed=3356886.bin_method=GMM.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=50.seed=99529223.bin_method=kmeans.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=50.seed=99529223.bin_method=kmeans.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=50.seed=99529223.n=10000.min_ns=5.background.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=50.seed=99529223.bin_method=ward.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=50.seed=99529223.bin_method=ward.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=50.seed=99529223.bin_method=GMM.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=50.seed=99529223.bin_method=GMM.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=50.seed=36913810.bin_method=kmeans.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=50.seed=36913810.bin_method=kmeans.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=50.seed=36913810.n=10000.min_ns=5.background.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=50.seed=36913810.bin_method=ward.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=50.seed=36913810.bin_method=ward.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=50.seed=36913810.bin_method=GMM.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=50.seed=36913810.bin_method=GMM.min_ns=5.binarization_stats.tsv is not found and will be created
# A 5
# file results_on_simulated_data/A.n_genes=5.seed=85822412.bin_method=kmeans.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=5.seed=85822412.bin_method=kmeans.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=5.seed=85822412.n=10000.min_ns=5.background.tsv is not found and will be created
# 	 failed 0 85822412 bin=kmeans;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0
# 	 failed 0 85822412 bin=kmeans;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.3
# 	 failed 0 85822412 bin=kmeans;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.4
# 	 failed 0 85822412 bin=kmeans;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.5
# 	 failed 0 85822412 bin=kmeans;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.6
# 	 failed 0 85822412 bin=kmeans;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.7
# 	 failed 0 85822412 bin=kmeans;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.8
# 	 failed 0 85822412 bin=kmeans;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.9
# file results_on_simulated_data/A.n_genes=5.seed=85822412.bin_method=ward.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=5.seed=85822412.bin_method=ward.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=5.seed=85822412.bin_method=GMM.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=5.seed=85822412.bin_method=GMM.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=5.seed=14942603.bin_method=kmeans.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=5.seed=14942603.bin_method=kmeans.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=5.seed=14942603.n=10000.min_ns=5.background.tsv is not found and will be created
# 	 failed 1 14942603 bin=kmeans;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0
# 	 failed 1 14942603 bin=kmeans;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.3
# 	 failed 1 14942603 bin=kmeans;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.4
# 	 failed 1 14942603 bin=kmeans;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.5
# 	 failed 1 14942603 bin=kmeans;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.6
# 	 failed 1 14942603 bin=kmeans;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.7
# 	 failed 1 14942603 bin=kmeans;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.8
# 	 failed 1 14942603 bin=kmeans;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.9
# file results_on_simulated_data/A.n_genes=5.seed=14942603.bin_method=ward.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=5.seed=14942603.bin_method=ward.min_ns=5.binarization_stats.tsv is not found and will be created
# 	 failed 1 14942603 bin=ward;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0
# 	 failed 1 14942603 bin=ward;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.3
# 	 failed 1 14942603 bin=ward;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.4
# 	 failed 1 14942603 bin=ward;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.5
# 	 failed 1 14942603 bin=ward;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.6
# 	 failed 1 14942603 bin=ward;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.7
# 	 failed 1 14942603 bin=ward;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.8
# 	 failed 1 14942603 bin=ward;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.9
# file results_on_simulated_data/A.n_genes=5.seed=14942603.bin_method=GMM.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=5.seed=14942603.bin_method=GMM.min_ns=5.binarization_stats.tsv is not found and will be created
# 	 failed 1 14942603 bin=GMM;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0
# 	 failed 1 14942603 bin=GMM;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.3
# 	 failed 1 14942603 bin=GMM;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.4
# 	 failed 1 14942603 bin=GMM;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.5
# 	 failed 1 14942603 bin=GMM;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.6
# 	 failed 1 14942603 bin=GMM;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.7
# 	 failed 1 14942603 bin=GMM;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.8
# 	 failed 1 14942603 bin=GMM;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.9
# file results_on_simulated_data/A.n_genes=5.seed=3356886.bin_method=kmeans.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=5.seed=3356886.bin_method=kmeans.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=5.seed=3356886.n=10000.min_ns=5.background.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=5.seed=3356886.bin_method=ward.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=5.seed=3356886.bin_method=ward.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=5.seed=3356886.bin_method=GMM.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=5.seed=3356886.bin_method=GMM.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=5.seed=99529223.bin_method=kmeans.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=5.seed=99529223.bin_method=kmeans.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=5.seed=99529223.n=10000.min_ns=5.background.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=5.seed=99529223.bin_method=ward.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=5.seed=99529223.bin_method=ward.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=5.seed=99529223.bin_method=GMM.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=5.seed=99529223.bin_method=GMM.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=5.seed=36913810.bin_method=kmeans.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=5.seed=36913810.bin_method=kmeans.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=5.seed=36913810.n=10000.min_ns=5.background.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=5.seed=36913810.bin_method=ward.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=5.seed=36913810.bin_method=ward.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=5.seed=36913810.bin_method=GMM.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/A.n_genes=5.seed=36913810.bin_method=GMM.min_ns=5.binarization_stats.tsv is not found and will be created
# B 500
# file results_on_simulated_data/B.n_genes=500.seed=85822412.bin_method=kmeans.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=500.seed=85822412.bin_method=kmeans.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=500.seed=85822412.n=10000.min_ns=5.background.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=500.seed=85822412.bin_method=ward.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=500.seed=85822412.bin_method=ward.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=500.seed=85822412.bin_method=GMM.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=500.seed=85822412.bin_method=GMM.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=500.seed=14942603.bin_method=kmeans.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=500.seed=14942603.bin_method=kmeans.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=500.seed=14942603.n=10000.min_ns=5.background.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=500.seed=14942603.bin_method=ward.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=500.seed=14942603.bin_method=ward.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=500.seed=14942603.bin_method=GMM.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=500.seed=14942603.bin_method=GMM.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=500.seed=3356886.bin_method=kmeans.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=500.seed=3356886.bin_method=kmeans.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=500.seed=3356886.n=10000.min_ns=5.background.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=500.seed=3356886.bin_method=ward.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=500.seed=3356886.bin_method=ward.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=500.seed=3356886.bin_method=GMM.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=500.seed=3356886.bin_method=GMM.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=500.seed=99529223.bin_method=kmeans.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=500.seed=99529223.bin_method=kmeans.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=500.seed=99529223.n=10000.min_ns=5.background.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=500.seed=99529223.bin_method=ward.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=500.seed=99529223.bin_method=ward.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=500.seed=99529223.bin_method=GMM.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=500.seed=99529223.bin_method=GMM.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=500.seed=36913810.bin_method=kmeans.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=500.seed=36913810.bin_method=kmeans.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=500.seed=36913810.n=10000.min_ns=5.background.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=500.seed=36913810.bin_method=ward.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=500.seed=36913810.bin_method=ward.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=500.seed=36913810.bin_method=GMM.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=500.seed=36913810.bin_method=GMM.min_ns=5.binarization_stats.tsv is not found and will be created
# B 50
# file results_on_simulated_data/B.n_genes=50.seed=85822412.bin_method=kmeans.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=50.seed=85822412.bin_method=kmeans.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=50.seed=85822412.n=10000.min_ns=5.background.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=50.seed=85822412.bin_method=ward.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=50.seed=85822412.bin_method=ward.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=50.seed=85822412.bin_method=GMM.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=50.seed=85822412.bin_method=GMM.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=50.seed=14942603.bin_method=kmeans.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=50.seed=14942603.bin_method=kmeans.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=50.seed=14942603.n=10000.min_ns=5.background.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=50.seed=14942603.bin_method=ward.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=50.seed=14942603.bin_method=ward.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=50.seed=14942603.bin_method=GMM.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=50.seed=14942603.bin_method=GMM.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=50.seed=3356886.bin_method=kmeans.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=50.seed=3356886.bin_method=kmeans.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=50.seed=3356886.n=10000.min_ns=5.background.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=50.seed=3356886.bin_method=ward.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=50.seed=3356886.bin_method=ward.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=50.seed=3356886.bin_method=GMM.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=50.seed=3356886.bin_method=GMM.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=50.seed=99529223.bin_method=kmeans.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=50.seed=99529223.bin_method=kmeans.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=50.seed=99529223.n=10000.min_ns=5.background.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=50.seed=99529223.bin_method=ward.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=50.seed=99529223.bin_method=ward.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=50.seed=99529223.bin_method=GMM.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=50.seed=99529223.bin_method=GMM.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=50.seed=36913810.bin_method=kmeans.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=50.seed=36913810.bin_method=kmeans.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=50.seed=36913810.n=10000.min_ns=5.background.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=50.seed=36913810.bin_method=ward.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=50.seed=36913810.bin_method=ward.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=50.seed=36913810.bin_method=GMM.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=50.seed=36913810.bin_method=GMM.min_ns=5.binarization_stats.tsv is not found and will be created
# B 5
# file results_on_simulated_data/B.n_genes=5.seed=85822412.bin_method=kmeans.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=5.seed=85822412.bin_method=kmeans.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=5.seed=85822412.n=10000.min_ns=5.background.tsv is not found and will be created
# 	 failed 0 85822412 bin=kmeans;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0
# 	 failed 0 85822412 bin=kmeans;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.3
# 	 failed 0 85822412 bin=kmeans;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.4
# 	 failed 0 85822412 bin=kmeans;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.5
# 	 failed 0 85822412 bin=kmeans;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.6
# 	 failed 0 85822412 bin=kmeans;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.7
# 	 failed 0 85822412 bin=kmeans;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.8
# 	 failed 0 85822412 bin=kmeans;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.9
# file results_on_simulated_data/B.n_genes=5.seed=85822412.bin_method=ward.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=5.seed=85822412.bin_method=ward.min_ns=5.binarization_stats.tsv is not found and will be created
# 	 failed 0 85822412 bin=ward;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0
# 	 failed 0 85822412 bin=ward;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.3
# 	 failed 0 85822412 bin=ward;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.4
# 	 failed 0 85822412 bin=ward;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.5
# 	 failed 0 85822412 bin=ward;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.6
# 	 failed 0 85822412 bin=ward;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.7
# 	 failed 0 85822412 bin=ward;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.8
# 	 failed 0 85822412 bin=ward;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.9
# file results_on_simulated_data/B.n_genes=5.seed=85822412.bin_method=GMM.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=5.seed=85822412.bin_method=GMM.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=5.seed=14942603.bin_method=kmeans.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=5.seed=14942603.bin_method=kmeans.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=5.seed=14942603.n=10000.min_ns=5.background.tsv is not found and will be created
# 	 failed 1 14942603 bin=kmeans;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0
# 	 failed 1 14942603 bin=kmeans;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.3
# 	 failed 1 14942603 bin=kmeans;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.4
# 	 failed 1 14942603 bin=kmeans;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.5
# 	 failed 1 14942603 bin=kmeans;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.6
# 	 failed 1 14942603 bin=kmeans;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.7
# 	 failed 1 14942603 bin=kmeans;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.8
# 	 failed 1 14942603 bin=kmeans;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.9
# file results_on_simulated_data/B.n_genes=5.seed=14942603.bin_method=ward.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=5.seed=14942603.bin_method=ward.min_ns=5.binarization_stats.tsv is not found and will be created
# 	 failed 1 14942603 bin=ward;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0
# 	 failed 1 14942603 bin=ward;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.3
# 	 failed 1 14942603 bin=ward;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.4
# 	 failed 1 14942603 bin=ward;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.5
# 	 failed 1 14942603 bin=ward;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.6
# 	 failed 1 14942603 bin=ward;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.7
# 	 failed 1 14942603 bin=ward;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.8
# 	 failed 1 14942603 bin=ward;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.9
# file results_on_simulated_data/B.n_genes=5.seed=14942603.bin_method=GMM.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=5.seed=14942603.bin_method=GMM.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=5.seed=3356886.bin_method=kmeans.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=5.seed=3356886.bin_method=kmeans.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=5.seed=3356886.n=10000.min_ns=5.background.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=5.seed=3356886.bin_method=ward.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=5.seed=3356886.bin_method=ward.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=5.seed=3356886.bin_method=GMM.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=5.seed=3356886.bin_method=GMM.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=5.seed=99529223.bin_method=kmeans.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=5.seed=99529223.bin_method=kmeans.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=5.seed=99529223.n=10000.min_ns=5.background.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=5.seed=99529223.bin_method=ward.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=5.seed=99529223.bin_method=ward.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=5.seed=99529223.bin_method=GMM.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=5.seed=99529223.bin_method=GMM.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=5.seed=36913810.bin_method=kmeans.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=5.seed=36913810.bin_method=kmeans.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=5.seed=36913810.n=10000.min_ns=5.background.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=5.seed=36913810.bin_method=ward.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=5.seed=36913810.bin_method=ward.min_ns=5.binarization_stats.tsv is not found and will be created
# 	 failed 4 36913810 bin=ward;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0
# 	 failed 4 36913810 bin=ward;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.3
# 	 failed 4 36913810 bin=ward;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.4
# 	 failed 4 36913810 bin=ward;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.5
# 	 failed 4 36913810 bin=ward;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.6
# 	 failed 4 36913810 bin=ward;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.7
# 	 failed 4 36913810 bin=ward;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.8
# 	 failed 4 36913810 bin=ward;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.9
# file results_on_simulated_data/B.n_genes=5.seed=36913810.bin_method=GMM.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/B.n_genes=5.seed=36913810.bin_method=GMM.min_ns=5.binarization_stats.tsv is not found and will be created
# C 500
# file results_on_simulated_data/C.n_genes=500.seed=85822412.bin_method=kmeans.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=500.seed=85822412.bin_method=kmeans.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=500.seed=85822412.n=10000.min_ns=5.background.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=500.seed=85822412.bin_method=ward.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=500.seed=85822412.bin_method=ward.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=500.seed=85822412.bin_method=GMM.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=500.seed=85822412.bin_method=GMM.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=500.seed=14942603.bin_method=kmeans.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=500.seed=14942603.bin_method=kmeans.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=500.seed=14942603.n=10000.min_ns=5.background.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=500.seed=14942603.bin_method=ward.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=500.seed=14942603.bin_method=ward.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=500.seed=14942603.bin_method=GMM.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=500.seed=14942603.bin_method=GMM.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=500.seed=3356886.bin_method=kmeans.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=500.seed=3356886.bin_method=kmeans.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=500.seed=3356886.n=10000.min_ns=5.background.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=500.seed=3356886.bin_method=ward.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=500.seed=3356886.bin_method=ward.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=500.seed=3356886.bin_method=GMM.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=500.seed=3356886.bin_method=GMM.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=500.seed=99529223.bin_method=kmeans.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=500.seed=99529223.bin_method=kmeans.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=500.seed=99529223.n=10000.min_ns=5.background.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=500.seed=99529223.bin_method=ward.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=500.seed=99529223.bin_method=ward.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=500.seed=99529223.bin_method=GMM.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=500.seed=99529223.bin_method=GMM.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=500.seed=36913810.bin_method=kmeans.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=500.seed=36913810.bin_method=kmeans.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=500.seed=36913810.n=10000.min_ns=5.background.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=500.seed=36913810.bin_method=ward.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=500.seed=36913810.bin_method=ward.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=500.seed=36913810.bin_method=GMM.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=500.seed=36913810.bin_method=GMM.min_ns=5.binarization_stats.tsv is not found and will be created
# C 50
# file results_on_simulated_data/C.n_genes=50.seed=85822412.bin_method=kmeans.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=50.seed=85822412.bin_method=kmeans.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=50.seed=85822412.n=10000.min_ns=5.background.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=50.seed=85822412.bin_method=ward.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=50.seed=85822412.bin_method=ward.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=50.seed=85822412.bin_method=GMM.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=50.seed=85822412.bin_method=GMM.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=50.seed=14942603.bin_method=kmeans.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=50.seed=14942603.bin_method=kmeans.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=50.seed=14942603.n=10000.min_ns=5.background.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=50.seed=14942603.bin_method=ward.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=50.seed=14942603.bin_method=ward.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=50.seed=14942603.bin_method=GMM.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=50.seed=14942603.bin_method=GMM.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=50.seed=3356886.bin_method=kmeans.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=50.seed=3356886.bin_method=kmeans.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=50.seed=3356886.n=10000.min_ns=5.background.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=50.seed=3356886.bin_method=ward.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=50.seed=3356886.bin_method=ward.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=50.seed=3356886.bin_method=GMM.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=50.seed=3356886.bin_method=GMM.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=50.seed=99529223.bin_method=kmeans.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=50.seed=99529223.bin_method=kmeans.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=50.seed=99529223.n=10000.min_ns=5.background.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=50.seed=99529223.bin_method=ward.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=50.seed=99529223.bin_method=ward.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=50.seed=99529223.bin_method=GMM.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=50.seed=99529223.bin_method=GMM.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=50.seed=36913810.bin_method=kmeans.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=50.seed=36913810.bin_method=kmeans.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=50.seed=36913810.n=10000.min_ns=5.background.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=50.seed=36913810.bin_method=ward.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=50.seed=36913810.bin_method=ward.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=50.seed=36913810.bin_method=GMM.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=50.seed=36913810.bin_method=GMM.min_ns=5.binarization_stats.tsv is not found and will be created
# C 5
# file results_on_simulated_data/C.n_genes=5.seed=85822412.bin_method=kmeans.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=5.seed=85822412.bin_method=kmeans.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=5.seed=85822412.n=10000.min_ns=5.background.tsv is not found and will be created
# 	 failed 0 85822412 bin=kmeans;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0
# 	 failed 0 85822412 bin=kmeans;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.3
# 	 failed 0 85822412 bin=kmeans;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.4
# 	 failed 0 85822412 bin=kmeans;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.5
# 	 failed 0 85822412 bin=kmeans;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.6
# 	 failed 0 85822412 bin=kmeans;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.7
# 	 failed 0 85822412 bin=kmeans;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.8
# 	 failed 0 85822412 bin=kmeans;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.9
# file results_on_simulated_data/C.n_genes=5.seed=85822412.bin_method=ward.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=5.seed=85822412.bin_method=ward.min_ns=5.binarization_stats.tsv is not found and will be created
# 	 failed 0 85822412 bin=ward;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0
# 	 failed 0 85822412 bin=ward;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.3
# 	 failed 0 85822412 bin=ward;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.4
# 	 failed 0 85822412 bin=ward;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.5
# 	 failed 0 85822412 bin=ward;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.6
# 	 failed 0 85822412 bin=ward;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.7
# 	 failed 0 85822412 bin=ward;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.8
# 	 failed 0 85822412 bin=ward;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.9
# file results_on_simulated_data/C.n_genes=5.seed=85822412.bin_method=GMM.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=5.seed=85822412.bin_method=GMM.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=5.seed=14942603.bin_method=kmeans.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=5.seed=14942603.bin_method=kmeans.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=5.seed=14942603.n=10000.min_ns=5.background.tsv is not found and will be created
# 	 failed 1 14942603 bin=kmeans;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0
# 	 failed 1 14942603 bin=kmeans;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.3
# 	 failed 1 14942603 bin=kmeans;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.4
# 	 failed 1 14942603 bin=kmeans;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.5
# 	 failed 1 14942603 bin=kmeans;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.6
# 	 failed 1 14942603 bin=kmeans;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.7
# 	 failed 1 14942603 bin=kmeans;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.8
# 	 failed 1 14942603 bin=kmeans;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.9
# file results_on_simulated_data/C.n_genes=5.seed=14942603.bin_method=ward.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=5.seed=14942603.bin_method=ward.min_ns=5.binarization_stats.tsv is not found and will be created
# 	 failed 1 14942603 bin=ward;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0
# 	 failed 1 14942603 bin=ward;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.3
# 	 failed 1 14942603 bin=ward;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.4
# 	 failed 1 14942603 bin=ward;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.5
# 	 failed 1 14942603 bin=ward;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.6
# 	 failed 1 14942603 bin=ward;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.7
# 	 failed 1 14942603 bin=ward;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.8
# 	 failed 1 14942603 bin=ward;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.9
# file results_on_simulated_data/C.n_genes=5.seed=14942603.bin_method=GMM.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=5.seed=14942603.bin_method=GMM.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=5.seed=3356886.bin_method=kmeans.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=5.seed=3356886.bin_method=kmeans.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=5.seed=3356886.n=10000.min_ns=5.background.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=5.seed=3356886.bin_method=ward.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=5.seed=3356886.bin_method=ward.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=5.seed=3356886.bin_method=GMM.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=5.seed=3356886.bin_method=GMM.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=5.seed=99529223.bin_method=kmeans.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=5.seed=99529223.bin_method=kmeans.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=5.seed=99529223.n=10000.min_ns=5.background.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=5.seed=99529223.bin_method=ward.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=5.seed=99529223.bin_method=ward.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=5.seed=99529223.bin_method=GMM.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=5.seed=99529223.bin_method=GMM.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=5.seed=36913810.bin_method=kmeans.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=5.seed=36913810.bin_method=kmeans.min_ns=5.binarization_stats.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=5.seed=36913810.n=10000.min_ns=5.background.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=5.seed=36913810.bin_method=ward.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=5.seed=36913810.bin_method=ward.min_ns=5.binarization_stats.tsv is not found and will be created
# 	 failed 4 36913810 bin=ward;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0
# 	 failed 4 36913810 bin=ward;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.3
# 	 failed 4 36913810 bin=ward;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.4
# 	 failed 4 36913810 bin=ward;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.5
# 	 failed 4 36913810 bin=ward;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.6
# 	 failed 4 36913810 bin=ward;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.7
# 	 failed 4 36913810 bin=ward;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.8
# 	 failed 4 36913810 bin=ward;pval=0.001;direction=UP-DOWN;clust=Louvain;m=0.9
# file results_on_simulated_data/C.n_genes=5.seed=36913810.bin_method=GMM.min_ns=5.binarized.tsv is not found and will be created
# file results_on_simulated_data/C.n_genes=5.seed=36913810.bin_method=GMM.min_ns=5.binarization_stats.tsv is not found and will be created

# %%
df2 = []

# %%
rpath="/home/olya/anaconda3/envs/r4_env/bin/"
clust_method = "WGCNA"
ds_values = [0,1,2,3,4]
dchs = [0.95,0.995]

for scenario in ["A","B","C"]:
    for gsize in [500,50,5]:
        exprs_file = fname_prefix + "/"+scenario+"/"+scenario+".n_genes="+str(gsize)+".exprs_z.tsv"
        all_samples = set(pd.read_csv(exprs_file,sep="\t",index_col=0, nrows=0).columns.values)

        ground_truth_file=fname_prefix + "/"+scenario+"/"+scenario+".n_genes="+str(gsize)+".biclusters.tsv"
        ground_truth = pd.read_csv(ground_truth_file,sep ="\t",index_col=0)
        ground_truth["samples"] = ground_truth["samples"].apply(lambda x: set(x.split(" ")))
        if "genes" in ground_truth.columns.values:
            ground_truth["genes"] = ground_truth["genes"].apply(lambda x: set(x.split(" ")))
        # make dictionary with sample sets for calculate_perforamce()
        known_groups = {}
        known_groups["simulated"] = {}
        for group in ground_truth.index.values:
            known_groups["simulated"][group] = ground_truth.loc[group,"samples"]
            
        basename = scenario+".n_genes="+str(gsize)
        print(scenario,gsize)

        for n_run in range(n_runs):
            seed = seeds[n_run]
            for pval in pvals:
                for bin_method in bin_methods:
                    for ds in ds_values:
                        for dch in dchs:
                            #
                            for d in directions:
                                # save parameters as a ;-separated string
                                params = "bin="+bin_method+";pval="+str(pval)+";direction="+str("-".join(d))
                                params += ";clust="+clust_method+";dch="+str(dch)+";ds="+str(ds)+";preClustering=T"
                                
                                fname = out_dir+basename+".seed="+str(seed)+\
                                ".bin="+bin_method +",pval="+str(pval)+",clust="+clust_method+",direction="+\
                                str("-".join(d))+",ds="+str(ds)+",dch="+str(dch)+",max_power=10,precluster=True.biclusters.tsv"
                                
                                try:
                                    t0 = time()
                                    if os.path.exists(fname):
                                        result = read_bic_table(fname)
                                    else:
                                        result = run(exprs_file, basename , out_dir=out_dir,
                                                                        save=True, load = True,
                                                                min_n_samples = 5,
                                                                bin_method = bin_method, pval = pval,
                                                                directions = d,
                                                                clust_method = clust_method,
                                                                precluster=True,
                                                                ds=ds,dch=dch,
                                                                rpath=rpath,
                                                                seed = seed,
                                                                verbose = False)

                                    time_t = time()-t0
                                    # find best matches and calculate performance 
                                    performance, best_matches = calculate_perfromance(result, known_groups,all_samples)

                                    d = {"scenario":scenario,"gsize":gsize,
                                         "n_run":n_run,"seed":seed,
                                         "parameters":params, 
                                         "performance":performance["simulated"]}
                                    d["runtime"] = time()-t0
                                    df2.append(d)
                                except:
                                    print("\t failed",n_run,seed, params, file = sys.stderr)
# Out:
# A 500
# A 50
# A 5
# 	 failed 1 14942603 bin=GMM;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=0;preClustering=T
# B 500
# B 50
# B 5
# 	 failed 3 99529223 bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=0;preClustering=T
# 	 failed 3 99529223 bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=0;preClustering=T
# 	 failed 3 99529223 bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=1;preClustering=T
# 	 failed 3 99529223 bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=1;preClustering=T
# 	 failed 3 99529223 bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=2;preClustering=T
# 	 failed 3 99529223 bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=2;preClustering=T
# 	 failed 3 99529223 bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=3;preClustering=T
# 	 failed 3 99529223 bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=3;preClustering=T
# 	 failed 3 99529223 bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=4;preClustering=T
# 	 failed 3 99529223 bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=4;preClustering=T
# 	 failed 3 99529223 bin=ward;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=0;preClustering=T
# C 500
# C 50
# C 5
# 	 failed 0 85822412 bin=ward;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=0;preClustering=T
# 	 failed 1 14942603 bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=0;preClustering=T
# 	 failed 1 14942603 bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=0;preClustering=T
# 	 failed 1 14942603 bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=1;preClustering=T
# 	 failed 1 14942603 bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=1;preClustering=T
# 	 failed 1 14942603 bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=2;preClustering=T
# 	 failed 1 14942603 bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=2;preClustering=T
# 	 failed 1 14942603 bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=3;preClustering=T
# 	 failed 1 14942603 bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=3;preClustering=T
# 	 failed 1 14942603 bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=4;preClustering=T
# 	 failed 1 14942603 bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=4;preClustering=T
# 	 failed 1 14942603 bin=ward;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=0;preClustering=T
# 	 failed 3 99529223 bin=kmeans;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=0;preClustering=T
# 	 failed 3 99529223 bin=kmeans;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=0;preClustering=T
# 	 failed 3 99529223 bin=kmeans;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=1;preClustering=T
# 	 failed 3 99529223 bin=kmeans;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=1;preClustering=T
# 	 failed 3 99529223 bin=kmeans;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=2;preClustering=T
# 	 failed 3 99529223 bin=kmeans;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=2;preClustering=T
# 	 failed 3 99529223 bin=kmeans;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=3;preClustering=T
# 	 failed 3 99529223 bin=kmeans;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=3;preClustering=T
# 	 failed 3 99529223 bin=kmeans;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=4;preClustering=T
# 	 failed 3 99529223 bin=kmeans;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=4;preClustering=T
# 	 failed 3 99529223 bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=0;preClustering=T
# 	 failed 3 99529223 bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=0;preClustering=T
# 	 failed 3 99529223 bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=1;preClustering=T
# 	 failed 3 99529223 bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=1;preClustering=T
# 	 failed 3 99529223 bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=2;preClustering=T
# 	 failed 3 99529223 bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=2;preClustering=T
# 	 failed 3 99529223 bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=3;preClustering=T
# 	 failed 3 99529223 bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=3;preClustering=T
# 	 failed 3 99529223 bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=4;preClustering=T
# 	 failed 3 99529223 bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=4;preClustering=T
# 	 failed 4 36913810 bin=ward;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=0;preClustering=T

# %%
pd.DataFrame.from_records(df+df2).loc[:,["parameters","performance"]].groupby(["parameters"]).agg("mean").sort_values("performance",ascending=False).head(10)
# Out:
#                                                     performance
# parameters
# bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCN...     0.984656
# bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCN...     0.984656
# bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCN...     0.984656
# bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCN...     0.984656
# bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCN...     0.984656
# bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCN...     0.984656
# bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCN...     0.982540
# bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCN...     0.982540
# bin=GMM;pval=0.005;direction=UP-DOWN;clust=WGCN...     0.982222
# bin=GMM;pval=0.01;direction=UP-DOWN;clust=WGCNA...     0.982207

# %%
overall_performance = pd.DataFrame.from_records(df+df2)
overall_performance.head(5)
# Out:
#   scenario  gsize  n_run      seed  \
# 0        A    500      0  85822412
# 1        A    500      0  85822412
# 2        A    500      0  85822412
# 3        A    500      0  85822412
# 4        A    500      0  85822412
#
#                                           parameters  performance    runtime
# 0  bin=kmeans;pval=0.001;direction=UP-DOWN;clust=...          1.0  38.960614
# 1  bin=kmeans;pval=0.001;direction=UP-DOWN;clust=...          1.0  19.671304
# 2  bin=kmeans;pval=0.001;direction=UP-DOWN;clust=...          1.0  22.045249
# 3  bin=kmeans;pval=0.001;direction=UP-DOWN;clust=...          1.0  20.182466
# 4  bin=kmeans;pval=0.001;direction=UP-DOWN;clust=...          1.0  20.191431

# %%
overall_performance.to_csv("UnPaSt_ABC.tsv",sep = "\t")

# %%
best_params = "bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=3;preClustering=T"

# %%
# mean
df = pd.read_csv("UnPaSt_ABC.tsv",sep = "\t",index_col =0)
d = df.loc[df["parameters"]==best_params,:]
d.groupby(["parameters","scenario","gsize"]).agg("mean").sort_values("performance",ascending=False).head(20)
# Out:
#                                                                    n_run  \
# parameters                                         scenario gsize
# bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCN... A        50      2.00
#                                                             500     2.00
#                                                    B        50      2.00
#                                                             500     2.00
#                                                    C        50      2.00
#                                                             500     2.00
#                                                    A        5       2.00
#                                                    B        5       1.75
#                                                    C        5       2.00
#
#                                                                           seed  \
# parameters                                         scenario gsize
# bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCN... A        50     48112986.80
#                                                             500    48112986.80
#                                                    B        50     48112986.80
#                                                             500    48112986.80
#                                                    C        50     48112986.80
#                                                             500    48112986.80
#                                                    A        5      48112986.80
#                                                    B        5      35258927.75
#                                                    C        5      42031036.00
#
#                                                                    performance  \
# parameters                                         scenario gsize
# bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCN... A        50        1.000000
#                                                             500       1.000000
#                                                    B        50        1.000000
#                                                             500       1.000000
#                                                    C        50        1.000000
#                                                             500       1.000000
#                                                    A        5         0.948889
#                                                    B        5         0.944444
#                                                    C        5         0.944444
#
#                                                                      runtime
# parameters                                         scenario gsize
# bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCN... A        50     37.054168
#                                                             500    52.697145
#                                                    B        50     39.214828
#                                                             500    53.166854
#                                                    C        50     39.873100
#                                                             500    55.105027
#                                                    A        5      31.316031
#                                                    B        5      33.236592
#                                                    C        5      34.565157

# %%
# std
d = df.loc[df["parameters"]==best_params,:]
d.groupby(["parameters","scenario","gsize"]).agg("std").sort_values("performance",ascending=False).head(20)
# Out:
#                                                                       n_run  \
# parameters                                         scenario gsize
# bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCN... A        5      1.581139
#                                                             50     1.581139
#                                                             500    1.581139
#                                                    B        5      1.707825
#                                                             50     1.581139
#                                                             500    1.581139
#                                                    C        5      2.000000
#                                                             50     1.581139
#                                                             500    1.581139
#
#                                                                            seed  \
# parameters                                         scenario gsize
# bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCN... A        5      4.270373e+07
#                                                             50     4.270373e+07
#                                                             500    4.270373e+07
#                                                    B        5      3.646870e+07
#                                                             50     4.270373e+07
#                                                             500    4.270373e+07
#                                                    C        5      4.147023e+07
#                                                             50     4.270373e+07
#                                                             500    4.270373e+07
#
#                                                                    performance  \
# parameters                                         scenario gsize
# bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCN... A        5         0.002485
#                                                             50        0.000000
#                                                             500       0.000000
#                                                    B        5         0.000000
#                                                             50        0.000000
#                                                             500       0.000000
#                                                    C        5         0.000000
#                                                             50        0.000000
#                                                             500       0.000000
#
#                                                                     runtime
# parameters                                         scenario gsize
# bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCN... A        5      1.418471
#                                                             50     1.165403
#                                                             500    0.802434
#                                                    B        5      0.576345
#                                                             50     0.346394
#                                                             500    0.837982
#                                                    C        5      1.615959
#                                                             50     1.119058
#                                                             500    1.417143
