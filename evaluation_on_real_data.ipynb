# %%
import numpy as np
import pandas as pd
import sys,os
import random
import copy
from time import time

import matplotlib.pyplot as plt
import seaborn as sns


from utils.method import read_bic_table

from utils.eval import make_ref_groups
from utils.eval import calculate_perfromance, compare_gene_clusters

# %% [markdown]
# # 1. Reading expressions and annotations

# %%
exprs_file_t = "data/preprocessed_v6/TCGA-BRCA_1079_17Kgenes.Xena_TCGA_PanCan.log2_exprs_z_v6.tsv"
exprs_t= pd.read_csv(exprs_file_t,sep = "\t",index_col=0)

exprs_file_m = "data/preprocessed_v6/METABRIC_1904_17Kgenes.log2_exprs_z_v6.tsv"
exprs_m= pd.read_csv(exprs_file_m,sep = "\t",index_col=0)

m_subtypes = pd.read_csv("data/preprocessed_v6/METABRIC_1904_17Kgenes.subtypes_and_signatures_v6.tsv",sep = "\t",index_col=0)
m_annotation = pd.read_csv("data/preprocessed_v6/METABRIC_1904.annotation_v6.tsv",sep = "\t",index_col=0)

t_subtypes = pd.read_csv("data/preprocessed_v6/TCGA-BRCA_1079_17Kgenes.Xena_TCGA_PanCan.subtypes_and_signatures_v6.tsv",sep = "\t",index_col=0)
t_annotation = pd.read_csv("data/preprocessed_v6/TCGA-BRCA_1079.Xena_TCGA_PanCan.annotation_v6.tsv",sep = "\t",index_col=0)

# %% [markdown]
# ## 1.1 Preparing ground truth samples sets for performance evaluation
#
# ### Example of known_groups dictionary for TCGA-BRCA
#
# *make_ref_groups(subtypes, annotation, exprs)*
#
# **input:**
#   - subtypes - subtypes dataframe
#   - annotation - annotation dataframe
#   - exprs - expression dataframe
#
# **returns:**
#   -  known_groups = {classificaton1:{"subt1":{s1,s2,...} , "subt2":{...}, "subt3":{...}, ...}, "classi2":{"subtA":{...}}, ... }
# *known_groups* is a dictionary with known sample classifications. Each classification (e.g. PAM50 or IHC or Luminal) is a dict that can conatain one or several sample sets
#   -  all_samples = {} set of all samples in expression and annotation files; necessary for computing overlap p-values

# %%
known_groups_t, all_samples_t = make_ref_groups(t_subtypes, t_annotation,exprs_t)
known_groups_m, all_samples_m = make_ref_groups(m_subtypes, m_annotation,exprs_m)

# %% [markdown]
# # Example 1:
# ## The sructure of known_groups dict for TCGA-BRCA:
#
# We calculate performance for **classifications**:
#     * PAM50 = [Luminal, Basal, Her2, Normal]
#     * Intrinsic = [Luminal, Basal, Her2, Normal, Claudin-low]
#     * PAM50_AB =  [LumA, LumB, Basal, Her2, Normal]
#     * SCMOD2 = [ER-/HER2-, ER+/HER2- High Prolif, ER+/HER2- Low Prolif,  HER2+]
#     * IHC = [IHC_HER2, IHC_ER, IHC_PR, IHC_TNBC]
# And for **isolated sample sets** corresponding to Luminal, Basal, LumA, NEC subtypes etc.

# %%
for cl in known_groups_t.keys():
    if len(known_groups_t[cl].keys())>1:
        print("classification", cl)
        print("\tsbtypes:"," ".join(known_groups_t[cl].keys()))
    else:
        print(" classification", cl, "(individual subtype)")
# Out:
# classification PAM50
# 	sbtypes: Basal Normal Her2 Luminal
# classification Intrinsic
# 	sbtypes: Basal Normal Her2 Luminal Claudin-low
# classification PAM50_AB
# 	sbtypes: Basal Normal LumA Her2 LumB
# classification SCMOD2
# 	sbtypes: ER-/HER2- ER+/HER2- High Prolif ER+/HER2- Low Prolif HER2+
# classification IHC
# 	sbtypes: IHC_HER2 IHC_ER IHC_PR IHC_TNBC
#  classification Luminal (individual subtype)
#  classification Basal (individual subtype)
#  classification Her2 (individual subtype)
#  classification LumA (individual subtype)
#  classification LumB (individual subtype)
#  classification Normal (individual subtype)
#  classification Claudin-low (individual subtype)
#  classification IHC_HER2 (individual subtype)
#  classification IHC_ER (individual subtype)
#  classification IHC_PR (individual subtype)
#  classification IHC_TNBC (individual subtype)
#  classification NET_kmeans (individual subtype)
#  classification NET_ward (individual subtype)

# %% [markdown]
# # Example 2:
# ## evaluation of the resulting sample set (on the example of UnPaSt file)
# reading the results

# %%
file = "results_on_real_data_WGCNA2/TCGA.seed=670487.bin=kmeans,pval=0.01,clust=WGCNA,direction=UP-DOWN,ds=3,dch=0.995,max_power=10,precluster=True.biclusters.tsv"
result = read_bic_table(file) # reading UnPaSt outputs
print("sample clusters: ", result.shape[0])
# drop clusters too small with < 5 samples
result = result.loc[result["samples"].apply(lambda x: len(x))>=5,:]
print("sample clusters: ", result.shape[0])
result.head(2)
# Out:
# sample clusters:  168
# sample clusters:  168
#          SNR  n_genes  n_samples  \
# id
# 0   4.042148      116         14
# 1   3.314768       52        191
#
#                                                 genes  \
# id
# 0   {KRTAP11-1, OR13D1, C9orf57, LOC286083, CPS1-I...
# 1   {KLHDC7A, C9orf152, HOXB2, CYP4Z2P, AR, PAX2, ...
#
#                                               samples direction  \
# id
# 0   {TCGA-A7-A13G-01, TCGA-A8-A08G-01, TCGA-A7-A0D...        UP
# 1   {TCGA-B6-A1KF-01, TCGA-S3-AA15-01, TCGA-EW-A1O...      DOWN
#
#                                              genes_up  \
# id
# 0   {KRTAP11-1, OR13D1, C9orf57, LOC286083, CPS1-I...
# 1                                                  {}
#
#                                            genes_down  \
# id
# 0                                                  {}
# 1   {KLHDC7A, C9orf152, HOXB2, CYP4Z2P, AR, PAX2, ...
#
#                                          gene_indexes  \
# id
# 0   {8194, 10251, 13836, 13838, 15375, 2063, 2065,...
# 1   {2947, 7430, 17160, 17161, 15755, 7821, 12174,...
#
#                                        sample_indexes
# id
# 0   {130, 131, 132, 133, 262, 135, 137, 202, 138, ...
# 1   {1024, 514, 1018, 1030, 519, 8, 1035, 524, 103...

# %% [markdown]
# * ensure that results file is a dataframe with "samples" column
# * each row in samples column must contain a non-empty set of samples
# ## performance evaluation
# * requires *known_groups* dict and *all_samples* set
#      - using *make_ref_groups()* is recommened for this breast cancer analysis
#      - alternatively, *known_groups* dict and *all_samples* can be created manually
# * if samples in (bi)clusters do not match *all_samples* set, trho

# %% [markdown]
# *calculate_perfromance(bi_clusters_df, annotation, exprs)*
#
# **input:**
#   - bi_clusters_df - a dataframe with sample clusters (sets in "sample" column)
#   - *known_groups* is a dictionary with known sample classifications. Each classification (e.g. PAM50 or IHC or Luminal) is a dict that can conatain one or several sample sets
#   - *all_samples* = {} set of all samples in expression and annotation files; necessary for computing overlap p-values
#
# **returns:**
#   - performances - *pandas.Series* with overall perforamnce for each classification from *known_groups*
#   - best_matches - a dataframe with information about the best matching (bi)cluster for each sample set from *known_groups* (helpful for debugging and validation)

# %%
performances, best_matches = calculate_perfromance(result, known_groups_t,all_samples_t)
performances
# Out:
# PAM50          0.842163
# Intrinsic      0.810808
# PAM50_AB       0.630113
# SCMOD2         0.652669
# IHC            0.712046
# Luminal        0.898305
# Basal          0.949495
# Her2           0.486842
# LumA           0.680070
# LumB           0.473404
# Normal         0.082011
# Claudin-low    0.118483
# IHC_HER2       0.412371
# IHC_ER         0.869464
# IHC_PR         0.777910
# IHC_TNBC       0.473430
# NET_kmeans     0.671875
# NET_ward       0.551724
# dtype: float64

# %%
best_matches
# Out:
#                       bm_id         J    weight  adj_pval is_enriched  \
# Basal                     1  0.949495  0.180723       0.0        True
# Normal                  132  0.082011  0.029657       0.0        True
# Her2                      8  0.486842  0.100093       0.0        True
# Luminal                   4  0.898305  0.689527       0.0       False
# Basal                     1  0.949495  0.173488       0.0        True
# Normal                  132  0.082011   0.02847       0.0        True
# Her2                      8  0.486842  0.096085       0.0        True
# Luminal                   4  0.898305  0.661922       0.0       False
# Claudin-low             134  0.058997  0.040036  0.009062       False
# Basal                     1  0.949495  0.180723       0.0        True
# Normal                  159  0.059659  0.029657  0.010363        True
# LumA                     77   0.68007   0.39481       0.0        True
# Her2                      8  0.486842  0.100093       0.0        True
# LumB                     69  0.473404  0.294717       0.0        True
# ER-/HER2-                 1  0.850679  0.202039       0.0        True
# ER+/HER2- High Prolif    95  0.468118  0.375348       0.0        True
# ER+/HER2- Low Prolif    117  0.697479  0.333642       0.0        True
# HER2+                     8  0.813559  0.088971       0.0        True
# IHC_HER2                  8  0.412371   0.09054       0.0        True
# IHC_ER                    4  0.869464  0.452699       0.0       False
# IHC_PR                   55  0.692209  0.390598       0.0       False
# IHC_TNBC                 63  0.162162  0.066164  0.000002        True
# Luminal                   4  0.898305       1.0       0.0       False
# Basal                     1  0.949495       1.0       0.0        True
# Her2                      8  0.486842       1.0       0.0        True
# LumA                     77   0.68007       1.0       0.0        True
# LumB                     69  0.473404       1.0       0.0        True
# Normal                  132  0.082011       1.0       0.0        True
# Claudin-low               1  0.118483       1.0  0.000001        True
# IHC_HER2                  8  0.412371       1.0       0.0        True
# IHC_ER                    4  0.869464       1.0       0.0       False
# IHC_PR                    4   0.77791       1.0       0.0       False
# IHC_TNBC                  1   0.47343       1.0       0.0        True
# NET                       7  0.671875       1.0       0.0        True
# NET                       7  0.551724       1.0       0.0        True
#
#                       classification
# Basal                          PAM50
# Normal                         PAM50
# Her2                           PAM50
# Luminal                        PAM50
# Basal                      Intrinsic
# Normal                     Intrinsic
# Her2                       Intrinsic
# Luminal                    Intrinsic
# Claudin-low                Intrinsic
# Basal                       PAM50_AB
# Normal                      PAM50_AB
# LumA                        PAM50_AB
# Her2                        PAM50_AB
# LumB                        PAM50_AB
# ER-/HER2-                     SCMOD2
# ER+/HER2- High Prolif         SCMOD2
# ER+/HER2- Low Prolif          SCMOD2
# HER2+                         SCMOD2
# IHC_HER2                         IHC
# IHC_ER                           IHC
# IHC_PR                           IHC
# IHC_TNBC                         IHC
# Luminal                      Luminal
# Basal                          Basal
# Her2                            Her2
# LumA                            LumA
# LumB                            LumB
# Normal                        Normal
# Claudin-low              Claudin-low
# IHC_HER2                    IHC_HER2
# IHC_ER                        IHC_ER
# IHC_PR                        IHC_PR
# IHC_TNBC                    IHC_TNBC
# NET                       NET_kmeans
# NET                         NET_ward

# %% [markdown]
# # 2. Evaluation of the results obtained with different parameters
# (UnPaSt)

# %%
# selecting 5 seeds for probabilistic methods 
n_runs = 5
seeds = []
random.seed(42)
for i in range(n_runs):
    seeds.append(random.randint(0,1000000))
print("generate ",n_runs," seeds",seeds)
# Out:
# generate  5  seeds [670487, 116739, 26225, 777572, 288389]

# %%
subt_t = [] # Perfoemances for TCGA-BRCA
subt_m = [] # Perfoemances for METABRIC
clustering_similarities = [] # Similarities of gene clusters found in TCGA and METABRIC

# UnPaSt parameters 
from run_unpast import run
rpath="/home/olya/anaconda3/envs/r4_env/bin/"
out_dir= "results_on_real_data_WGCNA2/"
basename_t = "TCGA"
basename_m = "METABRIC" 
pvals = [0.05,0.01,0.005,0.001]
bin_methods = ["kmeans","GMM","ward"] 
directions =  [["UP","DOWN"],["BOTH"]]

# %% [markdown]
# Because UnPaSt parameters are different for Louvain and WGCNA feature clusterings,
# we run it for each clust_method in a separate *for* loop

# %%
### Louvain 
out_dir= "results_on_real_data_WGCNA2//"
modularities = [0,0.3,0.4,0.5,0.6,0.7,0.8,0.9]

subt_t = []
subt_m = []
clustering_similarities = []


for pval in pvals:
    for bin_method in bin_methods:
        for d in directions:
            for m in modularities:
                # save parameters as a ;-separated string
                params = "bin="+bin_method+";pval="+str(pval)
                params += ";clust="+"Louvain"+";direction="+"-".join(d)+";m="+str(m)
                print()
                for r in range(n_runs):
                    seed = seeds[r]
                    params_dict = {"parameters":params, "seed":seed,"run":r}
                    ### running TCGA or reading results
                    try:
                        t0 = time()
                        fname = out_dir+basename_t+".seed="+str(seed)+\
                        ".bin="+bin_method +",pval="+str(pval)+",clust=Louvain"+",direction="+"-".join(d)+",m="+str(m)+".biclusters.tsv"
                        result_t = read_bic_table(fname)
                        """result_t = run_DESMOND(exprs_file_t, basename_t, out_dir=out_dir,
                                                    save=True, load = True,
                                                    ceiling = 3,
                                                    min_n_samples = 5,
                                                    bin_method = bin_method, pval = pval,
                                                    clust_method = "Louvain",
                                                    similarity_cutoffs = similarity_cutoffs,
                                                    seed = seed,
                                                    verbose = False)
                                                    """
                        time_t = time()-t0
                        # find the best matches between TCGA biclusters and subtypes
                        # and calculate overall performance == weighted sum of Jaccard indexes
                        performance_t,bm_dict_t = calculate_perfromance(result_t, known_groups_t,all_samples_t)
                        performance_t = performance_t.to_dict()
                        performance_t.update(params_dict)
                        performance_t["time"] = time_t
                        subt_t.append(performance_t)
                        t_failed = False
                    except:
                        print("TCGA biclustering failed with ",seed,  pval,bin_method ,file = sys.stderr)
                        print(fname)
                        t_failed = True
                        subt_t.append({params_dict})

                    ### running METABRIC or reading results
                    try:
                        t0 = time()
                        fname = out_dir+basename_m+".seed="+str(seed)+\
                        ".bin="+bin_method +",pval="+str(pval)+",clust=Louvain"+",direction="+"-".join(d)+",m="+str(m)+".biclusters.tsv"
                        result_m = read_bic_table(fname)
                        """result_m = run_DESMOND(exprs_file_m, basename_m, out_dir=out_dir,
                                                    save=True, load = True,
                                                    ceiling = 3,
                                                    min_n_samples = 5,
                                                    bin_method = bin_method, pval = pval,
                                                    clust_method = "Louvain",
                                                    similarity_cutoffs = similarity_cutoffs,
                                                    seed = seed,
                                                    verbose = False)"""
                        time_m = time()-t0
                        # find the best matches between METABRIC biclusters and subtypes
                        # and calculate overall performance == weighted sum of Jaccard indexes
                        performance_m,bm_dict_m = calculate_perfromance(result_m, known_groups_m,all_samples_m)
                        performance_m = performance_m.to_dict()
                        performance_m.update(params_dict)
                        performance_m["time"] = time_m
                        subt_m.append(performance_m)
                        m_failed = False
                    except:
                        print("METABRIC biclustering failed with ",seed,  pval,bin_method ,file = sys.stderr)
                        print(fname)
                        m_failed = True
                        subt_m.append(params_dict)
                    print(params,seed, round(performance_t["PAM50"],3),round(performance_m["PAM50"],3))    
                    # compare clustering results - only if gene sets are defined for each cluster
                    if not (t_failed or m_failed): 
                        N = exprs_m.shape[0]
                        clust_sim, bm, bm2 = compare_gene_clusters(result_t,result_m, N)                    
                    else:
                        clust_sim = {}
                    clust_sim.update(params_dict)
                    clustering_similarities.append(clust_sim)
# Out:
# bin=kmeans;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0 670487 0.738 0.835
# bin=kmeans;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0 116739 0.841 0.834
# bin=kmeans;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0 26225 0.734 0.835
# bin=kmeans;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0 777572 0.75 0.834
# bin=kmeans;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0 288389 0.73 0.835
#
# bin=kmeans;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.3 670487 0.738 0.835
# bin=kmeans;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.3 116739 0.841 0.834
# bin=kmeans;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.3 26225 0.734 0.835
# bin=kmeans;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.3 777572 0.75 0.834
# bin=kmeans;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.3 288389 0.73 0.835
#
# bin=kmeans;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.4 670487 0.738 0.835
# bin=kmeans;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.4 116739 0.841 0.834
# bin=kmeans;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.4 26225 0.734 0.835
# bin=kmeans;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.4 777572 0.75 0.834
# bin=kmeans;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.4 288389 0.73 0.835
#
# bin=kmeans;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.5 670487 0.738 0.835
# bin=kmeans;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.5 116739 0.841 0.834
# bin=kmeans;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.5 26225 0.734 0.835
# bin=kmeans;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.5 777572 0.75 0.834
# bin=kmeans;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.5 288389 0.73 0.835
#
# bin=kmeans;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.6 670487 0.738 0.835
# bin=kmeans;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.6 116739 0.841 0.834
# bin=kmeans;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.6 26225 0.734 0.835
# bin=kmeans;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.6 777572 0.75 0.834
# bin=kmeans;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.6 288389 0.73 0.835
#
# bin=kmeans;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.7 670487 0.738 0.835
# bin=kmeans;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.7 116739 0.841 0.834
# bin=kmeans;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.7 26225 0.734 0.835
# bin=kmeans;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.7 777572 0.75 0.834
# bin=kmeans;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.7 288389 0.73 0.835
#
# bin=kmeans;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.8 670487 0.738 0.835
# bin=kmeans;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.8 116739 0.841 0.834
# bin=kmeans;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.8 26225 0.734 0.835
# bin=kmeans;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.8 777572 0.75 0.834
# bin=kmeans;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.8 288389 0.73 0.835
#
# bin=kmeans;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.9 670487 0.738 0.835
# bin=kmeans;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.9 116739 0.841 0.834
# bin=kmeans;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.9 26225 0.734 0.835
# bin=kmeans;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.9 777572 0.75 0.834
# bin=kmeans;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.9 288389 0.73 0.835
#
# bin=kmeans;pval=0.1;clust=Louvain;direction=BOTH;m=0 670487 0.756 0.835
# bin=kmeans;pval=0.1;clust=Louvain;direction=BOTH;m=0 116739 0.739 0.834
# bin=kmeans;pval=0.1;clust=Louvain;direction=BOTH;m=0 26225 0.733 0.834
# bin=kmeans;pval=0.1;clust=Louvain;direction=BOTH;m=0 777572 0.74 0.834
# bin=kmeans;pval=0.1;clust=Louvain;direction=BOTH;m=0 288389 0.755 0.835
#
# bin=kmeans;pval=0.1;clust=Louvain;direction=BOTH;m=0.3 670487 0.756 0.835
# bin=kmeans;pval=0.1;clust=Louvain;direction=BOTH;m=0.3 116739 0.739 0.834
# bin=kmeans;pval=0.1;clust=Louvain;direction=BOTH;m=0.3 26225 0.733 0.834
# bin=kmeans;pval=0.1;clust=Louvain;direction=BOTH;m=0.3 777572 0.74 0.834
# bin=kmeans;pval=0.1;clust=Louvain;direction=BOTH;m=0.3 288389 0.755 0.835
#
# bin=kmeans;pval=0.1;clust=Louvain;direction=BOTH;m=0.4 670487 0.756 0.835
# bin=kmeans;pval=0.1;clust=Louvain;direction=BOTH;m=0.4 116739 0.739 0.834
# bin=kmeans;pval=0.1;clust=Louvain;direction=BOTH;m=0.4 26225 0.733 0.834
# bin=kmeans;pval=0.1;clust=Louvain;direction=BOTH;m=0.4 777572 0.74 0.834
# bin=kmeans;pval=0.1;clust=Louvain;direction=BOTH;m=0.4 288389 0.755 0.835
#
# bin=kmeans;pval=0.1;clust=Louvain;direction=BOTH;m=0.5 670487 0.756 0.835
# bin=kmeans;pval=0.1;clust=Louvain;direction=BOTH;m=0.5 116739 0.739 0.834
# bin=kmeans;pval=0.1;clust=Louvain;direction=BOTH;m=0.5 26225 0.733 0.834
# bin=kmeans;pval=0.1;clust=Louvain;direction=BOTH;m=0.5 777572 0.74 0.834
# bin=kmeans;pval=0.1;clust=Louvain;direction=BOTH;m=0.5 288389 0.755 0.835
#
# bin=kmeans;pval=0.1;clust=Louvain;direction=BOTH;m=0.6 670487 0.756 0.835
# bin=kmeans;pval=0.1;clust=Louvain;direction=BOTH;m=0.6 116739 0.739 0.834
# bin=kmeans;pval=0.1;clust=Louvain;direction=BOTH;m=0.6 26225 0.733 0.834
# bin=kmeans;pval=0.1;clust=Louvain;direction=BOTH;m=0.6 777572 0.74 0.834
# bin=kmeans;pval=0.1;clust=Louvain;direction=BOTH;m=0.6 288389 0.755 0.835
#
# bin=kmeans;pval=0.1;clust=Louvain;direction=BOTH;m=0.7 670487 0.756 0.835
# bin=kmeans;pval=0.1;clust=Louvain;direction=BOTH;m=0.7 116739 0.739 0.834
# bin=kmeans;pval=0.1;clust=Louvain;direction=BOTH;m=0.7 26225 0.733 0.834
# bin=kmeans;pval=0.1;clust=Louvain;direction=BOTH;m=0.7 777572 0.74 0.834
# bin=kmeans;pval=0.1;clust=Louvain;direction=BOTH;m=0.7 288389 0.755 0.835
#
# bin=kmeans;pval=0.1;clust=Louvain;direction=BOTH;m=0.8 670487 0.756 0.835
# bin=kmeans;pval=0.1;clust=Louvain;direction=BOTH;m=0.8 116739 0.739 0.834
# bin=kmeans;pval=0.1;clust=Louvain;direction=BOTH;m=0.8 26225 0.733 0.834
# bin=kmeans;pval=0.1;clust=Louvain;direction=BOTH;m=0.8 777572 0.74 0.834
# bin=kmeans;pval=0.1;clust=Louvain;direction=BOTH;m=0.8 288389 0.755 0.835
#
# bin=kmeans;pval=0.1;clust=Louvain;direction=BOTH;m=0.9 670487 0.756 0.835
# bin=kmeans;pval=0.1;clust=Louvain;direction=BOTH;m=0.9 116739 0.739 0.834
# bin=kmeans;pval=0.1;clust=Louvain;direction=BOTH;m=0.9 26225 0.733 0.834
# bin=kmeans;pval=0.1;clust=Louvain;direction=BOTH;m=0.9 777572 0.74 0.834
# bin=kmeans;pval=0.1;clust=Louvain;direction=BOTH;m=0.9 288389 0.755 0.835
#
# bin=GMM;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0 670487 0.813 0.832
# bin=GMM;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0 116739 0.819 0.832
# bin=GMM;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0 26225 0.806 0.832
# bin=GMM;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0 777572 0.801 0.832
# bin=GMM;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0 288389 0.819 0.827
#
# bin=GMM;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.3 670487 0.813 0.832
# bin=GMM;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.3 116739 0.819 0.832
# bin=GMM;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.3 26225 0.806 0.832
# bin=GMM;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.3 777572 0.801 0.832
# bin=GMM;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.3 288389 0.819 0.827
#
# bin=GMM;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.4 670487 0.813 0.832
# bin=GMM;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.4 116739 0.819 0.832
# bin=GMM;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.4 26225 0.806 0.832
# bin=GMM;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.4 777572 0.801 0.832
# bin=GMM;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.4 288389 0.819 0.827
#
# bin=GMM;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.5 670487 0.813 0.832
# bin=GMM;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.5 116739 0.819 0.832
# bin=GMM;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.5 26225 0.806 0.832
# bin=GMM;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.5 777572 0.801 0.832
# bin=GMM;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.5 288389 0.819 0.827
#
# bin=GMM;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.6 670487 0.813 0.832
# bin=GMM;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.6 116739 0.819 0.832
# bin=GMM;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.6 26225 0.806 0.832
# bin=GMM;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.6 777572 0.801 0.832
# bin=GMM;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.6 288389 0.819 0.827
#
# bin=GMM;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.7 670487 0.813 0.832
# bin=GMM;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.7 116739 0.819 0.832
# bin=GMM;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.7 26225 0.806 0.832
# bin=GMM;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.7 777572 0.801 0.832
# bin=GMM;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.7 288389 0.819 0.827
# bin=GMM;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.8 670487 0.813 0.832
# bin=GMM;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.8 116739 0.819 0.832
# bin=GMM;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.8 26225 0.806 0.832
# bin=GMM;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.8 777572 0.801 0.832
# bin=GMM;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.8 288389 0.819 0.827
#
# bin=GMM;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.9 670487 0.813 0.832
# bin=GMM;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.9 116739 0.819 0.832
# bin=GMM;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.9 26225 0.806 0.832
# bin=GMM;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.9 777572 0.801 0.832
# bin=GMM;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.9 288389 0.819 0.827
#
# bin=GMM;pval=0.1;clust=Louvain;direction=BOTH;m=0 670487 0.721 0.831
# bin=GMM;pval=0.1;clust=Louvain;direction=BOTH;m=0 116739 0.746 0.837
# bin=GMM;pval=0.1;clust=Louvain;direction=BOTH;m=0 26225 0.747 0.837
# bin=GMM;pval=0.1;clust=Louvain;direction=BOTH;m=0 777572 0.746 0.837
# bin=GMM;pval=0.1;clust=Louvain;direction=BOTH;m=0 288389 0.721 0.837
#
# bin=GMM;pval=0.1;clust=Louvain;direction=BOTH;m=0.3 670487 0.721 0.831
# bin=GMM;pval=0.1;clust=Louvain;direction=BOTH;m=0.3 116739 0.746 0.837
# bin=GMM;pval=0.1;clust=Louvain;direction=BOTH;m=0.3 26225 0.747 0.837
# bin=GMM;pval=0.1;clust=Louvain;direction=BOTH;m=0.3 777572 0.746 0.837
# bin=GMM;pval=0.1;clust=Louvain;direction=BOTH;m=0.3 288389 0.721 0.837
#
# bin=GMM;pval=0.1;clust=Louvain;direction=BOTH;m=0.4 670487 0.721 0.831
# bin=GMM;pval=0.1;clust=Louvain;direction=BOTH;m=0.4 116739 0.746 0.837
# bin=GMM;pval=0.1;clust=Louvain;direction=BOTH;m=0.4 26225 0.747 0.837
# bin=GMM;pval=0.1;clust=Louvain;direction=BOTH;m=0.4 777572 0.746 0.837
# bin=GMM;pval=0.1;clust=Louvain;direction=BOTH;m=0.4 288389 0.721 0.837
#
# bin=GMM;pval=0.1;clust=Louvain;direction=BOTH;m=0.5 670487 0.721 0.831
# bin=GMM;pval=0.1;clust=Louvain;direction=BOTH;m=0.5 116739 0.746 0.837
# bin=GMM;pval=0.1;clust=Louvain;direction=BOTH;m=0.5 26225 0.747 0.837
# bin=GMM;pval=0.1;clust=Louvain;direction=BOTH;m=0.5 777572 0.746 0.837
# bin=GMM;pval=0.1;clust=Louvain;direction=BOTH;m=0.5 288389 0.721 0.837
#
# bin=GMM;pval=0.1;clust=Louvain;direction=BOTH;m=0.6 670487 0.721 0.831
# bin=GMM;pval=0.1;clust=Louvain;direction=BOTH;m=0.6 116739 0.746 0.837
# bin=GMM;pval=0.1;clust=Louvain;direction=BOTH;m=0.6 26225 0.747 0.837
# bin=GMM;pval=0.1;clust=Louvain;direction=BOTH;m=0.6 777572 0.746 0.837
# bin=GMM;pval=0.1;clust=Louvain;direction=BOTH;m=0.6 288389 0.721 0.837
#
# bin=GMM;pval=0.1;clust=Louvain;direction=BOTH;m=0.7 670487 0.721 0.831
# bin=GMM;pval=0.1;clust=Louvain;direction=BOTH;m=0.7 116739 0.746 0.837
# bin=GMM;pval=0.1;clust=Louvain;direction=BOTH;m=0.7 26225 0.747 0.837
# bin=GMM;pval=0.1;clust=Louvain;direction=BOTH;m=0.7 777572 0.746 0.837
# bin=GMM;pval=0.1;clust=Louvain;direction=BOTH;m=0.7 288389 0.721 0.837
#
# bin=GMM;pval=0.1;clust=Louvain;direction=BOTH;m=0.8 670487 0.721 0.831
# bin=GMM;pval=0.1;clust=Louvain;direction=BOTH;m=0.8 116739 0.746 0.837
# bin=GMM;pval=0.1;clust=Louvain;direction=BOTH;m=0.8 26225 0.747 0.837
# bin=GMM;pval=0.1;clust=Louvain;direction=BOTH;m=0.8 777572 0.746 0.837
# bin=GMM;pval=0.1;clust=Louvain;direction=BOTH;m=0.8 288389 0.721 0.837
#
# bin=GMM;pval=0.1;clust=Louvain;direction=BOTH;m=0.9 670487 0.721 0.831
# bin=GMM;pval=0.1;clust=Louvain;direction=BOTH;m=0.9 116739 0.746 0.837
# bin=GMM;pval=0.1;clust=Louvain;direction=BOTH;m=0.9 26225 0.747 0.837
# bin=GMM;pval=0.1;clust=Louvain;direction=BOTH;m=0.9 777572 0.746 0.837
# bin=GMM;pval=0.1;clust=Louvain;direction=BOTH;m=0.9 288389 0.721 0.837
#
# bin=ward;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0 670487 0.782 0.833
# bin=ward;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0 116739 0.781 0.833
# bin=ward;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0 26225 0.781 0.833
# bin=ward;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0 777572 0.782 0.833
# bin=ward;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0 288389 0.781 0.833
#
# bin=ward;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.3 670487 0.782 0.833
# bin=ward;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.3 116739 0.781 0.833
# bin=ward;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.3 26225 0.781 0.833
# bin=ward;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.3 777572 0.782 0.833
# bin=ward;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.3 288389 0.781 0.833
#
# bin=ward;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.4 670487 0.782 0.833
# bin=ward;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.4 116739 0.781 0.833
# bin=ward;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.4 26225 0.781 0.833
# bin=ward;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.4 777572 0.782 0.833
# bin=ward;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.4 288389 0.781 0.833
#
# bin=ward;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.5 670487 0.782 0.833
# bin=ward;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.5 116739 0.781 0.833
# bin=ward;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.5 26225 0.781 0.833
# bin=ward;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.5 777572 0.782 0.833
# bin=ward;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.5 288389 0.781 0.833
#
# bin=ward;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.6 670487 0.782 0.833
# bin=ward;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.6 116739 0.781 0.833
# bin=ward;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.6 26225 0.781 0.833
# bin=ward;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.6 777572 0.782 0.833
# bin=ward;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.6 288389 0.781 0.833
#
# bin=ward;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.7 670487 0.782 0.833
# bin=ward;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.7 116739 0.781 0.833
# bin=ward;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.7 26225 0.781 0.833
# bin=ward;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.7 777572 0.782 0.833
# bin=ward;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.7 288389 0.781 0.833
#
# bin=ward;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.8 670487 0.782 0.833
# bin=ward;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.8 116739 0.781 0.833
# bin=ward;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.8 26225 0.781 0.833
# bin=ward;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.8 777572 0.782 0.833
# bin=ward;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.8 288389 0.781 0.833
#
# bin=ward;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.9 670487 0.782 0.833
# bin=ward;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.9 116739 0.781 0.833
# bin=ward;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.9 26225 0.781 0.833
# bin=ward;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.9 777572 0.782 0.833
# bin=ward;pval=0.1;clust=Louvain;direction=UP-DOWN;m=0.9 288389 0.781 0.833
#
# bin=ward;pval=0.1;clust=Louvain;direction=BOTH;m=0 670487 0.712 0.815
# bin=ward;pval=0.1;clust=Louvain;direction=BOTH;m=0 116739 0.735 0.815
# bin=ward;pval=0.1;clust=Louvain;direction=BOTH;m=0 26225 0.712 0.815
# bin=ward;pval=0.1;clust=Louvain;direction=BOTH;m=0 777572 0.735 0.815
# bin=ward;pval=0.1;clust=Louvain;direction=BOTH;m=0 288389 0.712 0.815
#
# bin=ward;pval=0.1;clust=Louvain;direction=BOTH;m=0.3 670487 0.712 0.815
# bin=ward;pval=0.1;clust=Louvain;direction=BOTH;m=0.3 116739 0.735 0.815
# bin=ward;pval=0.1;clust=Louvain;direction=BOTH;m=0.3 26225 0.712 0.815
# bin=ward;pval=0.1;clust=Louvain;direction=BOTH;m=0.3 777572 0.735 0.815
# bin=ward;pval=0.1;clust=Louvain;direction=BOTH;m=0.3 288389 0.712 0.815
#
# bin=ward;pval=0.1;clust=Louvain;direction=BOTH;m=0.4 670487 0.712 0.815
# bin=ward;pval=0.1;clust=Louvain;direction=BOTH;m=0.4 116739 0.735 0.815
# bin=ward;pval=0.1;clust=Louvain;direction=BOTH;m=0.4 26225 0.712 0.815
# bin=ward;pval=0.1;clust=Louvain;direction=BOTH;m=0.4 777572 0.735 0.815
# bin=ward;pval=0.1;clust=Louvain;direction=BOTH;m=0.4 288389 0.712 0.815
#
# bin=ward;pval=0.1;clust=Louvain;direction=BOTH;m=0.5 670487 0.712 0.815
# bin=ward;pval=0.1;clust=Louvain;direction=BOTH;m=0.5 116739 0.735 0.815
# bin=ward;pval=0.1;clust=Louvain;direction=BOTH;m=0.5 26225 0.712 0.815
# bin=ward;pval=0.1;clust=Louvain;direction=BOTH;m=0.5 777572 0.735 0.815
# bin=ward;pval=0.1;clust=Louvain;direction=BOTH;m=0.5 288389 0.712 0.815
#
# bin=ward;pval=0.1;clust=Louvain;direction=BOTH;m=0.6 670487 0.712 0.815
# bin=ward;pval=0.1;clust=Louvain;direction=BOTH;m=0.6 116739 0.735 0.815
# bin=ward;pval=0.1;clust=Louvain;direction=BOTH;m=0.6 26225 0.712 0.815
# bin=ward;pval=0.1;clust=Louvain;direction=BOTH;m=0.6 777572 0.735 0.815
# bin=ward;pval=0.1;clust=Louvain;direction=BOTH;m=0.6 288389 0.712 0.815
#
# bin=ward;pval=0.1;clust=Louvain;direction=BOTH;m=0.7 670487 0.712 0.815
# bin=ward;pval=0.1;clust=Louvain;direction=BOTH;m=0.7 116739 0.735 0.815
# bin=ward;pval=0.1;clust=Louvain;direction=BOTH;m=0.7 26225 0.712 0.815
# bin=ward;pval=0.1;clust=Louvain;direction=BOTH;m=0.7 777572 0.735 0.815
# bin=ward;pval=0.1;clust=Louvain;direction=BOTH;m=0.7 288389 0.712 0.815
#
# bin=ward;pval=0.1;clust=Louvain;direction=BOTH;m=0.8 670487 0.712 0.815
# bin=ward;pval=0.1;clust=Louvain;direction=BOTH;m=0.8 116739 0.735 0.815
# bin=ward;pval=0.1;clust=Louvain;direction=BOTH;m=0.8 26225 0.712 0.815
# bin=ward;pval=0.1;clust=Louvain;direction=BOTH;m=0.8 777572 0.735 0.815
# bin=ward;pval=0.1;clust=Louvain;direction=BOTH;m=0.8 288389 0.712 0.815
#
# bin=ward;pval=0.1;clust=Louvain;direction=BOTH;m=0.9 670487 0.712 0.815
# bin=ward;pval=0.1;clust=Louvain;direction=BOTH;m=0.9 116739 0.735 0.815
# bin=ward;pval=0.1;clust=Louvain;direction=BOTH;m=0.9 26225 0.712 0.815
# bin=ward;pval=0.1;clust=Louvain;direction=BOTH;m=0.9 777572 0.735 0.815
# bin=ward;pval=0.1;clust=Louvain;direction=BOTH;m=0.9 288389 0.712 0.815
#
# bin=kmeans;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0 670487 0.842 0.833
# bin=kmeans;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0 116739 0.842 0.833
# bin=kmeans;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0 26225 0.842 0.834
# bin=kmeans;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0 777572 0.842 0.834
# bin=kmeans;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0 288389 0.842 0.832
#
# bin=kmeans;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.3 670487 0.842 0.833
# bin=kmeans;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.3 116739 0.842 0.833
# bin=kmeans;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.3 26225 0.842 0.834
# bin=kmeans;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.3 777572 0.842 0.834
# bin=kmeans;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.3 288389 0.842 0.832
#
# bin=kmeans;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.4 670487 0.842 0.833
# bin=kmeans;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.4 116739 0.842 0.833
# bin=kmeans;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.4 26225 0.842 0.834
# bin=kmeans;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.4 777572 0.842 0.834
# bin=kmeans;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.4 288389 0.842 0.832
#
# bin=kmeans;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.5 670487 0.842 0.833
# bin=kmeans;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.5 116739 0.842 0.833
# bin=kmeans;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.5 26225 0.842 0.834
# bin=kmeans;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.5 777572 0.842 0.834
# bin=kmeans;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.5 288389 0.842 0.832
#
# bin=kmeans;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.6 670487 0.842 0.833
# bin=kmeans;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.6 116739 0.842 0.833
# bin=kmeans;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.6 26225 0.842 0.834
# bin=kmeans;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.6 777572 0.842 0.834
# bin=kmeans;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.6 288389 0.842 0.832
#
# bin=kmeans;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.7 670487 0.842 0.833
# bin=kmeans;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.7 116739 0.842 0.833
# bin=kmeans;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.7 26225 0.842 0.834
# bin=kmeans;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.7 777572 0.842 0.834
# bin=kmeans;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.7 288389 0.842 0.832
#
# bin=kmeans;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.8 670487 0.842 0.833
# bin=kmeans;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.8 116739 0.842 0.833
# bin=kmeans;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.8 26225 0.842 0.834
# bin=kmeans;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.8 777572 0.842 0.834
# bin=kmeans;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.8 288389 0.842 0.832
#
# bin=kmeans;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.9 670487 0.842 0.833
# bin=kmeans;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.9 116739 0.842 0.833
# bin=kmeans;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.9 26225 0.842 0.834
# bin=kmeans;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.9 777572 0.842 0.834
# bin=kmeans;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.9 288389 0.842 0.832
#
# bin=kmeans;pval=0.001;clust=Louvain;direction=BOTH;m=0 670487 0.74 0.835
# bin=kmeans;pval=0.001;clust=Louvain;direction=BOTH;m=0 116739 0.735 0.834
# bin=kmeans;pval=0.001;clust=Louvain;direction=BOTH;m=0 26225 0.744 0.831
# bin=kmeans;pval=0.001;clust=Louvain;direction=BOTH;m=0 777572 0.768 0.834
# bin=kmeans;pval=0.001;clust=Louvain;direction=BOTH;m=0 288389 0.744 0.833
#
# bin=kmeans;pval=0.001;clust=Louvain;direction=BOTH;m=0.3 670487 0.74 0.835
# bin=kmeans;pval=0.001;clust=Louvain;direction=BOTH;m=0.3 116739 0.735 0.834
# bin=kmeans;pval=0.001;clust=Louvain;direction=BOTH;m=0.3 26225 0.744 0.831
# bin=kmeans;pval=0.001;clust=Louvain;direction=BOTH;m=0.3 777572 0.768 0.834
# bin=kmeans;pval=0.001;clust=Louvain;direction=BOTH;m=0.3 288389 0.744 0.833
#
# bin=kmeans;pval=0.001;clust=Louvain;direction=BOTH;m=0.4 670487 0.74 0.835
# bin=kmeans;pval=0.001;clust=Louvain;direction=BOTH;m=0.4 116739 0.735 0.834
# bin=kmeans;pval=0.001;clust=Louvain;direction=BOTH;m=0.4 26225 0.744 0.831
# bin=kmeans;pval=0.001;clust=Louvain;direction=BOTH;m=0.4 777572 0.768 0.834
# bin=kmeans;pval=0.001;clust=Louvain;direction=BOTH;m=0.4 288389 0.744 0.833
#
# bin=kmeans;pval=0.001;clust=Louvain;direction=BOTH;m=0.5 670487 0.74 0.835
# bin=kmeans;pval=0.001;clust=Louvain;direction=BOTH;m=0.5 116739 0.735 0.834
# bin=kmeans;pval=0.001;clust=Louvain;direction=BOTH;m=0.5 26225 0.744 0.831
# bin=kmeans;pval=0.001;clust=Louvain;direction=BOTH;m=0.5 777572 0.768 0.834
# bin=kmeans;pval=0.001;clust=Louvain;direction=BOTH;m=0.5 288389 0.744 0.833
#
# bin=kmeans;pval=0.001;clust=Louvain;direction=BOTH;m=0.6 670487 0.74 0.835
# bin=kmeans;pval=0.001;clust=Louvain;direction=BOTH;m=0.6 116739 0.735 0.834
# bin=kmeans;pval=0.001;clust=Louvain;direction=BOTH;m=0.6 26225 0.744 0.831
# bin=kmeans;pval=0.001;clust=Louvain;direction=BOTH;m=0.6 777572 0.768 0.834
# bin=kmeans;pval=0.001;clust=Louvain;direction=BOTH;m=0.6 288389 0.744 0.833
#
# bin=kmeans;pval=0.001;clust=Louvain;direction=BOTH;m=0.7 670487 0.74 0.835
# bin=kmeans;pval=0.001;clust=Louvain;direction=BOTH;m=0.7 116739 0.735 0.834
# bin=kmeans;pval=0.001;clust=Louvain;direction=BOTH;m=0.7 26225 0.744 0.831
# bin=kmeans;pval=0.001;clust=Louvain;direction=BOTH;m=0.7 777572 0.768 0.834
# bin=kmeans;pval=0.001;clust=Louvain;direction=BOTH;m=0.7 288389 0.744 0.833
#
# bin=kmeans;pval=0.001;clust=Louvain;direction=BOTH;m=0.8 670487 0.74 0.835
# bin=kmeans;pval=0.001;clust=Louvain;direction=BOTH;m=0.8 116739 0.735 0.834
# bin=kmeans;pval=0.001;clust=Louvain;direction=BOTH;m=0.8 26225 0.744 0.831
# bin=kmeans;pval=0.001;clust=Louvain;direction=BOTH;m=0.8 777572 0.768 0.834
# bin=kmeans;pval=0.001;clust=Louvain;direction=BOTH;m=0.8 288389 0.744 0.833
#
# bin=kmeans;pval=0.001;clust=Louvain;direction=BOTH;m=0.9 670487 0.74 0.835
# bin=kmeans;pval=0.001;clust=Louvain;direction=BOTH;m=0.9 116739 0.735 0.834
# bin=kmeans;pval=0.001;clust=Louvain;direction=BOTH;m=0.9 26225 0.744 0.831
# bin=kmeans;pval=0.001;clust=Louvain;direction=BOTH;m=0.9 777572 0.768 0.834
# bin=kmeans;pval=0.001;clust=Louvain;direction=BOTH;m=0.9 288389 0.744 0.833
#
# bin=GMM;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0 670487 0.82 0.835
# bin=GMM;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0 116739 0.819 0.831
# bin=GMM;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0 26225 0.815 0.831
# bin=GMM;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0 777572 0.819 0.834
# bin=GMM;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0 288389 0.818 0.834
#
# bin=GMM;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.3 670487 0.82 0.835
# bin=GMM;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.3 116739 0.819 0.831
# bin=GMM;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.3 26225 0.815 0.831
# bin=GMM;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.3 777572 0.819 0.834
# bin=GMM;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.3 288389 0.818 0.834
#
# bin=GMM;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.4 670487 0.82 0.835
# bin=GMM;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.4 116739 0.819 0.831
# bin=GMM;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.4 26225 0.815 0.831
# bin=GMM;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.4 777572 0.819 0.834
# bin=GMM;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.4 288389 0.818 0.834
#
# bin=GMM;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.5 670487 0.82 0.835
# bin=GMM;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.5 116739 0.819 0.831
# bin=GMM;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.5 26225 0.815 0.831
# bin=GMM;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.5 777572 0.819 0.834
# bin=GMM;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.5 288389 0.818 0.834
#
# bin=GMM;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.6 670487 0.82 0.835
# bin=GMM;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.6 116739 0.819 0.831
# bin=GMM;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.6 26225 0.815 0.831
# bin=GMM;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.6 777572 0.819 0.834
# bin=GMM;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.6 288389 0.818 0.834
#
# bin=GMM;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.7 670487 0.82 0.835
# bin=GMM;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.7 116739 0.819 0.831
# bin=GMM;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.7 26225 0.815 0.831
# bin=GMM;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.7 777572 0.819 0.834
# bin=GMM;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.7 288389 0.818 0.834
#
# bin=GMM;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.8 670487 0.82 0.835
# bin=GMM;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.8 116739 0.819 0.831
# bin=GMM;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.8 26225 0.815 0.831
# bin=GMM;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.8 777572 0.819 0.834
# bin=GMM;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.8 288389 0.818 0.834
#
# bin=GMM;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.9 670487 0.82 0.835
# bin=GMM;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.9 116739 0.819 0.831
# bin=GMM;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.9 26225 0.815 0.831
# bin=GMM;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.9 777572 0.819 0.834
# bin=GMM;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.9 288389 0.818 0.834
#
# bin=GMM;pval=0.001;clust=Louvain;direction=BOTH;m=0 670487 0.718 0.836
# bin=GMM;pval=0.001;clust=Louvain;direction=BOTH;m=0 116739 0.718 0.836
# bin=GMM;pval=0.001;clust=Louvain;direction=BOTH;m=0 26225 0.698 0.837
# bin=GMM;pval=0.001;clust=Louvain;direction=BOTH;m=0 777572 0.718 0.837
# bin=GMM;pval=0.001;clust=Louvain;direction=BOTH;m=0 288389 0.721 0.837
#
# bin=GMM;pval=0.001;clust=Louvain;direction=BOTH;m=0.3 670487 0.718 0.836
# bin=GMM;pval=0.001;clust=Louvain;direction=BOTH;m=0.3 116739 0.718 0.836
# bin=GMM;pval=0.001;clust=Louvain;direction=BOTH;m=0.3 26225 0.698 0.837
# bin=GMM;pval=0.001;clust=Louvain;direction=BOTH;m=0.3 777572 0.718 0.837
# bin=GMM;pval=0.001;clust=Louvain;direction=BOTH;m=0.3 288389 0.721 0.837
#
# bin=GMM;pval=0.001;clust=Louvain;direction=BOTH;m=0.4 670487 0.718 0.836
# bin=GMM;pval=0.001;clust=Louvain;direction=BOTH;m=0.4 116739 0.718 0.836
# bin=GMM;pval=0.001;clust=Louvain;direction=BOTH;m=0.4 26225 0.698 0.837
# bin=GMM;pval=0.001;clust=Louvain;direction=BOTH;m=0.4 777572 0.718 0.837
# bin=GMM;pval=0.001;clust=Louvain;direction=BOTH;m=0.4 288389 0.721 0.837
#
# bin=GMM;pval=0.001;clust=Louvain;direction=BOTH;m=0.5 670487 0.718 0.836
# bin=GMM;pval=0.001;clust=Louvain;direction=BOTH;m=0.5 116739 0.718 0.836
# bin=GMM;pval=0.001;clust=Louvain;direction=BOTH;m=0.5 26225 0.698 0.837
# bin=GMM;pval=0.001;clust=Louvain;direction=BOTH;m=0.5 777572 0.718 0.837
# bin=GMM;pval=0.001;clust=Louvain;direction=BOTH;m=0.5 288389 0.721 0.837
#
# bin=GMM;pval=0.001;clust=Louvain;direction=BOTH;m=0.6 670487 0.718 0.836
# bin=GMM;pval=0.001;clust=Louvain;direction=BOTH;m=0.6 116739 0.718 0.836
# bin=GMM;pval=0.001;clust=Louvain;direction=BOTH;m=0.6 26225 0.698 0.837
# bin=GMM;pval=0.001;clust=Louvain;direction=BOTH;m=0.6 777572 0.718 0.837
# bin=GMM;pval=0.001;clust=Louvain;direction=BOTH;m=0.6 288389 0.721 0.837
#
# bin=GMM;pval=0.001;clust=Louvain;direction=BOTH;m=0.7 670487 0.718 0.836
# bin=GMM;pval=0.001;clust=Louvain;direction=BOTH;m=0.7 116739 0.718 0.836
# bin=GMM;pval=0.001;clust=Louvain;direction=BOTH;m=0.7 26225 0.698 0.837
# bin=GMM;pval=0.001;clust=Louvain;direction=BOTH;m=0.7 777572 0.718 0.837
# bin=GMM;pval=0.001;clust=Louvain;direction=BOTH;m=0.7 288389 0.721 0.837
#
# bin=GMM;pval=0.001;clust=Louvain;direction=BOTH;m=0.8 670487 0.718 0.836
# bin=GMM;pval=0.001;clust=Louvain;direction=BOTH;m=0.8 116739 0.718 0.836
# bin=GMM;pval=0.001;clust=Louvain;direction=BOTH;m=0.8 26225 0.698 0.837
# bin=GMM;pval=0.001;clust=Louvain;direction=BOTH;m=0.8 777572 0.718 0.837
# bin=GMM;pval=0.001;clust=Louvain;direction=BOTH;m=0.8 288389 0.721 0.837
#
# bin=GMM;pval=0.001;clust=Louvain;direction=BOTH;m=0.9 670487 0.718 0.836
# bin=GMM;pval=0.001;clust=Louvain;direction=BOTH;m=0.9 116739 0.718 0.836
# bin=GMM;pval=0.001;clust=Louvain;direction=BOTH;m=0.9 26225 0.698 0.837
# bin=GMM;pval=0.001;clust=Louvain;direction=BOTH;m=0.9 777572 0.718 0.837
# bin=GMM;pval=0.001;clust=Louvain;direction=BOTH;m=0.9 288389 0.721 0.837
#
# bin=ward;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0 670487 0.712 0.828
# bin=ward;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0 116739 0.712 0.829
# bin=ward;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0 26225 0.742 0.829
# bin=ward;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0 777572 0.712 0.83
# bin=ward;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0 288389 0.713 0.829
#
# bin=ward;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.3 670487 0.712 0.828
# bin=ward;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.3 116739 0.712 0.829
# bin=ward;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.3 26225 0.742 0.829
# bin=ward;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.3 777572 0.712 0.83
# bin=ward;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.3 288389 0.713 0.829
#
# bin=ward;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.4 670487 0.712 0.828
# bin=ward;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.4 116739 0.712 0.829
# bin=ward;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.4 26225 0.742 0.829
# bin=ward;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.4 777572 0.712 0.83
# bin=ward;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.4 288389 0.713 0.829
#
# bin=ward;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.5 670487 0.712 0.828
# bin=ward;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.5 116739 0.712 0.829
# bin=ward;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.5 26225 0.742 0.829
# bin=ward;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.5 777572 0.712 0.83
# bin=ward;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.5 288389 0.713 0.829
#
# bin=ward;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.6 670487 0.712 0.828
# bin=ward;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.6 116739 0.712 0.829
# bin=ward;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.6 26225 0.742 0.829
# bin=ward;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.6 777572 0.712 0.83
# bin=ward;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.6 288389 0.713 0.829
#
# bin=ward;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.7 670487 0.712 0.828
# bin=ward;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.7 116739 0.712 0.829
# bin=ward;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.7 26225 0.742 0.829
# bin=ward;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.7 777572 0.712 0.83
# bin=ward;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.7 288389 0.713 0.829
#
# bin=ward;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.8 670487 0.712 0.828
# bin=ward;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.8 116739 0.712 0.829
# bin=ward;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.8 26225 0.742 0.829
# bin=ward;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.8 777572 0.712 0.83
# bin=ward;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.8 288389 0.713 0.829
#
# bin=ward;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.9 670487 0.712 0.828
# bin=ward;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.9 116739 0.712 0.829
# bin=ward;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.9 26225 0.742 0.829
# bin=ward;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.9 777572 0.712 0.83
# bin=ward;pval=0.001;clust=Louvain;direction=UP-DOWN;m=0.9 288389 0.713 0.829
#
# bin=ward;pval=0.001;clust=Louvain;direction=BOTH;m=0 670487 0.734 0.827
# bin=ward;pval=0.001;clust=Louvain;direction=BOTH;m=0 116739 0.734 0.827
# bin=ward;pval=0.001;clust=Louvain;direction=BOTH;m=0 26225 0.734 0.827
# bin=ward;pval=0.001;clust=Louvain;direction=BOTH;m=0 777572 0.734 0.827
# bin=ward;pval=0.001;clust=Louvain;direction=BOTH;m=0 288389 0.735 0.827
#
# bin=ward;pval=0.001;clust=Louvain;direction=BOTH;m=0.3 670487 0.734 0.827
# bin=ward;pval=0.001;clust=Louvain;direction=BOTH;m=0.3 116739 0.734 0.827
# bin=ward;pval=0.001;clust=Louvain;direction=BOTH;m=0.3 26225 0.734 0.827
# bin=ward;pval=0.001;clust=Louvain;direction=BOTH;m=0.3 777572 0.734 0.827
# bin=ward;pval=0.001;clust=Louvain;direction=BOTH;m=0.3 288389 0.735 0.827
#
# bin=ward;pval=0.001;clust=Louvain;direction=BOTH;m=0.4 670487 0.734 0.827
# bin=ward;pval=0.001;clust=Louvain;direction=BOTH;m=0.4 116739 0.734 0.827
# bin=ward;pval=0.001;clust=Louvain;direction=BOTH;m=0.4 26225 0.734 0.827
# bin=ward;pval=0.001;clust=Louvain;direction=BOTH;m=0.4 777572 0.734 0.827
# bin=ward;pval=0.001;clust=Louvain;direction=BOTH;m=0.4 288389 0.735 0.827
#
# bin=ward;pval=0.001;clust=Louvain;direction=BOTH;m=0.5 670487 0.734 0.827
# bin=ward;pval=0.001;clust=Louvain;direction=BOTH;m=0.5 116739 0.734 0.827
# bin=ward;pval=0.001;clust=Louvain;direction=BOTH;m=0.5 26225 0.734 0.827
# bin=ward;pval=0.001;clust=Louvain;direction=BOTH;m=0.5 777572 0.734 0.827
# bin=ward;pval=0.001;clust=Louvain;direction=BOTH;m=0.5 288389 0.735 0.827
#
# bin=ward;pval=0.001;clust=Louvain;direction=BOTH;m=0.6 670487 0.734 0.827
# bin=ward;pval=0.001;clust=Louvain;direction=BOTH;m=0.6 116739 0.734 0.827
# bin=ward;pval=0.001;clust=Louvain;direction=BOTH;m=0.6 26225 0.734 0.827
# bin=ward;pval=0.001;clust=Louvain;direction=BOTH;m=0.6 777572 0.734 0.827
# bin=ward;pval=0.001;clust=Louvain;direction=BOTH;m=0.6 288389 0.735 0.827
#
# bin=ward;pval=0.001;clust=Louvain;direction=BOTH;m=0.7 670487 0.734 0.827
# bin=ward;pval=0.001;clust=Louvain;direction=BOTH;m=0.7 116739 0.734 0.827
# bin=ward;pval=0.001;clust=Louvain;direction=BOTH;m=0.7 26225 0.734 0.827
# bin=ward;pval=0.001;clust=Louvain;direction=BOTH;m=0.7 777572 0.734 0.827
# bin=ward;pval=0.001;clust=Louvain;direction=BOTH;m=0.7 288389 0.735 0.827
#
# bin=ward;pval=0.001;clust=Louvain;direction=BOTH;m=0.8 670487 0.734 0.827
# bin=ward;pval=0.001;clust=Louvain;direction=BOTH;m=0.8 116739 0.734 0.827
# bin=ward;pval=0.001;clust=Louvain;direction=BOTH;m=0.8 26225 0.734 0.827
# bin=ward;pval=0.001;clust=Louvain;direction=BOTH;m=0.8 777572 0.734 0.827
# bin=ward;pval=0.001;clust=Louvain;direction=BOTH;m=0.8 288389 0.735 0.827
#
# bin=ward;pval=0.001;clust=Louvain;direction=BOTH;m=0.9 670487 0.734 0.827
# bin=ward;pval=0.001;clust=Louvain;direction=BOTH;m=0.9 116739 0.734 0.827
# bin=ward;pval=0.001;clust=Louvain;direction=BOTH;m=0.9 26225 0.734 0.827
# bin=ward;pval=0.001;clust=Louvain;direction=BOTH;m=0.9 777572 0.734 0.827
# bin=ward;pval=0.001;clust=Louvain;direction=BOTH;m=0.9 288389 0.735 0.827
#
# bin=kmeans;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0 670487 0.841 0.835
# bin=kmeans;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0 116739 0.841 0.834
# bin=kmeans;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0 26225 0.744 0.834
# bin=kmeans;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0 777572 0.841 0.834
# bin=kmeans;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0 288389 0.746 0.835
#
# bin=kmeans;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.3 670487 0.841 0.835
# bin=kmeans;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.3 116739 0.841 0.834
# bin=kmeans;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.3 26225 0.744 0.834
# bin=kmeans;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.3 777572 0.841 0.834
# bin=kmeans;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.3 288389 0.746 0.835
#
# bin=kmeans;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.4 670487 0.841 0.835
# bin=kmeans;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.4 116739 0.841 0.834
# bin=kmeans;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.4 26225 0.744 0.834
# bin=kmeans;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.4 777572 0.841 0.834
# bin=kmeans;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.4 288389 0.746 0.835
#
# bin=kmeans;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.5 670487 0.841 0.835
# bin=kmeans;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.5 116739 0.841 0.834
# bin=kmeans;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.5 26225 0.744 0.834
# bin=kmeans;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.5 777572 0.841 0.834
# bin=kmeans;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.5 288389 0.746 0.835
#
# bin=kmeans;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.6 670487 0.841 0.835
# bin=kmeans;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.6 116739 0.841 0.834
# bin=kmeans;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.6 26225 0.744 0.834
# bin=kmeans;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.6 777572 0.841 0.834
# bin=kmeans;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.6 288389 0.746 0.835
#
# bin=kmeans;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.7 670487 0.841 0.835
# bin=kmeans;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.7 116739 0.841 0.834
# bin=kmeans;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.7 26225 0.744 0.834
# bin=kmeans;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.7 777572 0.841 0.834
# bin=kmeans;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.7 288389 0.746 0.835
#
# bin=kmeans;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.8 670487 0.841 0.835
# bin=kmeans;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.8 116739 0.841 0.834
# bin=kmeans;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.8 26225 0.744 0.834
# bin=kmeans;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.8 777572 0.841 0.834
# bin=kmeans;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.8 288389 0.746 0.835
#
# bin=kmeans;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.9 670487 0.841 0.835
# bin=kmeans;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.9 116739 0.841 0.834
# bin=kmeans;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.9 26225 0.744 0.834
# bin=kmeans;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.9 777572 0.841 0.834
# bin=kmeans;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.9 288389 0.746 0.835
#
# bin=kmeans;pval=0.05;clust=Louvain;direction=BOTH;m=0 670487 0.744 0.835
# bin=kmeans;pval=0.05;clust=Louvain;direction=BOTH;m=0 116739 0.744 0.834
# bin=kmeans;pval=0.05;clust=Louvain;direction=BOTH;m=0 26225 0.742 0.834
# bin=kmeans;pval=0.05;clust=Louvain;direction=BOTH;m=0 777572 0.766 0.834
# bin=kmeans;pval=0.05;clust=Louvain;direction=BOTH;m=0 288389 0.743 0.835
#
# bin=kmeans;pval=0.05;clust=Louvain;direction=BOTH;m=0.3 670487 0.744 0.835
# bin=kmeans;pval=0.05;clust=Louvain;direction=BOTH;m=0.3 116739 0.744 0.834
# bin=kmeans;pval=0.05;clust=Louvain;direction=BOTH;m=0.3 26225 0.742 0.834
# bin=kmeans;pval=0.05;clust=Louvain;direction=BOTH;m=0.3 777572 0.766 0.834
# bin=kmeans;pval=0.05;clust=Louvain;direction=BOTH;m=0.3 288389 0.743 0.835
#
# bin=kmeans;pval=0.05;clust=Louvain;direction=BOTH;m=0.4 670487 0.744 0.835
# bin=kmeans;pval=0.05;clust=Louvain;direction=BOTH;m=0.4 116739 0.744 0.834
# bin=kmeans;pval=0.05;clust=Louvain;direction=BOTH;m=0.4 26225 0.742 0.834
# bin=kmeans;pval=0.05;clust=Louvain;direction=BOTH;m=0.4 777572 0.766 0.834
# bin=kmeans;pval=0.05;clust=Louvain;direction=BOTH;m=0.4 288389 0.743 0.835
#
# bin=kmeans;pval=0.05;clust=Louvain;direction=BOTH;m=0.5 670487 0.744 0.835
# bin=kmeans;pval=0.05;clust=Louvain;direction=BOTH;m=0.5 116739 0.744 0.834
# bin=kmeans;pval=0.05;clust=Louvain;direction=BOTH;m=0.5 26225 0.742 0.834
# bin=kmeans;pval=0.05;clust=Louvain;direction=BOTH;m=0.5 777572 0.766 0.834
# bin=kmeans;pval=0.05;clust=Louvain;direction=BOTH;m=0.5 288389 0.743 0.835
#
# bin=kmeans;pval=0.05;clust=Louvain;direction=BOTH;m=0.6 670487 0.744 0.835
# bin=kmeans;pval=0.05;clust=Louvain;direction=BOTH;m=0.6 116739 0.744 0.834
# bin=kmeans;pval=0.05;clust=Louvain;direction=BOTH;m=0.6 26225 0.742 0.834
# bin=kmeans;pval=0.05;clust=Louvain;direction=BOTH;m=0.6 777572 0.766 0.834
# bin=kmeans;pval=0.05;clust=Louvain;direction=BOTH;m=0.6 288389 0.743 0.835
#
# bin=kmeans;pval=0.05;clust=Louvain;direction=BOTH;m=0.7 670487 0.744 0.835
# bin=kmeans;pval=0.05;clust=Louvain;direction=BOTH;m=0.7 116739 0.744 0.834
# bin=kmeans;pval=0.05;clust=Louvain;direction=BOTH;m=0.7 26225 0.742 0.834
# bin=kmeans;pval=0.05;clust=Louvain;direction=BOTH;m=0.7 777572 0.766 0.834
# bin=kmeans;pval=0.05;clust=Louvain;direction=BOTH;m=0.7 288389 0.743 0.835
# bin=kmeans;pval=0.05;clust=Louvain;direction=BOTH;m=0.8 670487 0.744 0.835
# bin=kmeans;pval=0.05;clust=Louvain;direction=BOTH;m=0.8 116739 0.744 0.834
# bin=kmeans;pval=0.05;clust=Louvain;direction=BOTH;m=0.8 26225 0.742 0.834
# bin=kmeans;pval=0.05;clust=Louvain;direction=BOTH;m=0.8 777572 0.766 0.834
# bin=kmeans;pval=0.05;clust=Louvain;direction=BOTH;m=0.8 288389 0.743 0.835
#
# bin=kmeans;pval=0.05;clust=Louvain;direction=BOTH;m=0.9 670487 0.744 0.835
# bin=kmeans;pval=0.05;clust=Louvain;direction=BOTH;m=0.9 116739 0.744 0.834
# bin=kmeans;pval=0.05;clust=Louvain;direction=BOTH;m=0.9 26225 0.742 0.834
# bin=kmeans;pval=0.05;clust=Louvain;direction=BOTH;m=0.9 777572 0.766 0.834
# bin=kmeans;pval=0.05;clust=Louvain;direction=BOTH;m=0.9 288389 0.743 0.835
#
# bin=GMM;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0 670487 0.808 0.831
# bin=GMM;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0 116739 0.821 0.833
# bin=GMM;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0 26225 0.818 0.832
# bin=GMM;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0 777572 0.805 0.832
# bin=GMM;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0 288389 0.818 0.831
#
# bin=GMM;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.3 670487 0.808 0.831
# bin=GMM;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.3 116739 0.821 0.833
# bin=GMM;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.3 26225 0.818 0.832
# bin=GMM;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.3 777572 0.805 0.832
# bin=GMM;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.3 288389 0.818 0.831
#
# bin=GMM;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.4 670487 0.808 0.831
# bin=GMM;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.4 116739 0.821 0.833
# bin=GMM;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.4 26225 0.818 0.832
# bin=GMM;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.4 777572 0.805 0.832
# bin=GMM;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.4 288389 0.818 0.831
#
# bin=GMM;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.5 670487 0.808 0.831
# bin=GMM;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.5 116739 0.821 0.833
# bin=GMM;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.5 26225 0.818 0.832
# bin=GMM;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.5 777572 0.805 0.832
# bin=GMM;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.5 288389 0.818 0.831
#
# bin=GMM;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.6 670487 0.808 0.831
# bin=GMM;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.6 116739 0.821 0.833
# bin=GMM;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.6 26225 0.818 0.832
# bin=GMM;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.6 777572 0.805 0.832
# bin=GMM;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.6 288389 0.818 0.831
#
# bin=GMM;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.7 670487 0.808 0.831
# bin=GMM;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.7 116739 0.821 0.833
# bin=GMM;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.7 26225 0.818 0.832
# bin=GMM;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.7 777572 0.805 0.832
# bin=GMM;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.7 288389 0.818 0.831
#
# bin=GMM;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.8 670487 0.808 0.831
# bin=GMM;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.8 116739 0.821 0.833
# bin=GMM;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.8 26225 0.818 0.832
# bin=GMM;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.8 777572 0.805 0.832
# bin=GMM;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.8 288389 0.818 0.831
#
# bin=GMM;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.9 670487 0.808 0.831
# bin=GMM;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.9 116739 0.821 0.833
# bin=GMM;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.9 26225 0.818 0.832
# bin=GMM;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.9 777572 0.805 0.832
# bin=GMM;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0.9 288389 0.818 0.831
#
# bin=GMM;pval=0.05;clust=Louvain;direction=BOTH;m=0 670487 0.722 0.831
# bin=GMM;pval=0.05;clust=Louvain;direction=BOTH;m=0 116739 0.742 0.836
# bin=GMM;pval=0.05;clust=Louvain;direction=BOTH;m=0 26225 0.723 0.837
# bin=GMM;pval=0.05;clust=Louvain;direction=BOTH;m=0 777572 0.726 0.837
# bin=GMM;pval=0.05;clust=Louvain;direction=BOTH;m=0 288389 0.737 0.837
#
# bin=GMM;pval=0.05;clust=Louvain;direction=BOTH;m=0.3 670487 0.722 0.831
# bin=GMM;pval=0.05;clust=Louvain;direction=BOTH;m=0.3 116739 0.742 0.836
# bin=GMM;pval=0.05;clust=Louvain;direction=BOTH;m=0.3 26225 0.723 0.837
# bin=GMM;pval=0.05;clust=Louvain;direction=BOTH;m=0.3 777572 0.726 0.837
# bin=GMM;pval=0.05;clust=Louvain;direction=BOTH;m=0.3 288389 0.737 0.837
#
# bin=GMM;pval=0.05;clust=Louvain;direction=BOTH;m=0.4 670487 0.722 0.831
# bin=GMM;pval=0.05;clust=Louvain;direction=BOTH;m=0.4 116739 0.742 0.836
# bin=GMM;pval=0.05;clust=Louvain;direction=BOTH;m=0.4 26225 0.723 0.837
# bin=GMM;pval=0.05;clust=Louvain;direction=BOTH;m=0.4 777572 0.726 0.837
# bin=GMM;pval=0.05;clust=Louvain;direction=BOTH;m=0.4 288389 0.737 0.837
#
# bin=GMM;pval=0.05;clust=Louvain;direction=BOTH;m=0.5 670487 0.722 0.831
# bin=GMM;pval=0.05;clust=Louvain;direction=BOTH;m=0.5 116739 0.742 0.836
# bin=GMM;pval=0.05;clust=Louvain;direction=BOTH;m=0.5 26225 0.723 0.837
# bin=GMM;pval=0.05;clust=Louvain;direction=BOTH;m=0.5 777572 0.726 0.837
# bin=GMM;pval=0.05;clust=Louvain;direction=BOTH;m=0.5 288389 0.737 0.837
#
# bin=GMM;pval=0.05;clust=Louvain;direction=BOTH;m=0.6 670487 0.722 0.831
# bin=GMM;pval=0.05;clust=Louvain;direction=BOTH;m=0.6 116739 0.742 0.836
# bin=GMM;pval=0.05;clust=Louvain;direction=BOTH;m=0.6 26225 0.723 0.837
# bin=GMM;pval=0.05;clust=Louvain;direction=BOTH;m=0.6 777572 0.726 0.837
# bin=GMM;pval=0.05;clust=Louvain;direction=BOTH;m=0.6 288389 0.737 0.837
#
# bin=GMM;pval=0.05;clust=Louvain;direction=BOTH;m=0.7 670487 0.722 0.831
# bin=GMM;pval=0.05;clust=Louvain;direction=BOTH;m=0.7 116739 0.742 0.836
# bin=GMM;pval=0.05;clust=Louvain;direction=BOTH;m=0.7 26225 0.723 0.837
# bin=GMM;pval=0.05;clust=Louvain;direction=BOTH;m=0.7 777572 0.726 0.837
# bin=GMM;pval=0.05;clust=Louvain;direction=BOTH;m=0.7 288389 0.737 0.837
#
# bin=GMM;pval=0.05;clust=Louvain;direction=BOTH;m=0.8 670487 0.722 0.831
# bin=GMM;pval=0.05;clust=Louvain;direction=BOTH;m=0.8 116739 0.742 0.836
# bin=GMM;pval=0.05;clust=Louvain;direction=BOTH;m=0.8 26225 0.723 0.837
# bin=GMM;pval=0.05;clust=Louvain;direction=BOTH;m=0.8 777572 0.726 0.837
# bin=GMM;pval=0.05;clust=Louvain;direction=BOTH;m=0.8 288389 0.737 0.837
#
# bin=GMM;pval=0.05;clust=Louvain;direction=BOTH;m=0.9 670487 0.722 0.831
# bin=GMM;pval=0.05;clust=Louvain;direction=BOTH;m=0.9 116739 0.742 0.836
# bin=GMM;pval=0.05;clust=Louvain;direction=BOTH;m=0.9 26225 0.723 0.837
# bin=GMM;pval=0.05;clust=Louvain;direction=BOTH;m=0.9 777572 0.726 0.837
# bin=GMM;pval=0.05;clust=Louvain;direction=BOTH;m=0.9 288389 0.737 0.837
#
# bin=ward;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0 670487 0.806 0.806
# bin=ward;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0 116739 0.81 0.806
# bin=ward;pval=0.05;clust=Louvain;direction=UP-DOWN;m=0 26225 0.81 0.806
# ...
# bin=kmeans;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.7 777572 0.842 0.834
# bin=kmeans;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.7 288389 0.842 0.835
#
# bin=kmeans;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.8 670487 0.842 0.835
# bin=kmeans;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.8 116739 0.841 0.835
# bin=kmeans;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.8 26225 0.841 0.834
# bin=kmeans;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.8 777572 0.842 0.834
# bin=kmeans;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.8 288389 0.842 0.835
#
# bin=kmeans;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.9 670487 0.842 0.835
# bin=kmeans;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.9 116739 0.841 0.835
# bin=kmeans;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.9 26225 0.841 0.834
# bin=kmeans;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.9 777572 0.842 0.834
# bin=kmeans;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.9 288389 0.842 0.835
#
# bin=kmeans;pval=0.005;clust=Louvain;direction=BOTH;m=0 670487 0.747 0.833
# bin=kmeans;pval=0.005;clust=Louvain;direction=BOTH;m=0 116739 0.736 0.831
# bin=kmeans;pval=0.005;clust=Louvain;direction=BOTH;m=0 26225 0.736 0.831
# bin=kmeans;pval=0.005;clust=Louvain;direction=BOTH;m=0 777572 0.745 0.832
# bin=kmeans;pval=0.005;clust=Louvain;direction=BOTH;m=0 288389 0.736 0.833
#
# bin=kmeans;pval=0.005;clust=Louvain;direction=BOTH;m=0.3 670487 0.747 0.833
# bin=kmeans;pval=0.005;clust=Louvain;direction=BOTH;m=0.3 116739 0.736 0.831
# bin=kmeans;pval=0.005;clust=Louvain;direction=BOTH;m=0.3 26225 0.736 0.831
# bin=kmeans;pval=0.005;clust=Louvain;direction=BOTH;m=0.3 777572 0.745 0.832
# bin=kmeans;pval=0.005;clust=Louvain;direction=BOTH;m=0.3 288389 0.736 0.833
#
# bin=kmeans;pval=0.005;clust=Louvain;direction=BOTH;m=0.4 670487 0.747 0.833
# bin=kmeans;pval=0.005;clust=Louvain;direction=BOTH;m=0.4 116739 0.736 0.831
# bin=kmeans;pval=0.005;clust=Louvain;direction=BOTH;m=0.4 26225 0.736 0.831
# bin=kmeans;pval=0.005;clust=Louvain;direction=BOTH;m=0.4 777572 0.745 0.832
# bin=kmeans;pval=0.005;clust=Louvain;direction=BOTH;m=0.4 288389 0.736 0.833
#
# bin=kmeans;pval=0.005;clust=Louvain;direction=BOTH;m=0.5 670487 0.747 0.833
# bin=kmeans;pval=0.005;clust=Louvain;direction=BOTH;m=0.5 116739 0.736 0.831
# bin=kmeans;pval=0.005;clust=Louvain;direction=BOTH;m=0.5 26225 0.736 0.831
# bin=kmeans;pval=0.005;clust=Louvain;direction=BOTH;m=0.5 777572 0.745 0.832
# bin=kmeans;pval=0.005;clust=Louvain;direction=BOTH;m=0.5 288389 0.736 0.833
#
# bin=kmeans;pval=0.005;clust=Louvain;direction=BOTH;m=0.6 670487 0.747 0.833
# bin=kmeans;pval=0.005;clust=Louvain;direction=BOTH;m=0.6 116739 0.736 0.831
# bin=kmeans;pval=0.005;clust=Louvain;direction=BOTH;m=0.6 26225 0.736 0.831
# bin=kmeans;pval=0.005;clust=Louvain;direction=BOTH;m=0.6 777572 0.745 0.832
# bin=kmeans;pval=0.005;clust=Louvain;direction=BOTH;m=0.6 288389 0.736 0.833
#
# bin=kmeans;pval=0.005;clust=Louvain;direction=BOTH;m=0.7 670487 0.747 0.833
# bin=kmeans;pval=0.005;clust=Louvain;direction=BOTH;m=0.7 116739 0.736 0.831
# bin=kmeans;pval=0.005;clust=Louvain;direction=BOTH;m=0.7 26225 0.736 0.831
# bin=kmeans;pval=0.005;clust=Louvain;direction=BOTH;m=0.7 777572 0.745 0.832
# bin=kmeans;pval=0.005;clust=Louvain;direction=BOTH;m=0.7 288389 0.736 0.833
#
# bin=kmeans;pval=0.005;clust=Louvain;direction=BOTH;m=0.8 670487 0.747 0.833
# bin=kmeans;pval=0.005;clust=Louvain;direction=BOTH;m=0.8 116739 0.736 0.831
# bin=kmeans;pval=0.005;clust=Louvain;direction=BOTH;m=0.8 26225 0.736 0.831
# bin=kmeans;pval=0.005;clust=Louvain;direction=BOTH;m=0.8 777572 0.745 0.832
# bin=kmeans;pval=0.005;clust=Louvain;direction=BOTH;m=0.8 288389 0.736 0.833
#
# bin=kmeans;pval=0.005;clust=Louvain;direction=BOTH;m=0.9 670487 0.747 0.833
# bin=kmeans;pval=0.005;clust=Louvain;direction=BOTH;m=0.9 116739 0.736 0.831
# bin=kmeans;pval=0.005;clust=Louvain;direction=BOTH;m=0.9 26225 0.736 0.831
# bin=kmeans;pval=0.005;clust=Louvain;direction=BOTH;m=0.9 777572 0.745 0.832
# bin=kmeans;pval=0.005;clust=Louvain;direction=BOTH;m=0.9 288389 0.736 0.833
#
# bin=GMM;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0 670487 0.821 0.835
# bin=GMM;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0 116739 0.813 0.834
# bin=GMM;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0 26225 0.815 0.835
# bin=GMM;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0 777572 0.816 0.835
# bin=GMM;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0 288389 0.818 0.834
#
# bin=GMM;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.3 670487 0.821 0.835
# bin=GMM;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.3 116739 0.813 0.834
# bin=GMM;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.3 26225 0.815 0.835
# bin=GMM;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.3 777572 0.816 0.835
# bin=GMM;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.3 288389 0.818 0.834
#
# bin=GMM;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.4 670487 0.821 0.835
# bin=GMM;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.4 116739 0.813 0.834
# bin=GMM;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.4 26225 0.815 0.835
# bin=GMM;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.4 777572 0.816 0.835
# bin=GMM;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.4 288389 0.818 0.834
#
# bin=GMM;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.5 670487 0.821 0.835
# bin=GMM;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.5 116739 0.813 0.834
# bin=GMM;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.5 26225 0.815 0.835
# bin=GMM;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.5 777572 0.816 0.835
# bin=GMM;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.5 288389 0.818 0.834
#
# bin=GMM;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.6 670487 0.821 0.835
# bin=GMM;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.6 116739 0.813 0.834
# bin=GMM;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.6 26225 0.815 0.835
# bin=GMM;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.6 777572 0.816 0.835
# bin=GMM;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.6 288389 0.818 0.834
#
# bin=GMM;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.7 670487 0.821 0.835
# bin=GMM;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.7 116739 0.813 0.834
# bin=GMM;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.7 26225 0.815 0.835
# bin=GMM;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.7 777572 0.816 0.835
# bin=GMM;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.7 288389 0.818 0.834
#
# bin=GMM;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.8 670487 0.821 0.835
# bin=GMM;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.8 116739 0.813 0.834
# bin=GMM;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.8 26225 0.815 0.835
# bin=GMM;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.8 777572 0.816 0.835
# bin=GMM;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.8 288389 0.818 0.834
#
# bin=GMM;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.9 670487 0.821 0.835
# bin=GMM;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.9 116739 0.813 0.834
# bin=GMM;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.9 26225 0.815 0.835
# bin=GMM;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.9 777572 0.816 0.835
# bin=GMM;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.9 288389 0.818 0.834
#
# bin=GMM;pval=0.005;clust=Louvain;direction=BOTH;m=0 670487 0.703 0.836
# bin=GMM;pval=0.005;clust=Louvain;direction=BOTH;m=0 116739 0.702 0.836
# bin=GMM;pval=0.005;clust=Louvain;direction=BOTH;m=0 26225 0.698 0.837
# bin=GMM;pval=0.005;clust=Louvain;direction=BOTH;m=0 777572 0.724 0.837
# bin=GMM;pval=0.005;clust=Louvain;direction=BOTH;m=0 288389 0.722 0.837
#
# bin=GMM;pval=0.005;clust=Louvain;direction=BOTH;m=0.3 670487 0.703 0.836
# bin=GMM;pval=0.005;clust=Louvain;direction=BOTH;m=0.3 116739 0.702 0.836
# bin=GMM;pval=0.005;clust=Louvain;direction=BOTH;m=0.3 26225 0.698 0.837
# bin=GMM;pval=0.005;clust=Louvain;direction=BOTH;m=0.3 777572 0.724 0.837
# bin=GMM;pval=0.005;clust=Louvain;direction=BOTH;m=0.3 288389 0.722 0.837
#
# bin=GMM;pval=0.005;clust=Louvain;direction=BOTH;m=0.4 670487 0.703 0.836
# bin=GMM;pval=0.005;clust=Louvain;direction=BOTH;m=0.4 116739 0.702 0.836
# bin=GMM;pval=0.005;clust=Louvain;direction=BOTH;m=0.4 26225 0.698 0.837
# bin=GMM;pval=0.005;clust=Louvain;direction=BOTH;m=0.4 777572 0.724 0.837
# bin=GMM;pval=0.005;clust=Louvain;direction=BOTH;m=0.4 288389 0.722 0.837
#
# bin=GMM;pval=0.005;clust=Louvain;direction=BOTH;m=0.5 670487 0.703 0.836
# bin=GMM;pval=0.005;clust=Louvain;direction=BOTH;m=0.5 116739 0.702 0.836
# bin=GMM;pval=0.005;clust=Louvain;direction=BOTH;m=0.5 26225 0.698 0.837
# bin=GMM;pval=0.005;clust=Louvain;direction=BOTH;m=0.5 777572 0.724 0.837
# bin=GMM;pval=0.005;clust=Louvain;direction=BOTH;m=0.5 288389 0.722 0.837
#
# bin=GMM;pval=0.005;clust=Louvain;direction=BOTH;m=0.6 670487 0.703 0.836
# bin=GMM;pval=0.005;clust=Louvain;direction=BOTH;m=0.6 116739 0.702 0.836
# bin=GMM;pval=0.005;clust=Louvain;direction=BOTH;m=0.6 26225 0.698 0.837
# bin=GMM;pval=0.005;clust=Louvain;direction=BOTH;m=0.6 777572 0.724 0.837
# bin=GMM;pval=0.005;clust=Louvain;direction=BOTH;m=0.6 288389 0.722 0.837
#
# bin=GMM;pval=0.005;clust=Louvain;direction=BOTH;m=0.7 670487 0.703 0.836
# bin=GMM;pval=0.005;clust=Louvain;direction=BOTH;m=0.7 116739 0.702 0.836
# bin=GMM;pval=0.005;clust=Louvain;direction=BOTH;m=0.7 26225 0.698 0.837
# bin=GMM;pval=0.005;clust=Louvain;direction=BOTH;m=0.7 777572 0.724 0.837
# bin=GMM;pval=0.005;clust=Louvain;direction=BOTH;m=0.7 288389 0.722 0.837
#
# bin=GMM;pval=0.005;clust=Louvain;direction=BOTH;m=0.8 670487 0.703 0.836
# bin=GMM;pval=0.005;clust=Louvain;direction=BOTH;m=0.8 116739 0.702 0.836
# bin=GMM;pval=0.005;clust=Louvain;direction=BOTH;m=0.8 26225 0.698 0.837
# bin=GMM;pval=0.005;clust=Louvain;direction=BOTH;m=0.8 777572 0.724 0.837
# bin=GMM;pval=0.005;clust=Louvain;direction=BOTH;m=0.8 288389 0.722 0.837
#
# bin=GMM;pval=0.005;clust=Louvain;direction=BOTH;m=0.9 670487 0.703 0.836
# bin=GMM;pval=0.005;clust=Louvain;direction=BOTH;m=0.9 116739 0.702 0.836
# bin=GMM;pval=0.005;clust=Louvain;direction=BOTH;m=0.9 26225 0.698 0.837
# bin=GMM;pval=0.005;clust=Louvain;direction=BOTH;m=0.9 777572 0.724 0.837
# bin=GMM;pval=0.005;clust=Louvain;direction=BOTH;m=0.9 288389 0.722 0.837
#
# bin=ward;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0 670487 0.727 0.83
# bin=ward;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0 116739 0.727 0.833
# bin=ward;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0 26225 0.727 0.833
# bin=ward;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0 777572 0.727 0.833
# bin=ward;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0 288389 0.727 0.833
#
# bin=ward;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.3 670487 0.727 0.83
# bin=ward;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.3 116739 0.727 0.833
# bin=ward;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.3 26225 0.727 0.833
# bin=ward;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.3 777572 0.727 0.833
# bin=ward;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.3 288389 0.727 0.833
#
# bin=ward;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.4 670487 0.727 0.83
# bin=ward;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.4 116739 0.727 0.833
# bin=ward;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.4 26225 0.727 0.833
# bin=ward;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.4 777572 0.727 0.833
# bin=ward;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.4 288389 0.727 0.833
#
# bin=ward;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.5 670487 0.727 0.83
# bin=ward;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.5 116739 0.727 0.833
# bin=ward;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.5 26225 0.727 0.833
# bin=ward;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.5 777572 0.727 0.833
# bin=ward;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.5 288389 0.727 0.833
#
# bin=ward;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.6 670487 0.727 0.83
# bin=ward;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.6 116739 0.727 0.833
# bin=ward;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.6 26225 0.727 0.833
# bin=ward;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.6 777572 0.727 0.833
# bin=ward;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.6 288389 0.727 0.833
#
# bin=ward;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.7 670487 0.727 0.83
# bin=ward;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.7 116739 0.727 0.833
# bin=ward;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.7 26225 0.727 0.833
# bin=ward;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.7 777572 0.727 0.833
# bin=ward;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.7 288389 0.727 0.833
#
# bin=ward;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.8 670487 0.727 0.83
# bin=ward;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.8 116739 0.727 0.833
# bin=ward;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.8 26225 0.727 0.833
# bin=ward;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.8 777572 0.727 0.833
# bin=ward;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.8 288389 0.727 0.833
#
# bin=ward;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.9 670487 0.727 0.83
# bin=ward;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.9 116739 0.727 0.833
# bin=ward;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.9 26225 0.727 0.833
# bin=ward;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.9 777572 0.727 0.833
# bin=ward;pval=0.005;clust=Louvain;direction=UP-DOWN;m=0.9 288389 0.727 0.833
#
# bin=ward;pval=0.005;clust=Louvain;direction=BOTH;m=0 670487 0.728 0.829
# bin=ward;pval=0.005;clust=Louvain;direction=BOTH;m=0 116739 0.716 0.827
# bin=ward;pval=0.005;clust=Louvain;direction=BOTH;m=0 26225 0.716 0.827
# bin=ward;pval=0.005;clust=Louvain;direction=BOTH;m=0 777572 0.728 0.827
# bin=ward;pval=0.005;clust=Louvain;direction=BOTH;m=0 288389 0.716 0.827
#
# bin=ward;pval=0.005;clust=Louvain;direction=BOTH;m=0.3 670487 0.728 0.829
# bin=ward;pval=0.005;clust=Louvain;direction=BOTH;m=0.3 116739 0.716 0.827
# bin=ward;pval=0.005;clust=Louvain;direction=BOTH;m=0.3 26225 0.716 0.827
# bin=ward;pval=0.005;clust=Louvain;direction=BOTH;m=0.3 777572 0.728 0.827
# bin=ward;pval=0.005;clust=Louvain;direction=BOTH;m=0.3 288389 0.716 0.827
#
# bin=ward;pval=0.005;clust=Louvain;direction=BOTH;m=0.4 670487 0.728 0.829
# bin=ward;pval=0.005;clust=Louvain;direction=BOTH;m=0.4 116739 0.716 0.827
# bin=ward;pval=0.005;clust=Louvain;direction=BOTH;m=0.4 26225 0.716 0.827
# bin=ward;pval=0.005;clust=Louvain;direction=BOTH;m=0.4 777572 0.728 0.827
# bin=ward;pval=0.005;clust=Louvain;direction=BOTH;m=0.4 288389 0.716 0.827
#
# bin=ward;pval=0.005;clust=Louvain;direction=BOTH;m=0.5 670487 0.728 0.829
# bin=ward;pval=0.005;clust=Louvain;direction=BOTH;m=0.5 116739 0.716 0.827
# bin=ward;pval=0.005;clust=Louvain;direction=BOTH;m=0.5 26225 0.716 0.827
# bin=ward;pval=0.005;clust=Louvain;direction=BOTH;m=0.5 777572 0.728 0.827
# bin=ward;pval=0.005;clust=Louvain;direction=BOTH;m=0.5 288389 0.716 0.827
#
# bin=ward;pval=0.005;clust=Louvain;direction=BOTH;m=0.6 670487 0.728 0.829
# bin=ward;pval=0.005;clust=Louvain;direction=BOTH;m=0.6 116739 0.716 0.827
# bin=ward;pval=0.005;clust=Louvain;direction=BOTH;m=0.6 26225 0.716 0.827
# bin=ward;pval=0.005;clust=Louvain;direction=BOTH;m=0.6 777572 0.728 0.827
# bin=ward;pval=0.005;clust=Louvain;direction=BOTH;m=0.6 288389 0.716 0.827
#
# bin=ward;pval=0.005;clust=Louvain;direction=BOTH;m=0.7 670487 0.728 0.829
# bin=ward;pval=0.005;clust=Louvain;direction=BOTH;m=0.7 116739 0.716 0.827
# bin=ward;pval=0.005;clust=Louvain;direction=BOTH;m=0.7 26225 0.716 0.827
# bin=ward;pval=0.005;clust=Louvain;direction=BOTH;m=0.7 777572 0.728 0.827
# bin=ward;pval=0.005;clust=Louvain;direction=BOTH;m=0.7 288389 0.716 0.827
#
# bin=ward;pval=0.005;clust=Louvain;direction=BOTH;m=0.8 670487 0.728 0.829
# bin=ward;pval=0.005;clust=Louvain;direction=BOTH;m=0.8 116739 0.716 0.827
# bin=ward;pval=0.005;clust=Louvain;direction=BOTH;m=0.8 26225 0.716 0.827
# bin=ward;pval=0.005;clust=Louvain;direction=BOTH;m=0.8 777572 0.728 0.827
# bin=ward;pval=0.005;clust=Louvain;direction=BOTH;m=0.8 288389 0.716 0.827
#
# bin=ward;pval=0.005;clust=Louvain;direction=BOTH;m=0.9 670487 0.728 0.829
# bin=ward;pval=0.005;clust=Louvain;direction=BOTH;m=0.9 116739 0.716 0.827
# bin=ward;pval=0.005;clust=Louvain;direction=BOTH;m=0.9 26225 0.716 0.827
# bin=ward;pval=0.005;clust=Louvain;direction=BOTH;m=0.9 777572 0.728 0.827
# bin=ward;pval=0.005;clust=Louvain;direction=BOTH;m=0.9 288389 0.716 0.827

# %%
clust_methods = ["WGCNA"]
dss = [0,1,2,3,4]
dchs = [0.95,0.995]
cseed = 0

pc = True

for pval in pvals:
    for ds in dss:
        for dch in dchs:
            for d in directions:
                for clust_method in clust_methods:
                    for bin_method in bin_methods:
                        # save parameters as a ;-separated string
                        params = "bin="+bin_method+";pval="+str(pval)+";direction="+str("-".join(d))
                        params += ";clust="+clust_method+";dch="+str(dch)+";ds="+str(ds)+";preClustering=T"
                        print(params)
                        biclusters_t = []
                        biclusters_m = []
                        for r in range(n_runs):
                            seed = seeds[r]
                            #print("run",run,bin_method,pval,m,seed)
                            params_dict = {"parameters":params, "seed":seed,"run":r}

                            ### running TCGA or reading results
                            try:
                                t0 = time()
                                fname = out_dir+basename_t+".seed="+str(seed)+".bin="+bin_method +",pval="+str(pval)+",clust=WGCNA,direction="+str("-".join(d))+",ds="+str(ds)+",dch="+str(dch)+",max_power=10,precluster=True"+".biclusters.tsv"
                                try:
                                    result_t = read_bic_table(fname)
                                except:
                                    print("not found")
                                    """result_t = run(exprs_file_t, basename_t, out_dir=out_dir,
                                                                save=True, load = True,
                                                                min_n_samples = 5,
                                                                bin_method = bin_method, pval = pval,
                                                                directions = d,
                                                                clust_method = clust_method,
                                                                precluster=pc,
                                                                ds=ds,dch=dch,
                                                                rpath=rpath,
                                                                seed = seed,
                                                                verbose = False)
                                                                
                                    """
                                performance_t,bm_dict_t = calculate_perfromance(result_t, known_groups_t,all_samples_t)
                                performance_t = performance_t.to_dict()
                                performance_t.update(params_dict)
                                performance_t["time"] = time_t
                                subt_t.append(performance_t)
                                t_failed = False
                            except:
                                print("TCGA biclustering failed with ",seed,  pval,bin_method ,file = sys.stderr)
                                print(fname)
                                t_failed = True
                                subt_t.append({params_dict})
                            
                            ### running METABRIC or reading results
                            try:
                                t0 = time()
                                fname = out_dir+basename_m+".seed="+str(seed)+".bin="+bin_method +",pval="+str(pval)+",clust=WGCNA,direction="+str("-".join(d))+",ds="+str(ds)+",dch="+str(dch)+",max_power=10,precluster=True"+".biclusters.tsv"
                                try:
                                    result_m = read_bic_table(fname)
                                except:
                                    print(fname)
                                    """result_m = run(exprs_file_m, basename_m, out_dir=out_dir,
                                                                save=True, load = True,
                                                                min_n_samples = 5,
                                                                bin_method = bin_method, pval = pval,
                                                                directions = d,
                                                                clust_method = clust_method,
                                                                precluster=pc,
                                                                ds=ds,dch=dch,
                                                                rpath=rpath,
                                                                seed = seed,
                                                                verbose = False)
                                    """
                                time_m = time()-t0
                                # find the best matches between METABRIC biclusters and subtypes
                                # and calculate overall performance == weighted sum of Jaccard indexes
                                performance_m,bm_dict_m = calculate_perfromance(result_m, known_groups_m,all_samples_m)
                                performance_m = performance_m.to_dict()
                                performance_m.update(params_dict)
                                performance_m["time"] = time_m
                                subt_m.append(performance_m)
                                m_failed = False
                            except:
                                print("METABRIC biclustering failed with ",seed,  pval,bin_method ,file = sys.stderr)
                                print(fname)
                                m_failed = True
                                subt_m.append(params_dict)
                            print(params,seed, round(performance_t["PAM50"],3),round(performance_m["PAM50"],3))    
                            # compare clustering results - only if gene sets are defined for each cluster
                            if not (t_failed or m_failed): 
                                N = exprs_m.shape[0]
                                clust_sim, bm, bm2 = compare_gene_clusters(result_t,result_m, N)                    
                            else:
                                clust_sim = {}
                            clust_sim.update(params_dict)
                            clustering_similarities.append(clust_sim)
# Out:
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=0;preClustering=T
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=0;preClustering=T 670487 0.696 0.834
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=0;preClustering=T 116739 0.789 0.834
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=0;preClustering=T 26225 0.841 0.834
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=0;preClustering=T 777572 0.698 0.834
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=0;preClustering=T 288389 0.694 0.834
# bin=GMM;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=0;preClustering=T
# bin=GMM;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=0;preClustering=T 670487 0.84 0.827
# bin=GMM;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=0;preClustering=T 116739 0.837 0.827
# bin=GMM;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=0;preClustering=T 26225 0.837 0.828
# bin=GMM;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=0;preClustering=T 777572 0.839 0.83
# bin=GMM;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=0;preClustering=T 288389 0.842 0.828
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=0;preClustering=T
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=0;preClustering=T 670487 0.838 0.835
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=0;preClustering=T 116739 0.851 0.83
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=0;preClustering=T 26225 0.851 0.836
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=0;preClustering=T 777572 0.839 0.832
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=0;preClustering=T 288389 0.838 0.835
# bin=kmeans;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=0;preClustering=T
# bin=kmeans;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=0;preClustering=T 670487 0.766 0.838
# bin=kmeans;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=0;preClustering=T 116739 0.746 0.838
# bin=kmeans;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=0;preClustering=T 26225 0.769 0.824
# bin=kmeans;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=0;preClustering=T 777572 0.749 0.84
# bin=kmeans;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=0;preClustering=T 288389 0.775 0.825
# bin=GMM;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=0;preClustering=T
# bin=GMM;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=0;preClustering=T 670487 0.71 0.814
# bin=GMM;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=0;preClustering=T 116739 0.712 0.817
# bin=GMM;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=0;preClustering=T 26225 0.71 0.812
# bin=GMM;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=0;preClustering=T 777572 0.711 0.813
# bin=GMM;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=0;preClustering=T 288389 0.71 0.813
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=0;preClustering=T
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=0;preClustering=T 670487 0.712 0.821
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=0;preClustering=T 116739 0.841 0.821
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=0;preClustering=T 26225 0.715 0.824
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=0;preClustering=T 777572 0.728 0.821
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=0;preClustering=T 288389 0.836 0.824
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=0;preClustering=T
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=0;preClustering=T 670487 0.821 0.849
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=0;preClustering=T 116739 0.833 0.85
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=0;preClustering=T 26225 0.816 0.841
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=0;preClustering=T 777572 0.817 0.843
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=0;preClustering=T 288389 0.818 0.848
# bin=GMM;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=0;preClustering=T
# bin=GMM;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=0;preClustering=T 670487 0.799 0.822
# bin=GMM;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=0;preClustering=T 116739 0.8 0.823
# bin=GMM;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=0;preClustering=T 26225 0.803 0.821
# bin=GMM;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=0;preClustering=T 777572 0.808 0.823
# bin=GMM;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=0;preClustering=T 288389 0.801 0.824
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=0;preClustering=T
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=0;preClustering=T 670487 0.808 0.825
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=0;preClustering=T 116739 0.829 0.837
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=0;preClustering=T 26225 0.775 0.828
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=0;preClustering=T 777572 0.85 0.831
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=0;preClustering=T 288389 0.812 0.825
# bin=kmeans;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=0;preClustering=T
# bin=kmeans;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=0;preClustering=T 670487 0.738 0.835
# bin=kmeans;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=0;preClustering=T 116739 0.776 0.834
# bin=kmeans;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=0;preClustering=T 26225 0.701 0.836
# bin=kmeans;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=0;preClustering=T 777572 0.749 0.823
# bin=kmeans;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=0;preClustering=T 288389 0.739 0.825
# bin=GMM;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=0;preClustering=T
# bin=GMM;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=0;preClustering=T 670487 0.708 0.814
# bin=GMM;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=0;preClustering=T 116739 0.709 0.815
# bin=GMM;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=0;preClustering=T 26225 0.707 0.768
# bin=GMM;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=0;preClustering=T 777572 0.709 0.82
# bin=GMM;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=0;preClustering=T 288389 0.707 0.802
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=0;preClustering=T
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=0;preClustering=T 670487 0.72 0.839
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=0;preClustering=T 116739 0.719 0.822
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=0;preClustering=T 26225 0.703 0.841
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=0;preClustering=T 777572 0.84 0.785
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=0;preClustering=T 288389 0.705 0.835
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=1;preClustering=T
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=1;preClustering=T 670487 0.696 0.834
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=1;preClustering=T 116739 0.79 0.834
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=1;preClustering=T 26225 0.841 0.836
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=1;preClustering=T 777572 0.699 0.834
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=1;preClustering=T 288389 0.694 0.834
# bin=GMM;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=1;preClustering=T
# bin=GMM;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=1;preClustering=T 670487 0.84 0.827
# bin=GMM;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=1;preClustering=T 116739 0.837 0.827
# bin=GMM;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=1;preClustering=T 26225 0.837 0.828
# bin=GMM;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=1;preClustering=T 777572 0.84 0.83
# bin=GMM;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=1;preClustering=T 288389 0.842 0.828
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=1;preClustering=T
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=1;preClustering=T 670487 0.838 0.832
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=1;preClustering=T 116739 0.851 0.832
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=1;preClustering=T 26225 0.851 0.836
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=1;preClustering=T 777572 0.839 0.832
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=1;preClustering=T 288389 0.838 0.832
# bin=kmeans;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=1;preClustering=T
# bin=kmeans;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=1;preClustering=T 670487 0.766 0.838
# bin=kmeans;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=1;preClustering=T 116739 0.747 0.838
# bin=kmeans;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=1;preClustering=T 26225 0.77 0.826
# bin=kmeans;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=1;preClustering=T 777572 0.749 0.84
# bin=kmeans;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=1;preClustering=T 288389 0.775 0.826
# bin=GMM;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=1;preClustering=T
# bin=GMM;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=1;preClustering=T 670487 0.71 0.814
# bin=GMM;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=1;preClustering=T 116739 0.712 0.817
# bin=GMM;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=1;preClustering=T 26225 0.71 0.812
# bin=GMM;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=1;preClustering=T 777572 0.711 0.813
# bin=GMM;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=1;preClustering=T 288389 0.71 0.813
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=1;preClustering=T
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=1;preClustering=T 670487 0.712 0.821
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=1;preClustering=T 116739 0.841 0.821
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=1;preClustering=T 26225 0.715 0.824
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=1;preClustering=T 777572 0.728 0.821
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=1;preClustering=T 288389 0.836 0.824
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=1;preClustering=T
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=1;preClustering=T 670487 0.821 0.843
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=1;preClustering=T 116739 0.833 0.84
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=1;preClustering=T 26225 0.807 0.841
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=1;preClustering=T 777572 0.816 0.843
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=1;preClustering=T 288389 0.796 0.849
# bin=GMM;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=1;preClustering=T
# bin=GMM;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=1;preClustering=T 670487 0.832 0.822
# bin=GMM;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=1;preClustering=T 116739 0.828 0.822
# bin=GMM;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=1;preClustering=T 26225 0.829 0.823
# bin=GMM;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=1;preClustering=T 777572 0.832 0.823
# bin=GMM;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=1;preClustering=T 288389 0.832 0.824
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=1;preClustering=T
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=1;preClustering=T 670487 0.863 0.827
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=1;preClustering=T 116739 0.829 0.834
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=1;preClustering=T 26225 0.827 0.829
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=1;preClustering=T 777572 0.842 0.792
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=1;preClustering=T 288389 0.816 0.83
# bin=kmeans;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=1;preClustering=T
# bin=kmeans;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=1;preClustering=T 670487 0.786 0.833
# bin=kmeans;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=1;preClustering=T 116739 0.75 0.835
# bin=kmeans;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=1;preClustering=T 26225 0.766 0.832
# bin=kmeans;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=1;preClustering=T 777572 0.744 0.826
# bin=kmeans;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=1;preClustering=T 288389 0.781 0.824
# bin=GMM;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=1;preClustering=T
# bin=GMM;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=1;preClustering=T 670487 0.708 0.807
# bin=GMM;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=1;preClustering=T 116739 0.748 0.815
# bin=GMM;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=1;preClustering=T 26225 0.711 0.811
# bin=GMM;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=1;preClustering=T 777572 0.715 0.821
# bin=GMM;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=1;preClustering=T 288389 0.764 0.802
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=1;preClustering=T
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=1;preClustering=T 670487 0.801 0.836
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=1;preClustering=T 116739 0.784 0.793
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=1;preClustering=T 26225 0.802 0.824
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=1;preClustering=T 777572 0.854 0.786
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=1;preClustering=T 288389 0.819 0.806
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=2;preClustering=T
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=2;preClustering=T 670487 0.846 0.834
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=2;preClustering=T 116739 0.854 0.834
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=2;preClustering=T 26225 0.841 0.836
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=2;preClustering=T 777572 0.852 0.834
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=2;preClustering=T 288389 0.847 0.834
# bin=GMM;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=2;preClustering=T
# bin=GMM;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=2;preClustering=T 670487 0.84 0.827
# bin=GMM;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=2;preClustering=T 116739 0.837 0.827
# bin=GMM;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=2;preClustering=T 26225 0.837 0.828
# bin=GMM;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=2;preClustering=T 777572 0.84 0.83
# bin=GMM;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=2;preClustering=T 288389 0.842 0.828
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=2;preClustering=T
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=2;preClustering=T 670487 0.838 0.834
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=2;preClustering=T 116739 0.851 0.833
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=2;preClustering=T 26225 0.851 0.834
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=2;preClustering=T 777572 0.839 0.833
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=2;preClustering=T 288389 0.837 0.833
# bin=kmeans;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=2;preClustering=T
# bin=kmeans;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=2;preClustering=T 670487 0.843 0.838
# bin=kmeans;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=2;preClustering=T 116739 0.748 0.838
# bin=kmeans;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=2;preClustering=T 26225 0.757 0.822
# bin=kmeans;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=2;preClustering=T 777572 0.83 0.84
# bin=kmeans;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=2;preClustering=T 288389 0.774 0.823
# bin=GMM;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=2;preClustering=T
# bin=GMM;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=2;preClustering=T 670487 0.71 0.814
# bin=GMM;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=2;preClustering=T 116739 0.712 0.817
# bin=GMM;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=2;preClustering=T 26225 0.71 0.812
# bin=GMM;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=2;preClustering=T 777572 0.711 0.813
# bin=GMM;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=2;preClustering=T 288389 0.71 0.813
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=2;preClustering=T
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=2;preClustering=T 670487 0.754 0.821
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=2;preClustering=T 116739 0.839 0.821
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=2;preClustering=T 26225 0.716 0.824
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=2;preClustering=T 777572 0.728 0.821
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=2;preClustering=T 288389 0.835 0.824
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=2;preClustering=T
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=2;preClustering=T 670487 0.8 0.842
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=2;preClustering=T 116739 0.834 0.84
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=2;preClustering=T 26225 0.794 0.846
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=2;preClustering=T 777572 0.816 0.843
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=2;preClustering=T 288389 0.796 0.844
# bin=GMM;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=2;preClustering=T
# bin=GMM;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=2;preClustering=T 670487 0.832 0.821
# bin=GMM;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=2;preClustering=T 116739 0.829 0.824
# bin=GMM;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=2;preClustering=T 26225 0.828 0.823
# bin=GMM;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=2;preClustering=T 777572 0.831 0.821
# bin=GMM;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=2;preClustering=T 288389 0.831 0.825
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=2;preClustering=T
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=2;preClustering=T 670487 0.844 0.805
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=2;preClustering=T 116739 0.822 0.828
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=2;preClustering=T 26225 0.852 0.832
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=2;preClustering=T 777572 0.841 0.831
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=2;preClustering=T 288389 0.859 0.824
# bin=kmeans;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=2;preClustering=T
# bin=kmeans;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=2;preClustering=T 670487 0.777 0.835
# bin=kmeans;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=2;preClustering=T 116739 0.774 0.835
# bin=kmeans;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=2;preClustering=T 26225 0.768 0.828
# bin=kmeans;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=2;preClustering=T 777572 0.736 0.826
# bin=kmeans;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=2;preClustering=T 288389 0.775 0.823
# bin=GMM;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=2;preClustering=T
# bin=GMM;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=2;preClustering=T 670487 0.777 0.817
# bin=GMM;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=2;preClustering=T 116739 0.777 0.816
# bin=GMM;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=2;preClustering=T 26225 0.796 0.815
# bin=GMM;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=2;preClustering=T 777572 0.81 0.824
# bin=GMM;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=2;preClustering=T 288389 0.806 0.807
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=2;preClustering=T
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=2;preClustering=T 670487 0.802 0.804
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=2;preClustering=T 116739 0.841 0.83
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=2;preClustering=T 26225 0.859 0.832
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=2;preClustering=T 777572 0.853 0.813
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=2;preClustering=T 288389 0.855 0.798
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=3;preClustering=T
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=3;preClustering=T 670487 0.846 0.834
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=3;preClustering=T 116739 0.854 0.834
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=3;preClustering=T 26225 0.842 0.835
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=3;preClustering=T 777572 0.852 0.834
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=3;preClustering=T 288389 0.853 0.837
# bin=GMM;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=3;preClustering=T
# bin=GMM;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=3;preClustering=T 670487 0.841 0.827
# bin=GMM;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=3;preClustering=T 116739 0.839 0.827
# bin=GMM;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=3;preClustering=T 26225 0.837 0.828
# bin=GMM;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=3;preClustering=T 777572 0.835 0.831
# bin=GMM;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=3;preClustering=T 288389 0.84 0.828
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=3;preClustering=T
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=3;preClustering=T 670487 0.838 0.833
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=3;preClustering=T 116739 0.854 0.836
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=3;preClustering=T 26225 0.854 0.835
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=3;preClustering=T 777572 0.838 0.832
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=3;preClustering=T 288389 0.852 0.834
# bin=kmeans;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=3;preClustering=T
# bin=kmeans;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=3;preClustering=T 670487 0.834 0.838
# bin=kmeans;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=3;preClustering=T 116739 0.849 0.838
# bin=kmeans;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=3;preClustering=T 26225 0.844 0.823
# bin=kmeans;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=3;preClustering=T 777572 0.832 0.838
# bin=kmeans;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=3;preClustering=T 288389 0.843 0.818
# bin=GMM;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=3;preClustering=T
# bin=GMM;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=3;preClustering=T 670487 0.71 0.814
# bin=GMM;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=3;preClustering=T 116739 0.712 0.817
# bin=GMM;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=3;preClustering=T 26225 0.71 0.813
# bin=GMM;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=3;preClustering=T 777572 0.711 0.813
# bin=GMM;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=3;preClustering=T 288389 0.71 0.813
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=3;preClustering=T
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=3;preClustering=T 670487 0.786 0.821
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=3;preClustering=T 116739 0.839 0.821
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=3;preClustering=T 26225 0.716 0.824
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=3;preClustering=T 777572 0.741 0.821
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=3;preClustering=T 288389 0.834 0.824
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=3;preClustering=T
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=3;preClustering=T 670487 0.851 0.839
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=3;preClustering=T 116739 0.847 0.841
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=3;preClustering=T 26225 0.824 0.845
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=3;preClustering=T 777572 0.849 0.844
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=3;preClustering=T 288389 0.85 0.843
# bin=GMM;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=3;preClustering=T
# bin=GMM;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=3;preClustering=T 670487 0.831 0.821
# bin=GMM;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=3;preClustering=T 116739 0.832 0.819
# bin=GMM;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=3;preClustering=T 26225 0.828 0.821
# bin=GMM;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=3;preClustering=T 777572 0.832 0.821
# bin=GMM;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=3;preClustering=T 288389 0.83 0.828
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=3;preClustering=T
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=3;preClustering=T 670487 0.824 0.825
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=3;preClustering=T 116739 0.86 0.848
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=3;preClustering=T 26225 0.842 0.826
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=3;preClustering=T 777572 0.826 0.824
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=3;preClustering=T 288389 0.839 0.831
# bin=kmeans;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=3;preClustering=T
# bin=kmeans;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=3;preClustering=T 670487 0.824 0.836
# bin=kmeans;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=3;preClustering=T 116739 0.847 0.836
# bin=kmeans;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=3;preClustering=T 26225 0.795 0.826
# bin=kmeans;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=3;preClustering=T 777572 0.821 0.827
# bin=kmeans;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=3;preClustering=T 288389 0.781 0.82
# bin=GMM;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=3;preClustering=T
# bin=GMM;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=3;preClustering=T 670487 0.812 0.813
# bin=GMM;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=3;preClustering=T 116739 0.811 0.826
# bin=GMM;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=3;preClustering=T 26225 0.792 0.815
# bin=GMM;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=3;preClustering=T 777572 0.799 0.818
# bin=GMM;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=3;preClustering=T 288389 0.797 0.811
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=3;preClustering=T
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=3;preClustering=T 670487 0.816 0.801
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=3;preClustering=T 116739 0.84 0.825
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=3;preClustering=T 26225 0.836 0.803
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=3;preClustering=T 777572 0.842 0.803
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=3;preClustering=T 288389 0.834 0.837
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=4;preClustering=T
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=4;preClustering=T 670487 0.852 0.834
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=4;preClustering=T 116739 0.854 0.834
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=4;preClustering=T 26225 0.842 0.835
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=4;preClustering=T 777572 0.852 0.834
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=4;preClustering=T 288389 0.853 0.837
# bin=GMM;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=4;preClustering=T
# bin=GMM;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=4;preClustering=T 670487 0.841 0.827
# bin=GMM;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=4;preClustering=T 116739 0.837 0.828
# bin=GMM;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=4;preClustering=T 26225 0.837 0.829
# bin=GMM;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=4;preClustering=T 777572 0.834 0.831
# bin=GMM;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=4;preClustering=T 288389 0.836 0.829
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=4;preClustering=T
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=4;preClustering=T 670487 0.838 0.836
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=4;preClustering=T 116739 0.854 0.835
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=4;preClustering=T 26225 0.854 0.833
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=4;preClustering=T 777572 0.838 0.833
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=4;preClustering=T 288389 0.852 0.832
# bin=kmeans;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=4;preClustering=T
# bin=kmeans;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=4;preClustering=T 670487 0.836 0.839
# bin=kmeans;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=4;preClustering=T 116739 0.848 0.838
# bin=kmeans;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=4;preClustering=T 26225 0.833 0.82
# bin=kmeans;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=4;preClustering=T 777572 0.832 0.838
# bin=kmeans;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=4;preClustering=T 288389 0.843 0.818
# bin=GMM;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=4;preClustering=T
# bin=GMM;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=4;preClustering=T 670487 0.71 0.814
# bin=GMM;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=4;preClustering=T 116739 0.712 0.817
# bin=GMM;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=4;preClustering=T 26225 0.71 0.813
# bin=GMM;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=4;preClustering=T 777572 0.711 0.813
# bin=GMM;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=4;preClustering=T 288389 0.71 0.813
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=4;preClustering=T
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=4;preClustering=T 670487 0.786 0.821
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=4;preClustering=T 116739 0.839 0.821
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=4;preClustering=T 26225 0.716 0.824
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=4;preClustering=T 777572 0.741 0.821
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.95;ds=4;preClustering=T 288389 0.834 0.824
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=4;preClustering=T
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=4;preClustering=T 670487 0.852 0.838
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=4;preClustering=T 116739 0.852 0.836
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=4;preClustering=T 26225 0.824 0.844
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=4;preClustering=T 777572 0.85 0.843
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=4;preClustering=T 288389 0.849 0.845
# bin=GMM;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=4;preClustering=T
# bin=GMM;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=4;preClustering=T 670487 0.837 0.825
# bin=GMM;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=4;preClustering=T 116739 0.834 0.821
# bin=GMM;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=4;preClustering=T 26225 0.834 0.819
# bin=GMM;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=4;preClustering=T 777572 0.837 0.824
# bin=GMM;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=4;preClustering=T 288389 0.835 0.826
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=4;preClustering=T
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=4;preClustering=T 670487 0.831 0.83
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=4;preClustering=T 116739 0.843 0.825
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=4;preClustering=T 26225 0.841 0.834
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=4;preClustering=T 777572 0.839 0.83
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=4;preClustering=T 288389 0.832 0.827
# bin=kmeans;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=4;preClustering=T
# bin=kmeans;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=4;preClustering=T 670487 0.823 0.837
# bin=kmeans;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=4;preClustering=T 116739 0.851 0.837
# bin=kmeans;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=4;preClustering=T 26225 0.843 0.829
# bin=kmeans;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=4;preClustering=T 777572 0.819 0.834
# bin=kmeans;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=4;preClustering=T 288389 0.822 0.818
# bin=GMM;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=4;preClustering=T
# bin=GMM;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=4;preClustering=T 670487 0.81 0.814
# bin=GMM;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=4;preClustering=T 116739 0.812 0.815
# bin=GMM;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=4;preClustering=T 26225 0.791 0.819
# bin=GMM;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=4;preClustering=T 777572 0.799 0.819
# bin=GMM;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=4;preClustering=T 288389 0.8 0.808
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=4;preClustering=T
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=4;preClustering=T 670487 0.841 0.819
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=4;preClustering=T 116739 0.811 0.83
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=4;preClustering=T 26225 0.831 0.802
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=4;preClustering=T 777572 0.849 0.823
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dch=0.995;ds=4;preClustering=T 288389 0.849 0.833
# bin=kmeans;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=0;preClustering=T
# bin=kmeans;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=0;preClustering=T 670487 0.708 0.833
# bin=kmeans;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=0;preClustering=T 116739 0.739 0.832
# bin=kmeans;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=0;preClustering=T 26225 0.715 0.832
# bin=kmeans;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=0;preClustering=T 777572 0.737 0.836
# bin=kmeans;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=0;preClustering=T 288389 0.791 0.835
# bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=0;preClustering=T
# bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=0;preClustering=T 670487 0.677 0.829
# bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=0;preClustering=T 116739 0.703 0.83
# bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=0;preClustering=T 26225 0.724 0.815
# bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=0;preClustering=T 777572 0.68 0.821
# bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=0;preClustering=T 288389 0.673 0.814
# bin=ward;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=0;preClustering=T
# bin=ward;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=0;preClustering=T 670487 0.838 0.836
# bin=ward;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=0;preClustering=T 116739 0.719 0.814
# bin=ward;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=0;preClustering=T 26225 0.746 0.834
# bin=ward;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=0;preClustering=T 777572 0.716 0.833
# bin=ward;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=0;preClustering=T 288389 0.831 0.836
# bin=kmeans;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.95;ds=0;preClustering=T
# bin=kmeans;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.95;ds=0;preClustering=T 670487 0.689 0.84
# bin=kmeans;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.95;ds=0;preClustering=T 116739 0.702 0.837
# bin=kmeans;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.95;ds=0;preClustering=T 26225 0.681 0.844
# bin=kmeans;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.95;ds=0;preClustering=T 777572 0.685 0.843
# bin=kmeans;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.95;ds=0;preClustering=T 288389 0.699 0.836
# bin=GMM;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.95;ds=0;preClustering=T
# bin=GMM;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.95;ds=0;preClustering=T 670487 0.668 0.822
# bin=GMM;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.95;ds=0;preClustering=T 116739 0.837 0.813
# bin=GMM;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.95;ds=0;preClustering=T 26225 0.668 0.813
# bin=GMM;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.95;ds=0;preClustering=T 777572 0.669 0.816
# bin=GMM;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.95;ds=0;preClustering=T 288389 0.671 0.813
# bin=ward;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.95;ds=0;preClustering=T
# bin=ward;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.95;ds=0;preClustering=T 670487 0.695 0.831
# bin=ward;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.95;ds=0;preClustering=T 116739 0.712 0.832
# bin=ward;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.95;ds=0;preClustering=T 26225 0.687 0.807
# bin=ward;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.95;ds=0;preClustering=T 777572 0.719 0.809
# bin=ward;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.95;ds=0;preClustering=T 288389 0.702 0.834
# bin=kmeans;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=0;preClustering=T
# bin=kmeans;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=0;preClustering=T 670487 0.727 0.847
# bin=kmeans;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=0;preClustering=T 116739 0.754 0.832
# bin=kmeans;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=0;preClustering=T 26225 0.82 0.848
# bin=kmeans;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=0;preClustering=T 777572 0.732 0.849
# bin=kmeans;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=0;preClustering=T 288389 0.711 0.835
# bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=0;preClustering=T
# bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=0;preClustering=T 670487 0.757 0.825
# bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=0;preClustering=T 116739 0.666 0.82
# bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=0;preClustering=T 26225 0.667 0.815
# bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=0;preClustering=T 777572 0.807 0.81
# bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=0;preClustering=T 288389 0.674 0.797
# bin=ward;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=0;preClustering=T
# bin=ward;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=0;preClustering=T 670487 0.837 0.824
# bin=ward;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=0;preClustering=T 116739 0.748 0.811
# bin=ward;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=0;preClustering=T 26225 0.765 0.815
# bin=ward;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=0;preClustering=T 777572 0.748 0.833
# bin=ward;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=0;preClustering=T 288389 0.807 0.839
# bin=kmeans;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.995;ds=0;preClustering=T
# bin=kmeans;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.995;ds=0;preClustering=T 670487 0.808 0.831
# bin=kmeans;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.995;ds=0;preClustering=T 116739 0.82 0.838
# bin=kmeans;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.995;ds=0;preClustering=T 26225 0.682 0.832
# bin=kmeans;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.995;ds=0;preClustering=T 777572 0.675 0.833
# bin=kmeans;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.995;ds=0;preClustering=T 288389 0.84 0.83
# bin=GMM;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.995;ds=0;preClustering=T
# bin=GMM;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.995;ds=0;preClustering=T 670487 0.666 0.809
# bin=GMM;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.995;ds=0;preClustering=T 116739 0.843 0.816
# bin=GMM;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.995;ds=0;preClustering=T 26225 0.674 0.817
# bin=GMM;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.995;ds=0;preClustering=T 777572 0.672 0.815
# bin=GMM;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.995;ds=0;preClustering=T 288389 0.723 0.822
# bin=ward;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.995;ds=0;preClustering=T
# bin=ward;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.995;ds=0;preClustering=T 670487 0.853 0.84
# bin=ward;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.995;ds=0;preClustering=T 116739 0.768 0.773
# bin=ward;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.995;ds=0;preClustering=T 26225 0.81 0.828
# bin=ward;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.995;ds=0;preClustering=T 777572 0.848 0.823
# bin=ward;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.995;ds=0;preClustering=T 288389 0.845 0.764
# bin=kmeans;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=1;preClustering=T
# bin=kmeans;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=1;preClustering=T 670487 0.816 0.833
# bin=kmeans;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=1;preClustering=T 116739 0.74 0.832
# bin=kmeans;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=1;preClustering=T 26225 0.715 0.833
# bin=kmeans;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=1;preClustering=T 777572 0.694 0.836
# bin=kmeans;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=1;preClustering=T 288389 0.791 0.835
# bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=1;preClustering=T
# bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=1;preClustering=T 670487 0.682 0.829
# bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=1;preClustering=T 116739 0.703 0.83
# bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=1;preClustering=T 26225 0.724 0.815
# bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=1;preClustering=T 777572 0.685 0.821
# bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=1;preClustering=T 288389 0.673 0.819
# bin=ward;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=1;preClustering=T
# bin=ward;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=1;preClustering=T 670487 0.744 0.833
# bin=ward;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=1;preClustering=T 116739 0.737 0.823
# bin=ward;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=1;preClustering=T 26225 0.767 0.832
# bin=ward;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=1;preClustering=T 777572 0.711 0.833
# bin=ward;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=1;preClustering=T 288389 0.849 0.837
# bin=kmeans;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.95;ds=1;preClustering=T
# bin=kmeans;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.95;ds=1;preClustering=T 670487 0.71 0.841
# bin=kmeans;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.95;ds=1;preClustering=T 116739 0.708 0.837
# bin=kmeans;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.95;ds=1;preClustering=T 26225 0.704 0.844
# bin=kmeans;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.95;ds=1;preClustering=T 777572 0.706 0.843
# bin=kmeans;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.95;ds=1;preClustering=T 288389 0.71 0.836
# bin=GMM;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.95;ds=1;preClustering=T
# bin=GMM;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.95;ds=1;preClustering=T 670487 0.668 0.822
# bin=GMM;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.95;ds=1;preClustering=T 116739 0.837 0.813
# bin=GMM;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.95;ds=1;preClustering=T 26225 0.668 0.813
# bin=GMM;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.95;ds=1;preClustering=T 777572 0.669 0.815
# bin=GMM;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.95;ds=1;preClustering=T 288389 0.671 0.813
# bin=ward;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.95;ds=1;preClustering=T
# bin=ward;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.95;ds=1;preClustering=T 670487 0.765 0.832
# bin=ward;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.95;ds=1;preClustering=T 116739 0.742 0.832
# bin=ward;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.95;ds=1;preClustering=T 26225 0.707 0.81
# bin=ward;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.95;ds=1;preClustering=T 777572 0.718 0.809
# bin=ward;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.95;ds=1;preClustering=T 288389 0.761 0.834
# bin=kmeans;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=1;preClustering=T
# bin=kmeans;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=1;preClustering=T 670487 0.733 0.847
# bin=kmeans;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=1;preClustering=T 116739 0.76 0.829
# bin=kmeans;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=1;preClustering=T 26225 0.748 0.846
# bin=kmeans;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=1;preClustering=T 777572 0.766 0.85
# bin=kmeans;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=1;preClustering=T 288389 0.794 0.838
# bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=1;preClustering=T
# bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=1;preClustering=T 670487 0.788 0.824
# bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=1;preClustering=T 116739 0.768 0.816
# bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=1;preClustering=T 26225 0.795 0.818
# bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=1;preClustering=T 777572 0.769 0.809
# bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=1;preClustering=T 288389 0.776 0.814
# bin=ward;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=1;preClustering=T
# bin=ward;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=1;preClustering=T 670487 0.838 0.827
# bin=ward;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=1;preClustering=T 116739 0.751 0.812
# bin=ward;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=1;preClustering=T 26225 0.765 0.819
# bin=ward;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=1;preClustering=T 777572 0.845 0.825
# bin=ward;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=1;preClustering=T 288389 0.834 0.837
# bin=kmeans;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.995;ds=1;preClustering=T
# bin=kmeans;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.995;ds=1;preClustering=T 670487 0.763 0.834
# bin=kmeans;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.995;ds=1;preClustering=T 116739 0.819 0.836
# bin=kmeans;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.995;ds=1;preClustering=T 26225 0.766 0.833
# bin=kmeans;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.995;ds=1;preClustering=T 777572 0.792 0.833
# bin=kmeans;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.995;ds=1;preClustering=T 288389 0.75 0.833
# bin=GMM;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.995;ds=1;preClustering=T
# bin=GMM;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.995;ds=1;preClustering=T 670487 0.666 0.815
# bin=GMM;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.995;ds=1;preClustering=T 116739 0.843 0.816
# bin=GMM;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.995;ds=1;preClustering=T 26225 0.673 0.825
# bin=GMM;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.995;ds=1;preClustering=T 777572 0.672 0.816
# bin=GMM;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.995;ds=1;preClustering=T 288389 0.723 0.829
# bin=ward;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.995;ds=1;preClustering=T
# bin=ward;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.995;ds=1;preClustering=T 670487 0.747 0.82
# bin=ward;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.995;ds=1;preClustering=T 116739 0.85 0.841
# bin=ward;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.995;ds=1;preClustering=T 26225 0.811 0.804
# bin=ward;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.995;ds=1;preClustering=T 777572 0.847 0.828
# bin=ward;pval=0.001;direction=BOTH;clust=WGCNA;dch=0.995;ds=1;preClustering=T 288389 0.788 0.832
# bin=kmeans;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=2;preClustering=T
# bin=kmeans;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=2;preClustering=T 670487 0.84 0.833
# bin=kmeans;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=2;preClustering=T 116739 0.74 0.832
# bin=kmeans;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=2;preClustering=T 26225 0.839 0.833
# bin=kmeans;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=2;preClustering=T 777572 0.84 0.836
# bin=kmeans;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=2;preClustering=T 288389 0.791 0.835
# bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=2;preClustering=T
# bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=2;preClustering=T 670487 0.841 0.829
# bin=GMM;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=2;preClustering=T 116739 0.728 0.83
# ...
# bin=ward;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=2;preClustering=T
# bin=ward;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=2;preClustering=T 670487 0.848 0.807
# bin=ward;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=2;preClustering=T 116739 0.843 0.803
# bin=ward;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=2;preClustering=T 26225 0.831 0.826
# bin=ward;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=2;preClustering=T 777572 0.849 0.802
# bin=ward;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=2;preClustering=T 288389 0.832 0.835
# bin=kmeans;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.995;ds=2;preClustering=T
# bin=kmeans;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.995;ds=2;preClustering=T 670487 0.793 0.836
# bin=kmeans;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.995;ds=2;preClustering=T 116739 0.8 0.835
# bin=kmeans;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.995;ds=2;preClustering=T 26225 0.782 0.829
# bin=kmeans;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.995;ds=2;preClustering=T 777572 0.782 0.829
# bin=kmeans;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.995;ds=2;preClustering=T 288389 0.777 0.834
# bin=GMM;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.995;ds=2;preClustering=T
# bin=GMM;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.995;ds=2;preClustering=T 670487 0.724 0.816
# bin=GMM;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.995;ds=2;preClustering=T 116739 0.844 0.816
# bin=GMM;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.995;ds=2;preClustering=T 26225 0.845 0.817
# bin=GMM;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.995;ds=2;preClustering=T 777572 0.726 0.825
# bin=GMM;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.995;ds=2;preClustering=T 288389 0.719 0.821
# bin=ward;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.995;ds=2;preClustering=T
# bin=ward;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.995;ds=2;preClustering=T 670487 0.839 0.815
# bin=ward;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.995;ds=2;preClustering=T 116739 0.773 0.816
# bin=ward;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.995;ds=2;preClustering=T 26225 0.835 0.845
# bin=ward;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.995;ds=2;preClustering=T 777572 0.834 0.8
# bin=ward;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.995;ds=2;preClustering=T 288389 0.837 0.816
# bin=kmeans;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=3;preClustering=T
# bin=kmeans;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=3;preClustering=T 670487 0.836 0.833
# bin=kmeans;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=3;preClustering=T 116739 0.838 0.835
# bin=kmeans;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=3;preClustering=T 26225 0.836 0.836
# bin=kmeans;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=3;preClustering=T 777572 0.837 0.837
# bin=kmeans;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=3;preClustering=T 288389 0.846 0.833
# bin=GMM;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=3;preClustering=T
# bin=GMM;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=3;preClustering=T 670487 0.67 0.817
# bin=GMM;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=3;preClustering=T 116739 0.668 0.813
# bin=GMM;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=3;preClustering=T 26225 0.665 0.818
# bin=GMM;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=3;preClustering=T 777572 0.667 0.814
# bin=GMM;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=3;preClustering=T 288389 0.668 0.821
# bin=ward;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=3;preClustering=T
# bin=ward;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=3;preClustering=T 670487 0.847 0.838
# bin=ward;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=3;preClustering=T 116739 0.858 0.832
# bin=ward;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=3;preClustering=T 26225 0.85 0.834
# bin=ward;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=3;preClustering=T 777572 0.853 0.833
# bin=ward;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=3;preClustering=T 288389 0.855 0.823
# bin=kmeans;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.95;ds=3;preClustering=T
# bin=kmeans;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.95;ds=3;preClustering=T 670487 0.735 0.838
# bin=kmeans;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.95;ds=3;preClustering=T 116739 0.739 0.837
# bin=kmeans;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.95;ds=3;preClustering=T 26225 0.727 0.84
# bin=kmeans;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.95;ds=3;preClustering=T 777572 0.737 0.84
# bin=kmeans;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.95;ds=3;preClustering=T 288389 0.755 0.84
# bin=GMM;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.95;ds=3;preClustering=T
# bin=GMM;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.95;ds=3;preClustering=T 670487 0.73 0.813
# bin=GMM;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.95;ds=3;preClustering=T 116739 0.843 0.812
# bin=GMM;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.95;ds=3;preClustering=T 26225 0.84 0.813
# bin=GMM;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.95;ds=3;preClustering=T 777572 0.73 0.813
# bin=GMM;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.95;ds=3;preClustering=T 288389 0.731 0.813
# bin=ward;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.95;ds=3;preClustering=T
# bin=ward;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.95;ds=3;preClustering=T 670487 0.782 0.835
# bin=ward;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.95;ds=3;preClustering=T 116739 0.825 0.835
# bin=ward;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.95;ds=3;preClustering=T 26225 0.784 0.824
# bin=ward;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.95;ds=3;preClustering=T 777572 0.776 0.835
# bin=ward;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.95;ds=3;preClustering=T 288389 0.795 0.834
# bin=kmeans;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=3;preClustering=T
# bin=kmeans;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=3;preClustering=T 670487 0.835 0.84
# bin=kmeans;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=3;preClustering=T 116739 0.84 0.841
# bin=kmeans;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=3;preClustering=T 26225 0.841 0.837
# bin=kmeans;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=3;preClustering=T 777572 0.843 0.843
# bin=kmeans;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=3;preClustering=T 288389 0.838 0.842
# bin=GMM;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=3;preClustering=T
# bin=GMM;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=3;preClustering=T 670487 0.792 0.822
# bin=GMM;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=3;preClustering=T 116739 0.788 0.818
# bin=GMM;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=3;preClustering=T 26225 0.789 0.816
# bin=GMM;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=3;preClustering=T 777572 0.786 0.82
# bin=GMM;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=3;preClustering=T 288389 0.791 0.823
# bin=ward;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=3;preClustering=T
# bin=ward;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=3;preClustering=T 670487 0.837 0.811
# bin=ward;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=3;preClustering=T 116739 0.835 0.834
# bin=ward;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=3;preClustering=T 26225 0.837 0.823
# bin=ward;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=3;preClustering=T 777572 0.86 0.834
# bin=ward;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=3;preClustering=T 288389 0.857 0.814
# bin=kmeans;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.995;ds=3;preClustering=T
# bin=kmeans;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.995;ds=3;preClustering=T 670487 0.778 0.838
# bin=kmeans;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.995;ds=3;preClustering=T 116739 0.724 0.84
# bin=kmeans;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.995;ds=3;preClustering=T 26225 0.748 0.828
# bin=kmeans;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.995;ds=3;preClustering=T 777572 0.738 0.834
# bin=kmeans;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.995;ds=3;preClustering=T 288389 0.743 0.838
# bin=GMM;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.995;ds=3;preClustering=T
# bin=GMM;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.995;ds=3;preClustering=T 670487 0.724 0.818
# bin=GMM;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.995;ds=3;preClustering=T 116739 0.841 0.813
# bin=GMM;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.995;ds=3;preClustering=T 26225 0.841 0.822
# bin=GMM;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.995;ds=3;preClustering=T 777572 0.729 0.823
# bin=GMM;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.995;ds=3;preClustering=T 288389 0.748 0.823
# bin=ward;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.995;ds=3;preClustering=T
# bin=ward;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.995;ds=3;preClustering=T 670487 0.835 0.831
# bin=ward;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.995;ds=3;preClustering=T 116739 0.841 0.788
# bin=ward;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.995;ds=3;preClustering=T 26225 0.81 0.826
# bin=ward;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.995;ds=3;preClustering=T 777572 0.845 0.831
# bin=ward;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.995;ds=3;preClustering=T 288389 0.768 0.817
# bin=kmeans;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=4;preClustering=T
# bin=kmeans;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=4;preClustering=T 670487 0.835 0.836
# bin=kmeans;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=4;preClustering=T 116739 0.837 0.835
# bin=kmeans;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=4;preClustering=T 26225 0.836 0.838
# bin=kmeans;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=4;preClustering=T 777572 0.838 0.837
# bin=kmeans;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=4;preClustering=T 288389 0.846 0.833
# bin=GMM;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=4;preClustering=T
# bin=GMM;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=4;preClustering=T 670487 0.67 0.818
# bin=GMM;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=4;preClustering=T 116739 0.668 0.814
# bin=GMM;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=4;preClustering=T 26225 0.665 0.818
# bin=GMM;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=4;preClustering=T 777572 0.667 0.814
# bin=GMM;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=4;preClustering=T 288389 0.668 0.822
# bin=ward;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=4;preClustering=T
# bin=ward;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=4;preClustering=T 670487 0.847 0.838
# bin=ward;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=4;preClustering=T 116739 0.858 0.834
# bin=ward;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=4;preClustering=T 26225 0.851 0.836
# bin=ward;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=4;preClustering=T 777572 0.853 0.833
# bin=ward;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=4;preClustering=T 288389 0.842 0.826
# bin=kmeans;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.95;ds=4;preClustering=T
# bin=kmeans;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.95;ds=4;preClustering=T 670487 0.732 0.838
# bin=kmeans;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.95;ds=4;preClustering=T 116739 0.739 0.837
# bin=kmeans;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.95;ds=4;preClustering=T 26225 0.726 0.84
# bin=kmeans;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.95;ds=4;preClustering=T 777572 0.734 0.837
# bin=kmeans;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.95;ds=4;preClustering=T 288389 0.755 0.84
# bin=GMM;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.95;ds=4;preClustering=T
# bin=GMM;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.95;ds=4;preClustering=T 670487 0.73 0.813
# bin=GMM;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.95;ds=4;preClustering=T 116739 0.843 0.812
# bin=GMM;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.95;ds=4;preClustering=T 26225 0.84 0.813
# bin=GMM;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.95;ds=4;preClustering=T 777572 0.73 0.813
# bin=GMM;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.95;ds=4;preClustering=T 288389 0.731 0.813
# bin=ward;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.95;ds=4;preClustering=T
# bin=ward;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.95;ds=4;preClustering=T 670487 0.821 0.835
# bin=ward;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.95;ds=4;preClustering=T 116739 0.828 0.835
# bin=ward;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.95;ds=4;preClustering=T 26225 0.852 0.824
# bin=ward;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.95;ds=4;preClustering=T 777572 0.801 0.835
# bin=ward;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.95;ds=4;preClustering=T 288389 0.795 0.834
# bin=kmeans;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=4;preClustering=T
# bin=kmeans;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=4;preClustering=T 670487 0.837 0.839
# bin=kmeans;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=4;preClustering=T 116739 0.841 0.842
# bin=kmeans;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=4;preClustering=T 26225 0.838 0.838
# bin=kmeans;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=4;preClustering=T 777572 0.842 0.841
# bin=kmeans;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=4;preClustering=T 288389 0.838 0.841
# bin=GMM;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=4;preClustering=T
# bin=GMM;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=4;preClustering=T 670487 0.792 0.819
# bin=GMM;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=4;preClustering=T 116739 0.791 0.815
# bin=GMM;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=4;preClustering=T 26225 0.787 0.814
# bin=GMM;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=4;preClustering=T 777572 0.787 0.823
# bin=GMM;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=4;preClustering=T 288389 0.792 0.822
# bin=ward;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=4;preClustering=T
# bin=ward;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=4;preClustering=T 670487 0.858 0.816
# bin=ward;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=4;preClustering=T 116739 0.834 0.817
# bin=ward;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=4;preClustering=T 26225 0.839 0.827
# bin=ward;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=4;preClustering=T 777572 0.86 0.827
# bin=ward;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=4;preClustering=T 288389 0.855 0.81
# bin=kmeans;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.995;ds=4;preClustering=T
# bin=kmeans;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.995;ds=4;preClustering=T 670487 0.734 0.838
# bin=kmeans;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.995;ds=4;preClustering=T 116739 0.737 0.837
# bin=kmeans;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.995;ds=4;preClustering=T 26225 0.732 0.831
# bin=kmeans;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.995;ds=4;preClustering=T 777572 0.739 0.84
# bin=kmeans;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.995;ds=4;preClustering=T 288389 0.744 0.838
# bin=GMM;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.995;ds=4;preClustering=T
# bin=GMM;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.995;ds=4;preClustering=T 670487 0.724 0.818
# bin=GMM;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.995;ds=4;preClustering=T 116739 0.84 0.818
# bin=GMM;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.995;ds=4;preClustering=T 26225 0.841 0.82
# bin=GMM;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.995;ds=4;preClustering=T 777572 0.735 0.824
# bin=GMM;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.995;ds=4;preClustering=T 288389 0.748 0.822
# bin=ward;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.995;ds=4;preClustering=T
# bin=ward;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.995;ds=4;preClustering=T 670487 0.824 0.772
# bin=ward;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.995;ds=4;preClustering=T 116739 0.808 0.837
# bin=ward;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.995;ds=4;preClustering=T 26225 0.808 0.835
# bin=ward;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.995;ds=4;preClustering=T 777572 0.834 0.815
# bin=ward;pval=0.005;direction=BOTH;clust=WGCNA;dch=0.995;ds=4;preClustering=T 288389 0.81 0.79

# %% [markdown]
# ### Saving method performaces for all parameter combinations

# %%
pd.DataFrame.from_records(clustering_similarities).to_csv("UnPaSt_similarities.tsv",sep = "\t")
pd.DataFrame.from_records(subt_t).to_csv("UnPaSt_TCGA.tsv",sep = "\t")
pd.DataFrame.from_records(subt_m).to_csv("UnPaSt_METABRIC.tsv",sep = "\t")
#df = pd.read_csv("UnPaSt_TCGA.tsv",sep = "\t",index_col =0).groupby("parameters").agg("mean").sort_values(by= cl,ascending=False)
#df2 = pd.read_csv("UnPaSt_METABRIC.tsv",sep = "\t",index_col =0).groupby("parameters").agg("mean").sort_values(by= cl,ascending=False)

# %% [markdown]
# # 3. Selecting parameters for TCGA and METABRIC
# * max. performance for PAM50 classification
# * TCGA-BRCA = 0.852
# * METABRIC = 0.845

# %%
# TCGA-BRCA 
cl = "PAM50"
df = pd.DataFrame.from_records(subt_t).groupby("parameters").agg("mean")
df = df.sort_values(cl,ascending = False)
df.head(10)
# Out:
#                                                        PAM50  Intrinsic  \
# parameters
# bin=ward;pval=0.01;direction=UP-DOWN;clust=WGCN...  0.852806   0.818664
# bin=ward;pval=0.005;direction=UP-DOWN;clust=WGC...  0.852708   0.818569
# bin=ward;pval=0.05;direction=BOTH;clust=WGCNA;d...  0.852124   0.820628
# bin=ward;pval=0.01;direction=UP-DOWN;clust=WGCN...  0.852082   0.817968
# bin=ward;pval=0.05;direction=BOTH;clust=WGCNA;d...  0.851299   0.819054
# bin=ward;pval=0.05;direction=BOTH;clust=WGCNA;d...  0.850751   0.819123
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGC...  0.850690   0.817778
# bin=ward;pval=0.005;direction=UP-DOWN;clust=WGC...  0.850316   0.816273
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGC...  0.849503   0.816637
# bin=ward;pval=0.005;direction=UP-DOWN;clust=WGC...  0.849017   0.817501
#
#                                                     PAM50_AB    SCMOD2  \
# parameters
# bin=ward;pval=0.01;direction=UP-DOWN;clust=WGCN...  0.619256  0.667183
# bin=ward;pval=0.005;direction=UP-DOWN;clust=WGC...  0.612114  0.672083
# bin=ward;pval=0.05;direction=BOTH;clust=WGCNA;d...  0.618730  0.661658
# bin=ward;pval=0.01;direction=UP-DOWN;clust=WGCN...  0.617381  0.666309
# bin=ward;pval=0.05;direction=BOTH;clust=WGCNA;d...  0.617083  0.660899
# bin=ward;pval=0.05;direction=BOTH;clust=WGCNA;d...  0.624003  0.660449
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGC...  0.633483  0.674252
# bin=ward;pval=0.005;direction=UP-DOWN;clust=WGC...  0.612875  0.670878
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGC...  0.633765  0.674636
# bin=ward;pval=0.005;direction=UP-DOWN;clust=WGC...  0.617531  0.652607
#
#                                                          IHC   Luminal  \
# parameters
# bin=ward;pval=0.01;direction=UP-DOWN;clust=WGCN...  0.708085  0.912704
# bin=ward;pval=0.005;direction=UP-DOWN;clust=WGC...  0.706543  0.914291
# bin=ward;pval=0.05;direction=BOTH;clust=WGCNA;d...  0.724461  0.914427
# bin=ward;pval=0.01;direction=UP-DOWN;clust=WGCN...  0.707970  0.911593
# bin=ward;pval=0.05;direction=BOTH;clust=WGCNA;d...  0.704382  0.912378
# bin=ward;pval=0.05;direction=BOTH;clust=WGCNA;d...  0.716855  0.910201
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGC...  0.701811  0.917107
# bin=ward;pval=0.005;direction=UP-DOWN;clust=WGC...  0.706186  0.910563
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGC...  0.703406  0.915425
# bin=ward;pval=0.005;direction=UP-DOWN;clust=WGC...  0.714139  0.907314
#
#                                                        Basal      Her2  \
# parameters
# bin=ward;pval=0.01;direction=UP-DOWN;clust=WGCN...  0.946757  0.482270
# bin=ward;pval=0.005;direction=UP-DOWN;clust=WGC...  0.941046  0.482270
# bin=ward;pval=0.05;direction=BOTH;clust=WGCNA;d...  0.940465  0.479031
# bin=ward;pval=0.01;direction=UP-DOWN;clust=WGCN...  0.948596  0.482270
# bin=ward;pval=0.05;direction=BOTH;clust=WGCNA;d...  0.944388  0.482270
# bin=ward;pval=0.05;direction=BOTH;clust=WGCNA;d...  0.947265  0.482270
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGC...  0.929185  0.482478
# bin=ward;pval=0.005;direction=UP-DOWN;clust=WGC...  0.941046  0.482270
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGC...  0.929185  0.482478
# bin=ward;pval=0.005;direction=UP-DOWN;clust=WGC...  0.941947  0.491428
#
#                                                         LumA      LumB  ...  \
# parameters                                                              ...
# bin=ward;pval=0.01;direction=UP-DOWN;clust=WGCN...  0.668896  0.456727  ...
# bin=ward;pval=0.005;direction=UP-DOWN;clust=WGC...  0.674865  0.436289  ...
# bin=ward;pval=0.05;direction=BOTH;clust=WGCNA;d...  0.669067  0.458681  ...
# bin=ward;pval=0.01;direction=UP-DOWN;clust=WGCN...  0.665307  0.456727  ...
# bin=ward;pval=0.05;direction=BOTH;clust=WGCNA;d...  0.647710  0.475956  ...
# bin=ward;pval=0.05;direction=BOTH;clust=WGCNA;d...  0.663921  0.478168  ...
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGC...  0.718875  0.451254  ...
# bin=ward;pval=0.005;direction=UP-DOWN;clust=WGC...  0.674865  0.436289  ...
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGC...  0.719261  0.451248  ...
# bin=ward;pval=0.005;direction=UP-DOWN;clust=WGC...  0.673546  0.451109  ...
#
#                                                     Claudin-low  IHC_HER2  \
# parameters
# bin=ward;pval=0.01;direction=UP-DOWN;clust=WGCN...     0.119802  0.396739
# bin=ward;pval=0.005;direction=UP-DOWN;clust=WGC...     0.118305  0.396739
# bin=ward;pval=0.05;direction=BOTH;clust=WGCNA;d...     0.113962  0.391367
# bin=ward;pval=0.01;direction=UP-DOWN;clust=WGCN...     0.119200  0.396739
# bin=ward;pval=0.05;direction=BOTH;clust=WGCNA;d...     0.113962  0.396739
# bin=ward;pval=0.05;direction=BOTH;clust=WGCNA;d...     0.114287  0.396739
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGC...     0.120295  0.424035
# bin=ward;pval=0.005;direction=UP-DOWN;clust=WGC...     0.118305  0.396739
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGC...     0.120104  0.424035
# bin=ward;pval=0.005;direction=UP-DOWN;clust=WGC...     0.120538  0.403471
#
#                                                       IHC_ER    IHC_PR  \
# parameters
# bin=ward;pval=0.01;direction=UP-DOWN;clust=WGCN...  0.863619  0.782320
# bin=ward;pval=0.005;direction=UP-DOWN;clust=WGC...  0.863433  0.785107
# bin=ward;pval=0.05;direction=BOTH;clust=WGCNA;d...  0.867202  0.784839
# bin=ward;pval=0.01;direction=UP-DOWN;clust=WGCN...  0.863479  0.782235
# bin=ward;pval=0.05;direction=BOTH;clust=WGCNA;d...  0.863861  0.782256
# bin=ward;pval=0.05;direction=BOTH;clust=WGCNA;d...  0.867292  0.783678
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGC...  0.855934  0.786618
# bin=ward;pval=0.005;direction=UP-DOWN;clust=WGC...  0.862644  0.783256
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGC...  0.855259  0.785502
# bin=ward;pval=0.005;direction=UP-DOWN;clust=WGC...  0.861674  0.778864
#
#                                                     IHC_TNBC  NET_kmeans  \
# parameters
# bin=ward;pval=0.01;direction=UP-DOWN;clust=WGCN...  0.474118    0.663697
# bin=ward;pval=0.005;direction=UP-DOWN;clust=WGC...  0.472746    0.646916
# bin=ward;pval=0.05;direction=BOTH;clust=WGCNA;d...  0.470930    0.634428
# bin=ward;pval=0.01;direction=UP-DOWN;clust=WGCN...  0.473166    0.663697
# bin=ward;pval=0.05;direction=BOTH;clust=WGCNA;d...  0.473786    0.657962
# bin=ward;pval=0.05;direction=BOTH;clust=WGCNA;d...  0.470874    0.657962
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGC...  0.463306    0.327332
# bin=ward;pval=0.005;direction=UP-DOWN;clust=WGC...  0.472746    0.646916
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGC...  0.463306    0.331898
# bin=ward;pval=0.005;direction=UP-DOWN;clust=WGC...  0.470306    0.593159
#
#                                                     NET_ward      seed  run  \
# parameters
# bin=ward;pval=0.01;direction=UP-DOWN;clust=WGCN...  0.564650  375882.4  2.0
# bin=ward;pval=0.005;direction=UP-DOWN;clust=WGC...  0.584660  375882.4  2.0
# bin=ward;pval=0.05;direction=BOTH;clust=WGCNA;d...  0.562521  375882.4  2.0
# bin=ward;pval=0.01;direction=UP-DOWN;clust=WGCN...  0.564650  375882.4  2.0
# bin=ward;pval=0.05;direction=BOTH;clust=WGCNA;d...  0.551061  375882.4  2.0
# bin=ward;pval=0.05;direction=BOTH;clust=WGCNA;d...  0.551061  375882.4  2.0
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGC...  0.275547  375882.4  2.0
# bin=ward;pval=0.005;direction=UP-DOWN;clust=WGC...  0.584660  375882.4  2.0
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGC...  0.269751  375882.4  2.0
# bin=ward;pval=0.005;direction=UP-DOWN;clust=WGC...  0.542847  375882.4  2.0
#
#                                                         time
# parameters
# bin=ward;pval=0.01;direction=UP-DOWN;clust=WGCN...  0.015121
# bin=ward;pval=0.005;direction=UP-DOWN;clust=WGC...  0.015121
# bin=ward;pval=0.05;direction=BOTH;clust=WGCNA;d...  0.015121
# bin=ward;pval=0.01;direction=UP-DOWN;clust=WGCN...  0.015121
# bin=ward;pval=0.05;direction=BOTH;clust=WGCNA;d...  0.015121
# bin=ward;pval=0.05;direction=BOTH;clust=WGCNA;d...  0.015121
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGC...  0.015121
# bin=ward;pval=0.005;direction=UP-DOWN;clust=WGC...  0.015121
# bin=kmeans;pval=0.1;direction=UP-DOWN;clust=WGC...  0.015121
# bin=ward;pval=0.005;direction=UP-DOWN;clust=WGC...  0.015121
#
# [10 rows x 21 columns]

# %%
# METABRIC
df2 = pd.DataFrame.from_records(subt_m).groupby("parameters").agg("mean")
df2 = df2.sort_values(cl,ascending = False)
df2.head(10)
# Out:
#                                                        PAM50  Intrinsic  \
# parameters
# bin=kmeans;pval=0.05;direction=UP-DOWN;clust=WG...  0.845645   0.814071
# bin=kmeans;pval=0.05;direction=UP-DOWN;clust=WG...  0.845598   0.813851
# bin=kmeans;pval=0.05;direction=UP-DOWN;clust=WG...  0.845565   0.813987
# bin=kmeans;pval=0.05;direction=UP-DOWN;clust=WG...  0.845221   0.813657
# bin=kmeans;pval=0.05;direction=UP-DOWN;clust=WG...  0.843692   0.812269
# bin=kmeans;pval=0.005;direction=UP-DOWN;clust=W...  0.842902   0.811304
# bin=kmeans;pval=0.001;direction=UP-DOWN;clust=W...  0.842358   0.810780
# bin=kmeans;pval=0.005;direction=UP-DOWN;clust=W...  0.842341   0.810716
# bin=kmeans;pval=0.001;direction=UP-DOWN;clust=W...  0.841946   0.810344
# bin=kmeans;pval=0.01;direction=UP-DOWN;clust=WG...  0.840818   0.809557
#
#                                                     PAM50_AB    SCMOD2  \
# parameters
# bin=kmeans;pval=0.05;direction=UP-DOWN;clust=WG...  0.578241  0.614674
# bin=kmeans;pval=0.05;direction=UP-DOWN;clust=WG...  0.582768  0.603657
# bin=kmeans;pval=0.05;direction=UP-DOWN;clust=WG...  0.584253  0.603499
# bin=kmeans;pval=0.05;direction=UP-DOWN;clust=WG...  0.582303  0.608683
# bin=kmeans;pval=0.05;direction=UP-DOWN;clust=WG...  0.579321  0.620045
# bin=kmeans;pval=0.005;direction=UP-DOWN;clust=W...  0.563861  0.563194
# bin=kmeans;pval=0.001;direction=UP-DOWN;clust=W...  0.555466  0.551287
# bin=kmeans;pval=0.005;direction=UP-DOWN;clust=W...  0.558340  0.556616
# bin=kmeans;pval=0.001;direction=UP-DOWN;clust=W...  0.551577  0.544238
# bin=kmeans;pval=0.01;direction=UP-DOWN;clust=WG...  0.560380  0.579753
#
#                                                          IHC   Luminal  \
# parameters
# bin=kmeans;pval=0.05;direction=UP-DOWN;clust=WG...  0.763691  0.932988
# bin=kmeans;pval=0.05;direction=UP-DOWN;clust=WG...  0.740343  0.928953
# bin=kmeans;pval=0.05;direction=UP-DOWN;clust=WG...  0.742601  0.928953
# bin=kmeans;pval=0.05;direction=UP-DOWN;clust=WG...  0.754936  0.932988
# bin=kmeans;pval=0.05;direction=UP-DOWN;clust=WG...  0.779307  0.932129
# bin=kmeans;pval=0.005;direction=UP-DOWN;clust=W...  0.735630  0.926916
# bin=kmeans;pval=0.001;direction=UP-DOWN;clust=W...  0.707574  0.924308
# bin=kmeans;pval=0.005;direction=UP-DOWN;clust=W...  0.738771  0.927890
# bin=kmeans;pval=0.001;direction=UP-DOWN;clust=W...  0.728856  0.924471
# bin=kmeans;pval=0.01;direction=UP-DOWN;clust=WG...  0.784695  0.931479
#
#                                                        Basal      Her2  \
# parameters
# bin=kmeans;pval=0.05;direction=UP-DOWN;clust=WG...  0.869298  0.496223
# bin=kmeans;pval=0.05;direction=UP-DOWN;clust=WG...  0.863469  0.529044
# bin=kmeans;pval=0.05;direction=UP-DOWN;clust=WG...  0.863469  0.529044
# bin=kmeans;pval=0.05;direction=UP-DOWN;clust=WG...  0.864903  0.497984
# bin=kmeans;pval=0.05;direction=UP-DOWN;clust=WG...  0.868199  0.487593
# bin=kmeans;pval=0.005;direction=UP-DOWN;clust=W...  0.856946  0.526540
# bin=kmeans;pval=0.001;direction=UP-DOWN;clust=W...  0.853825  0.538730
# bin=kmeans;pval=0.005;direction=UP-DOWN;clust=W...  0.856946  0.515215
# bin=kmeans;pval=0.001;direction=UP-DOWN;clust=W...  0.852027  0.535004
# bin=kmeans;pval=0.01;direction=UP-DOWN;clust=WG...  0.858427  0.482719
#
#                                                         LumA      LumB  ...  \
# parameters                                                              ...
# bin=kmeans;pval=0.05;direction=UP-DOWN;clust=WG...  0.571114  0.553441  ...
# bin=kmeans;pval=0.05;direction=UP-DOWN;clust=WG...  0.571114  0.560592  ...
# bin=kmeans;pval=0.05;direction=UP-DOWN;clust=WG...  0.571114  0.560519  ...
# bin=kmeans;pval=0.05;direction=UP-DOWN;clust=WG...  0.571114  0.564405  ...
# bin=kmeans;pval=0.05;direction=UP-DOWN;clust=WG...  0.571114  0.559239  ...
# bin=kmeans;pval=0.005;direction=UP-DOWN;clust=W...  0.502493  0.568243  ...
# bin=kmeans;pval=0.001;direction=UP-DOWN;clust=W...  0.490893  0.551685  ...
# bin=kmeans;pval=0.005;direction=UP-DOWN;clust=W...  0.504145  0.554576  ...
# bin=kmeans;pval=0.001;direction=UP-DOWN;clust=W...  0.488168  0.544972  ...
# bin=kmeans;pval=0.01;direction=UP-DOWN;clust=WG...  0.508724  0.564797  ...
#
#                                                     Claudin-low  IHC_HER2  \
# parameters
# bin=kmeans;pval=0.05;direction=UP-DOWN;clust=WG...     0.160535  0.790270
# bin=kmeans;pval=0.05;direction=UP-DOWN;clust=WG...     0.160535  0.717883
# bin=kmeans;pval=0.05;direction=UP-DOWN;clust=WG...     0.160535  0.717883
# bin=kmeans;pval=0.05;direction=UP-DOWN;clust=WG...     0.160535  0.795081
# bin=kmeans;pval=0.05;direction=UP-DOWN;clust=WG...     0.160535  0.838778
# bin=kmeans;pval=0.005;direction=UP-DOWN;clust=W...     0.159590  0.727946
# bin=kmeans;pval=0.001;direction=UP-DOWN;clust=W...     0.160630  0.733361
# bin=kmeans;pval=0.005;direction=UP-DOWN;clust=W...     0.159590  0.754410
# bin=kmeans;pval=0.001;direction=UP-DOWN;clust=W...     0.161438  0.739655
# bin=kmeans;pval=0.01;direction=UP-DOWN;clust=WG...     0.160588  0.852329
#
#                                                       IHC_ER    IHC_PR  \
# parameters
# bin=kmeans;pval=0.05;direction=UP-DOWN;clust=WG...  0.936390  0.681838
# bin=kmeans;pval=0.05;direction=UP-DOWN;clust=WG...  0.929332  0.679421
# bin=kmeans;pval=0.05;direction=UP-DOWN;clust=WG...  0.929332  0.679421
# bin=kmeans;pval=0.05;direction=UP-DOWN;clust=WG...  0.936390  0.681838
# bin=kmeans;pval=0.05;direction=UP-DOWN;clust=WG...  0.938453  0.681908
# bin=kmeans;pval=0.005;direction=UP-DOWN;clust=W...  0.924472  0.674109
# bin=kmeans;pval=0.001;direction=UP-DOWN;clust=W...  0.920366  0.674554
# bin=kmeans;pval=0.005;direction=UP-DOWN;clust=W...  0.928042  0.675513
# bin=kmeans;pval=0.001;direction=UP-DOWN;clust=W...  0.923652  0.673320
# bin=kmeans;pval=0.01;direction=UP-DOWN;clust=WG...  0.939144  0.680764
#
#                                                     IHC_TNBC  NET_kmeans  \
# parameters
# bin=kmeans;pval=0.05;direction=UP-DOWN;clust=WG...  0.681682    0.791445
# bin=kmeans;pval=0.05;direction=UP-DOWN;clust=WG...  0.681682    0.706168
# bin=kmeans;pval=0.05;direction=UP-DOWN;clust=WG...  0.681682    0.706168
# bin=kmeans;pval=0.05;direction=UP-DOWN;clust=WG...  0.681682    0.706193
# bin=kmeans;pval=0.05;direction=UP-DOWN;clust=WG...  0.681682    0.791445
# bin=kmeans;pval=0.005;direction=UP-DOWN;clust=W...  0.675701    0.711591
# bin=kmeans;pval=0.001;direction=UP-DOWN;clust=W...  0.681761    0.710235
# bin=kmeans;pval=0.005;direction=UP-DOWN;clust=W...  0.675701    0.711591
# bin=kmeans;pval=0.001;direction=UP-DOWN;clust=W...  0.679707    0.707498
# bin=kmeans;pval=0.01;direction=UP-DOWN;clust=WG...  0.678733    0.786067
#
#                                                     NET_ward      seed  run  \
# parameters
# bin=kmeans;pval=0.05;direction=UP-DOWN;clust=WG...  0.636467  375882.4  2.0
# bin=kmeans;pval=0.05;direction=UP-DOWN;clust=WG...  0.496296  375882.4  2.0
# bin=kmeans;pval=0.05;direction=UP-DOWN;clust=WG...  0.496296  375882.4  2.0
# bin=kmeans;pval=0.05;direction=UP-DOWN;clust=WG...  0.496313  375882.4  2.0
# bin=kmeans;pval=0.05;direction=UP-DOWN;clust=WG...  0.636467  375882.4  2.0
# bin=kmeans;pval=0.005;direction=UP-DOWN;clust=W...  0.500036  375882.4  2.0
# bin=kmeans;pval=0.001;direction=UP-DOWN;clust=W...  0.499101  375882.4  2.0
# bin=kmeans;pval=0.005;direction=UP-DOWN;clust=W...  0.500036  375882.4  2.0
# bin=kmeans;pval=0.001;direction=UP-DOWN;clust=W...  0.497214  375882.4  2.0
# bin=kmeans;pval=0.01;direction=UP-DOWN;clust=WG...  0.627347  375882.4  2.0
#
#                                                         time
# parameters
# bin=kmeans;pval=0.05;direction=UP-DOWN;clust=WG...  0.047742
# bin=kmeans;pval=0.05;direction=UP-DOWN;clust=WG...  0.019611
# bin=kmeans;pval=0.05;direction=UP-DOWN;clust=WG...  0.020640
# bin=kmeans;pval=0.05;direction=UP-DOWN;clust=WG...  0.030309
# bin=kmeans;pval=0.05;direction=UP-DOWN;clust=WG...  0.066756
# bin=kmeans;pval=0.005;direction=UP-DOWN;clust=W...  0.018016
# bin=kmeans;pval=0.001;direction=UP-DOWN;clust=W...  0.017783
# bin=kmeans;pval=0.005;direction=UP-DOWN;clust=W...  0.020972
# bin=kmeans;pval=0.001;direction=UP-DOWN;clust=W...  0.022167
# bin=kmeans;pval=0.01;direction=UP-DOWN;clust=WG...  0.060760
#
# [10 rows x 21 columns]

# %% [markdown]
# # 4. Optimal parameters selection
#
# * minimal rank sum for TCGA and METABRIC

# %%
df["rank"] = range(df.shape[0])
df2["rank"] = range(df2.shape[0])
r = df["rank"]+df2["rank"]
r.sort_values().head(10)
# Out:
# parameters
# bin=kmeans;pval=0.01;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=3;preClustering=T      50
# bin=kmeans;pval=0.01;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=4;preClustering=T      53
# bin=kmeans;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=3;preClustering=T     60
# bin=kmeans;pval=0.05;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=3;preClustering=T      65
# bin=kmeans;pval=0.05;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=4;preClustering=T      67
# bin=kmeans;pval=0.005;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=4;preClustering=T     71
# bin=kmeans;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=4;preClustering=T     94
# bin=kmeans;pval=0.001;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=3;preClustering=T    103
# bin=kmeans;pval=0.01;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=2;preClustering=T     104
# bin=kmeans;pval=0.01;direction=UP-DOWN;clust=WGCNA;dch=0.95;ds=3;preClustering=T      116
# Name: rank, dtype: int64

# %% [markdown]
# ### Performance with selected parameters only slightly decreases compared to best performance

# %%
params = r.sort_values().index[0]
print(params)
df.loc[[params],:]
# Out:
# bin=kmeans;pval=0.01;direction=UP-DOWN;clust=WGCNA;dch=0.995;ds=3;preClustering=T
#                                                        PAM50  Intrinsic  \
# parameters
# bin=kmeans;pval=0.01;direction=UP-DOWN;clust=WG...  0.841306   0.809262
#
#                                                     PAM50_AB    SCMOD2  \
# parameters
# bin=kmeans;pval=0.01;direction=UP-DOWN;clust=WG...  0.631223  0.662526
#
#                                                          IHC  Luminal  \
# parameters
# bin=kmeans;pval=0.01;direction=UP-DOWN;clust=WG...  0.710483  0.89918
#
#                                                        Basal      Her2  \
# parameters
# bin=kmeans;pval=0.01;direction=UP-DOWN;clust=WG...  0.945687  0.475058
#
#                                                         LumA      LumB  ...  \
# parameters                                                              ...
# bin=kmeans;pval=0.01;direction=UP-DOWN;clust=WG...  0.689499  0.473313  ...
#
#                                                     IHC_HER2    IHC_ER  \
# parameters
# bin=kmeans;pval=0.01;direction=UP-DOWN;clust=WG...  0.417338  0.864536
#
#                                                       IHC_PR  IHC_TNBC  \
# parameters
# bin=kmeans;pval=0.01;direction=UP-DOWN;clust=WG...  0.778363  0.471613
#
#                                                     NET_kmeans  NET_ward  \
# parameters
# bin=kmeans;pval=0.01;direction=UP-DOWN;clust=WG...     0.43055  0.351626
#
#                                                         seed  run      time  \
# parameters
# bin=kmeans;pval=0.01;direction=UP-DOWN;clust=WG...  375882.4  2.0  0.015121
#
#                                                     rank
# parameters
# bin=kmeans;pval=0.01;direction=UP-DOWN;clust=WG...    40
#
# [1 rows x 22 columns]

# %%
df2.loc[[params],:]
# Out:
#                                                        PAM50  Intrinsic  \
# parameters
# bin=kmeans;pval=0.01;direction=UP-DOWN;clust=WG...  0.840732   0.809425
#
#                                                     PAM50_AB    SCMOD2  \
# parameters
# bin=kmeans;pval=0.01;direction=UP-DOWN;clust=WG...  0.561267  0.578005
#
#                                                          IHC   Luminal  \
# parameters
# bin=kmeans;pval=0.01;direction=UP-DOWN;clust=WG...  0.777367  0.931168
#
#                                                        Basal      Her2  \
# parameters
# bin=kmeans;pval=0.01;direction=UP-DOWN;clust=WG...  0.857924  0.482644
#
#                                                         LumA      LumB  ...  \
# parameters                                                              ...
# bin=kmeans;pval=0.01;direction=UP-DOWN;clust=WG...  0.506047  0.569946  ...
#
#                                                     IHC_HER2    IHC_ER  \
# parameters
# bin=kmeans;pval=0.01;direction=UP-DOWN;clust=WG...  0.857478  0.938055
#
#                                                      IHC_PR  IHC_TNBC  \
# parameters
# bin=kmeans;pval=0.01;direction=UP-DOWN;clust=WG...  0.68035  0.678733
#
#                                                     NET_kmeans  NET_ward  \
# parameters
# bin=kmeans;pval=0.01;direction=UP-DOWN;clust=WG...     0.77201  0.597819
#
#                                                         seed  run      time  \
# parameters
# bin=kmeans;pval=0.01;direction=UP-DOWN;clust=WG...  375882.4  2.0  0.038138
#
#                                                     rank
# parameters
# bin=kmeans;pval=0.01;direction=UP-DOWN;clust=WG...    10
#
# [1 rows x 22 columns]

# %% [markdown]
# ### Similarities of (bi)clusters in TCGA and METABRIC

# %%
#s = pd.read_csv("UnPaSt_similarities.tsv",sep = "\t",index_col=0).groupby("parameters").agg("mean")
s = pd.DataFrame.from_records(clustering_similarities).groupby("parameters").agg("mean")
s["avg_percent_matched"] = (s["percent_matched_1"]+s["percent_matched_2"])*0.5
s.sort_values(by = "avg_percent_matched",ascending = False)
# Out:
#                                                       n_1    n_2  \
# parameters
# bin=kmeans;pval=0.005;direction=UP-DOWN;clust=W...   44.8   51.0
# bin=kmeans;pval=0.005;direction=BOTH;clust=WGCN...   35.4   61.8
# bin=kmeans;pval=0.005;direction=UP-DOWN;clust=W...   68.4   62.2
# bin=kmeans;pval=0.01;direction=BOTH;clust=WGCNA...   40.4   66.0
# bin=ward;pval=0.005;direction=BOTH;clust=WGCNA;...   37.0   70.8
# ...                                                   ...    ...
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA...  483.6  421.8
# bin=ward;pval=0.05;direction=UP-DOWN;clust=WGCN...  428.6  386.6
# bin=ward;pval=0.001;direction=BOTH;clust=WGCNA;...  214.2  240.6
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dc...  429.6  351.2
# bin=ward;pval=0.05;direction=BOTH;clust=WGCNA;d...  358.4  221.4
#
#                                                     percent_matched_1  \
# parameters
# bin=kmeans;pval=0.005;direction=UP-DOWN;clust=W...           0.544970
# bin=kmeans;pval=0.005;direction=BOTH;clust=WGCN...           0.576392
# bin=kmeans;pval=0.005;direction=UP-DOWN;clust=W...           0.485745
# bin=kmeans;pval=0.01;direction=BOTH;clust=WGCNA...           0.533764
# bin=ward;pval=0.005;direction=BOTH;clust=WGCNA;...           0.597559
# ...                                                               ...
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA...           0.161696
# bin=ward;pval=0.05;direction=UP-DOWN;clust=WGCN...           0.161072
# bin=ward;pval=0.001;direction=BOTH;clust=WGCNA;...           0.149559
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dc...           0.143510
# bin=ward;pval=0.05;direction=BOTH;clust=WGCNA;d...           0.114463
#
#                                                     percent_matched_2  \
# parameters
# bin=kmeans;pval=0.005;direction=UP-DOWN;clust=W...           0.573866
# bin=kmeans;pval=0.005;direction=BOTH;clust=WGCN...           0.528918
# bin=kmeans;pval=0.005;direction=UP-DOWN;clust=W...           0.576198
# bin=kmeans;pval=0.01;direction=BOTH;clust=WGCNA...           0.514946
# bin=ward;pval=0.005;direction=BOTH;clust=WGCNA;...           0.442186
# ...                                                               ...
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA...           0.198435
# bin=ward;pval=0.05;direction=UP-DOWN;clust=WGCN...           0.189657
# bin=ward;pval=0.001;direction=BOTH;clust=WGCNA;...           0.195537
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dc...           0.194139
# bin=ward;pval=0.05;direction=BOTH;clust=WGCNA;d...           0.220487
#
#                                                     n_shared_genes_1  \
# parameters
# bin=kmeans;pval=0.005;direction=UP-DOWN;clust=W...             293.0
# bin=kmeans;pval=0.005;direction=BOTH;clust=WGCN...             168.4
# bin=kmeans;pval=0.005;direction=UP-DOWN;clust=W...             302.6
# bin=kmeans;pval=0.01;direction=BOTH;clust=WGCNA...             186.6
# bin=ward;pval=0.005;direction=BOTH;clust=WGCNA;...             191.8
# ...                                                              ...
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA...             282.2
# bin=ward;pval=0.05;direction=UP-DOWN;clust=WGCN...             246.2
# bin=ward;pval=0.001;direction=BOTH;clust=WGCNA;...             159.8
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dc...             213.6
# bin=ward;pval=0.05;direction=BOTH;clust=WGCNA;d...             132.2
#
#                                                     avg_bm_J_1  \
# parameters
# bin=kmeans;pval=0.005;direction=UP-DOWN;clust=W...    0.171955
# bin=kmeans;pval=0.005;direction=BOTH;clust=WGCN...    0.157806
# bin=kmeans;pval=0.005;direction=UP-DOWN;clust=W...    0.167821
# bin=kmeans;pval=0.01;direction=BOTH;clust=WGCNA...    0.160966
# bin=ward;pval=0.005;direction=BOTH;clust=WGCNA;...    0.146806
# ...                                                        ...
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA...    0.250113
# bin=ward;pval=0.05;direction=UP-DOWN;clust=WGCN...    0.236848
# bin=ward;pval=0.001;direction=BOTH;clust=WGCNA;...    0.222312
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dc...    0.302687
# bin=ward;pval=0.05;direction=BOTH;clust=WGCNA;d...    0.290246
#
#                                                     n_shared_genes_2  \
# parameters
# bin=kmeans;pval=0.005;direction=UP-DOWN;clust=W...             314.2
# bin=kmeans;pval=0.005;direction=BOTH;clust=WGCN...             246.4
# bin=kmeans;pval=0.005;direction=UP-DOWN;clust=W...             319.0
# bin=kmeans;pval=0.01;direction=BOTH;clust=WGCNA...             261.2
# bin=ward;pval=0.005;direction=BOTH;clust=WGCNA;...             233.2
# ...                                                              ...
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA...             303.8
# bin=ward;pval=0.05;direction=UP-DOWN;clust=WGCN...             276.2
# bin=ward;pval=0.001;direction=BOTH;clust=WGCNA;...             218.0
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dc...             246.0
# bin=ward;pval=0.05;direction=BOTH;clust=WGCNA;d...             158.8
#
#                                                     avg_bm_J_2      seed  run  \
# parameters
# bin=kmeans;pval=0.005;direction=UP-DOWN;clust=W...    0.150679  375882.4  2.0
# bin=kmeans;pval=0.005;direction=BOTH;clust=WGCN...    0.113102  375882.4  2.0
# bin=kmeans;pval=0.005;direction=UP-DOWN;clust=W...    0.160051  375882.4  2.0
# bin=kmeans;pval=0.01;direction=BOTH;clust=WGCNA...    0.114310  375882.4  2.0
# bin=ward;pval=0.005;direction=BOTH;clust=WGCNA;...    0.114953  375882.4  2.0
# ...                                                        ...       ...  ...
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA...    0.243000  375882.4  2.0
# bin=ward;pval=0.05;direction=UP-DOWN;clust=WGCN...    0.233937  375882.4  2.0
# bin=ward;pval=0.001;direction=BOTH;clust=WGCNA;...    0.174894  375882.4  2.0
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dc...    0.292358  375882.4  2.0
# bin=ward;pval=0.05;direction=BOTH;clust=WGCNA;d...    0.263677  375882.4  2.0
#
#                                                     avg_percent_matched
# parameters
# bin=kmeans;pval=0.005;direction=UP-DOWN;clust=W...             0.559418
# bin=kmeans;pval=0.005;direction=BOTH;clust=WGCN...             0.552655
# bin=kmeans;pval=0.005;direction=UP-DOWN;clust=W...             0.530972
# bin=kmeans;pval=0.01;direction=BOTH;clust=WGCNA...             0.524355
# bin=ward;pval=0.005;direction=BOTH;clust=WGCNA;...             0.519873
# ...                                                                 ...
# bin=ward;pval=0.1;direction=UP-DOWN;clust=WGCNA...             0.180065
# bin=ward;pval=0.05;direction=UP-DOWN;clust=WGCN...             0.175365
# bin=ward;pval=0.001;direction=BOTH;clust=WGCNA;...             0.172548
# bin=ward;pval=0.1;direction=BOTH;clust=WGCNA;dc...             0.168825
# bin=ward;pval=0.05;direction=BOTH;clust=WGCNA;d...             0.167475
#
# [540 rows x 11 columns]

# %%
s.loc[[params],:]
# Out:
#                                                       n_1    n_2  \
# parameters
# bin=kmeans;pval=0.01;direction=UP-DOWN;clust=WG...  171.8  161.2
#
#                                                     percent_matched_1  \
# parameters
# bin=kmeans;pval=0.01;direction=UP-DOWN;clust=WG...           0.354259
#
#                                                     percent_matched_2  \
# parameters
# bin=kmeans;pval=0.01;direction=UP-DOWN;clust=WG...           0.378438
#
#                                                     n_shared_genes_1  \
# parameters
# bin=kmeans;pval=0.01;direction=UP-DOWN;clust=WG...             237.4
#
#                                                     avg_bm_J_1  \
# parameters
# bin=kmeans;pval=0.01;direction=UP-DOWN;clust=WG...    0.202671
#
#                                                     n_shared_genes_2  \
# parameters
# bin=kmeans;pval=0.01;direction=UP-DOWN;clust=WG...             263.8
#
#                                                     avg_bm_J_2      seed  run  \
# parameters
# bin=kmeans;pval=0.01;direction=UP-DOWN;clust=WG...    0.199374  375882.4  2.0
#
#                                                     avg_percent_matched
# parameters
# bin=kmeans;pval=0.01;direction=UP-DOWN;clust=WG...             0.366349
