# %%
import numpy as np
import pandas as pd
import sys,os
import random
import copy
from time import time

import matplotlib.pyplot as plt
import seaborn as sns

from utils.method import read_bic_table

from utils.eval import find_best_matches, make_known_groups, make_ref_groups
from utils.eval import calculate_perfromance, compare_gene_clusters

# %%
classifications={"Intrinsic":["Luminal","Basal","Her2","Normal","Claudin-low"],
                "SCMOD2":["ER-/HER2-","ER+/HER2- Low Prolif","ER+/HER2- High Prolif","HER2+"],
                "IHC":["IHC_TNBC","IHC_ER","IHC_HER2","IHC_PR"]}

exprs_file_t = "data/preprocessed_v6/TCGA-BRCA_1079_17Kgenes.Xena_TCGA_PanCan.log2_exprs_z_v6.tsv"
basename_t = "TCGA"

exprs_file_m = "data/preprocessed_v6/METABRIC_1904_17Kgenes.log2_exprs_z_v6.tsv"
basename_m = "METABRIC" 

m_subtypes = pd.read_csv("data/preprocessed_v6/METABRIC_1904_17Kgenes.subtypes_and_signatures_v6.tsv",sep = "\t",index_col=0)
m_annotation = pd.read_csv("data/preprocessed_v6/METABRIC_1904.annotation_v6.tsv",sep = "\t",index_col=0)

t_subtypes = pd.read_csv("data/preprocessed_v6/TCGA-BRCA_1079_17Kgenes.Xena_TCGA_PanCan.subtypes_and_signatures_v6.tsv",sep = "\t",index_col=0)
t_annotation = pd.read_csv("data/preprocessed_v6/TCGA-BRCA_1079.Xena_TCGA_PanCan.annotation_v6.tsv",sep = "\t",index_col=0)


exprs_t= pd.read_csv(exprs_file_t,sep = "\t",index_col=0)
exprs_t[exprs_t>3] = 3
exprs_t[exprs_t<-3] = -3

exprs_m= pd.read_csv(exprs_file_m,sep = "\t",index_col=0)
exprs_m[exprs_m>3] = 3
exprs_m[exprs_m<-3] = -3


known_groups_t, freqs_t = make_ref_groups(t_subtypes, t_annotation,exprs_t)
known_groups_m, freqs_m = make_ref_groups(m_subtypes, m_annotation,exprs_m)

# %%
n_runs = 5
seeds = []
random.seed(42)
for i in range(n_runs):
    seeds.append(random.randint(0,1000000))
print("generate ",n_runs," seeds",seeds)
# Out:
# generate  5  seeds [670487, 116739, 26225, 777572, 288389]

# %%
subt_t = []
subt_m = []
clustering_similarities = []

pvals = [0.0001, 0.0005,0.005,0.001,0.01,0.05]
bin_methods = ["kmeans","GMM","ward"]

# %%
from run_desmond import run_DESMOND

# %%
### Louvain 
out_dir= "results_on_real_data/"
modularities = [0,0.3,0.4,0.5,0.6,0.7,0.8,0.9]

subt_t = []
subt_m = []
clustering_similarities = []
for run in range(n_runs):
    seed = seeds[run]
    for pval in pvals:
        for bin_method in bin_methods:
            for m in modularities:
                #print("run",run,bin_method,pval,m,seed)
                
                # save parameters as a ;-separated string
                params = "bin="+bin_method+";pval="+str(pval)
                params += ";clust="+"Louvain"+";m="+str(m)
                params_dict = {"parameters":params, "seed":seed,"run":run}
                
                ### running TCGA or reading results
                try:
                    t0 = time()
                    fname = out_dir+basename_t+".seed="+str(seed)+\
                    ".bin="+bin_method +",pval="+str(pval)+",clust=Louvain"+",m="+str(m)+".biclusters.tsv"
                    result_t = read_bic_table(fname)
                    """result_t = run_DESMOND(exprs_file_t, basename_t, out_dir=out_dir,
                                                save=True, load = True,
                                                ceiling = 3,
                                                min_n_samples = 5,
                                                bin_method = bin_method, pval = pval,
                                                clust_method = "Louvain",
                                                similarity_cutoffs = similarity_cutoffs,
                                                seed = seed,
                                                verbose = False)"""
                    time_t = time()-t0
                    # find the best matches between TCGA biclusters and subtypes
                    # and calculate overall performance == weighted sum of Jaccard indexes
                    performance_t = calculate_perfromance(result_t, known_groups_t,
                                                          freqs_t, set(exprs_t.columns.values),
                                                          classifications=classifications)
                    performance_t.update(params_dict)
                    performance_t["time"] = time_t
                    subt_t.append(performance_t)
                    t_failed = False
                except:
                    print("TCGA biclustering failed with ",seed,  pval,bin_method ,file = sys.stderr)
                    print(fname)
                    t_failed = True
                    subt_t.append({params_dict})
                
                ### running METABRIC or reading results
                try:
                    t0 = time()
                    fname = out_dir+basename_m+".seed="+str(seed)+\
                    ".bin="+bin_method +",pval="+str(pval)+",clust=Louvain"+",m="+str(m)+".biclusters.tsv"
                    result_m = read_bic_table(fname)
                    """result_m = run_DESMOND(exprs_file_m, basename_m, out_dir=out_dir,
                                                save=True, load = True,
                                                ceiling = 3,
                                                min_n_samples = 5,
                                                bin_method = bin_method, pval = pval,
                                                clust_method = "Louvain",
                                                similarity_cutoffs = similarity_cutoffs,
                                                seed = seed,
                                                verbose = False)"""
                    time_m = time()-t0
                    # find the best matches between METABRIC biclusters and subtypes
                    # and calculate overall performance == weighted sum of Jaccard indexes
                    performance_m = calculate_perfromance(result_m, known_groups_m,
                                                          freqs_m, set(exprs_m.columns.values),
                                                          classifications=classifications)
                    performance_m.update(params_dict)
                    performance_m["time"] = time_m
                    subt_m.append(performance_m)
                    m_failed = False
                except:
                    print("METABRIC biclustering failed with ",seed,  pval,bin_method ,file = sys.stderr)
                    print(fname)
                    m_failed = True
                    subt_m.append(params_dict)
                    
                # compare clustering results - only if gene sets are defined for each cluster
                if not (t_failed or m_failed): 
                    N = exprs_m.shape[0]
                    clust_sim, bm, bm2 = compare_gene_clusters(result_t,result_m, N)                    
                else:
                    clust_sim = {}
                clust_sim.update(params_dict)
                clustering_similarities.append(clust_sim)

# %%
out_dir = "results_on_real_data_WGCNA/"
### WGCNA
ds_values = [0,1,2,3,4]
dch = 0.995

for run in range(n_runs):
    seed = seeds[run]
    for pval in pvals:
        for bin_method in bin_methods:
            for ds in ds_values:
                
                # save parameters as a ;-separated string
                params = "bin="+bin_method+";pval="+str(pval)
                params += ";clust="+"WGCNA"+";ds="+str(ds)+";dch="+str(dch)
                #print("run",run,seed,params)
                params_dict = {"parameters":params, "seed":seed,"run":run}
                
                ### running TCGA or reading results
                try:
                    t0 = time()
                    fname = out_dir+basename_t+".seed="+str(seed)+".bin="+bin_method \
                    +",pval="+str(pval)+",clust=WGCNA"+",ds="+str(ds)+",dch="+str(dch)+".biclusters.tsv"
                    result_t = read_bic_table(fname)
                    """result_t = run_DESMOND(exprs_file_t, basename_t, out_dir=out_dir,
                                                save=True, load = True,
                                                ceiling = 3,
                                                min_n_samples = 5,
                                                bin_method = bin_method, pval = pval,
                                                clust_method = "WGCNA",
                                                ds = ds, dch  = dch,
                                                #similarity_cutoffs = similarity_cutoffs,
                                                seed = seed,
                                                verbose = False)"""
                    time_t = time()-t0
                    # find the best matches between TCGA biclusters and subtypes
                    # and calculate overall performance == weighted sum of Jaccard indexes
                    performance_t = calculate_perfromance(result_t, known_groups_t,
                                                          freqs_t, set(exprs_t.columns.values),
                                                          classifications=classifications)
                    performance_t.update(params_dict)
                    performance_t["time"] = time_t
                    subt_t.append(performance_t)
                    t_failed = False
                except:
                    print("TCGA biclustering failed with ",seed,  pval,bin_method ,file = sys.stderr)
                    print(fname)
                    t_failed = True
                    subt_t.append({params_dict})
                
                ### running METABRIC or reading results
                try:
                    t0 = time()
                    fname = out_dir+basename_m+".seed="+str(seed)+".bin="+bin_method \
                    +",pval="+str(pval)+",clust=WGCNA"+",ds="+str(ds)+",dch="+str(dch)+".biclusters.tsv"
                    result_m = read_bic_table(fname)
                    """result_m = run_DESMOND(exprs_file_m, basename_m, out_dir=out_dir,
                                                save=True, load = True,
                                                ceiling = 3,
                                                min_n_samples = 5,
                                                bin_method = bin_method, pval = pval,
                                                clust_method = "WGCNA",
                                                ds = ds, dch  = dch,
                                                #similarity_cutoffs = similarity_cutoffs,
                                                seed = seed,
                                                verbose = False)"""
                    time_m = time()-t0
                    # find the best matches between METABRIC biclusters and subtypes
                    # and calculate overall performance == weighted sum of Jaccard indexes
                    performance_m = calculate_perfromance(result_m, known_groups_m,
                                                          freqs_m, set(exprs_m.columns.values),
                                                          classifications=classifications)
                    performance_m.update(params_dict)
                    performance_m["time"] = time_m
                    subt_m.append(performance_m)
                    m_failed = False
                except:
                    print("METABRIC biclustering failed with ",seed,  pval,bin_method,file = sys.stderr)
                    print(fname)
                    m_failed = True
                    subt_m.append(params_dict)
                    
                # compare clustering results - only if gene sets are defined for each cluster
                if not (t_failed or m_failed): 
                    N = exprs_m.shape[0]
                    clust_sim, bm, bm2 = compare_gene_clusters(result_t,result_m, N)
                    
                    
                else:
                    clust_sim = {}
                clust_sim.update(params_dict)
                clustering_similarities.append(clust_sim)

# %%
df = pd.DataFrame.from_records(subt_t).groupby("parameters").agg("mean").sort_values("overall_performance_Intrinsic",ascending = False)
df.head(10)
# Out:
#                                                Basal      LumA      Her2  \
# parameters
# bin=ward;pval=0.0005;clust=Louvain;m=0.9    0.950249  0.673546  0.480769
# bin=ward;pval=0.005;clust=Louvain;m=0.6     0.953000  0.580247  0.492647
# bin=ward;pval=0.0001;clust=Louvain;m=0.7    0.949749  0.603748  0.492647
# bin=ward;pval=0.0005;clust=Louvain;m=0.6    0.944724  0.641405  0.478261
# bin=ward;pval=0.05;clust=Louvain;m=0.6      0.945455  0.703397  0.492647
# bin=kmeans;pval=0.0001;clust=Louvain;m=0.6  0.937576  0.606481  0.477803
# bin=kmeans;pval=0.001;clust=Louvain;m=0.7   0.938077  0.619340  0.477803
# bin=kmeans;pval=0.0005;clust=Louvain;m=0.7  0.936879  0.617115  0.477803
# bin=ward;pval=0.001;clust=Louvain;m=0.5     0.949444  0.568162  0.478261
# bin=ward;pval=0.01;clust=Louvain;m=0.4      0.949495  0.661342  0.478261
#
#                                                 LumB    Normal   Luminal  \
# parameters
# bin=ward;pval=0.0005;clust=Louvain;m=0.9    0.431694  0.103878  0.920398
# bin=ward;pval=0.005;clust=Louvain;m=0.6     0.464988  0.094164  0.918184
# bin=ward;pval=0.0001;clust=Louvain;m=0.7    0.410673  0.088888  0.916049
# bin=ward;pval=0.0005;clust=Louvain;m=0.6    0.457088  0.105642  0.918388
# bin=ward;pval=0.05;clust=Louvain;m=0.6      0.465157  0.070904  0.914730
# bin=kmeans;pval=0.0001;clust=Louvain;m=0.6  0.464504  0.063948  0.918403
# bin=kmeans;pval=0.001;clust=Louvain;m=0.7   0.480190  0.121951  0.914608
# bin=kmeans;pval=0.0005;clust=Louvain;m=0.7  0.479489  0.119681  0.914385
# bin=ward;pval=0.001;clust=Louvain;m=0.5     0.441550  0.120482  0.909414
# bin=ward;pval=0.01;clust=Louvain;m=0.4      0.411705  0.121172  0.909045
#
#                                             Claudin-low  ER-/HER2-     HER2+  \
# parameters
# bin=ward;pval=0.0005;clust=Louvain;m=0.9       0.125581   0.860987  0.780488
# bin=ward;pval=0.005;clust=Louvain;m=0.6        0.121156   0.863063  0.854369
# bin=ward;pval=0.0001;clust=Louvain;m=0.7       0.117371   0.851617  0.854369
# bin=ward;pval=0.0005;clust=Louvain;m=0.6       0.117925   0.846847  0.846154
# bin=ward;pval=0.05;clust=Louvain;m=0.6         0.118935   0.847059  0.854369
# bin=kmeans;pval=0.0001;clust=Louvain;m=0.6     0.118838   0.861514  0.795680
# bin=kmeans;pval=0.001;clust=Louvain;m=0.7      0.118415   0.850774  0.795680
# bin=kmeans;pval=0.0005;clust=Louvain;m=0.7     0.118148   0.845720  0.795680
# bin=ward;pval=0.001;clust=Louvain;m=0.5        0.118712   0.853545  0.846154
# bin=ward;pval=0.01;clust=Louvain;m=0.4         0.118483   0.850679  0.846154
#
#                                             ER+/HER2- Low Prolif  ...  \
# parameters                                                        ...
# bin=ward;pval=0.0005;clust=Louvain;m=0.9                0.661972  ...
# bin=ward;pval=0.005;clust=Louvain;m=0.6                 0.520532  ...
# bin=ward;pval=0.0001;clust=Louvain;m=0.7                0.552818  ...
# bin=ward;pval=0.0005;clust=Louvain;m=0.6                0.657258  ...
# bin=ward;pval=0.05;clust=Louvain;m=0.6                  0.740938  ...
# bin=kmeans;pval=0.0001;clust=Louvain;m=0.6              0.521117  ...
# bin=kmeans;pval=0.001;clust=Louvain;m=0.7               0.544030  ...
# bin=kmeans;pval=0.0005;clust=Louvain;m=0.7              0.537536  ...
# bin=ward;pval=0.001;clust=Louvain;m=0.5                 0.506814  ...
# bin=ward;pval=0.01;clust=Louvain;m=0.4                  0.625537  ...
#
#                                               IHC_ER    IHC_PR  IHC_TNBC  \
# parameters
# bin=ward;pval=0.0005;clust=Louvain;m=0.9    0.865407  0.755864  0.466981
# bin=ward;pval=0.005;clust=Louvain;m=0.6     0.863274  0.754050  0.463245
# bin=ward;pval=0.0001;clust=Louvain;m=0.7    0.866040  0.750361  0.468257
# bin=ward;pval=0.0005;clust=Louvain;m=0.6    0.863587  0.749572  0.469156
# bin=ward;pval=0.05;clust=Louvain;m=0.6      0.862983  0.749868  0.475269
# bin=kmeans;pval=0.0001;clust=Louvain;m=0.6  0.867627  0.739713  0.469258
# bin=kmeans;pval=0.001;clust=Louvain;m=0.7   0.870372  0.741531  0.476031
# bin=kmeans;pval=0.0005;clust=Louvain;m=0.7  0.871082  0.746729  0.479190
# bin=ward;pval=0.001;clust=Louvain;m=0.5     0.863367  0.747712  0.469118
# bin=ward;pval=0.01;clust=Louvain;m=0.4      0.858154  0.757744  0.473430
#
#                                             IHC_HER2  \
# parameters
# bin=ward;pval=0.0005;clust=Louvain;m=0.9    0.423469
# bin=ward;pval=0.005;clust=Louvain;m=0.6     0.394444
# bin=ward;pval=0.0001;clust=Louvain;m=0.7    0.394444
# bin=ward;pval=0.0005;clust=Louvain;m=0.6    0.392265
# bin=ward;pval=0.05;clust=Louvain;m=0.6      0.394444
# bin=kmeans;pval=0.0001;clust=Louvain;m=0.6  0.420287
# bin=kmeans;pval=0.001;clust=Louvain;m=0.7   0.420287
# bin=kmeans;pval=0.0005;clust=Louvain;m=0.7  0.420287
# bin=ward;pval=0.001;clust=Louvain;m=0.5     0.392265
# bin=ward;pval=0.01;clust=Louvain;m=0.4      0.392265
#
#                                             overall_performance_Intrinsic  \
# parameters
# bin=ward;pval=0.0005;clust=Louvain;m=0.9                         0.828268
# bin=ward;pval=0.005;clust=Louvain;m=0.6                          0.827967
# bin=ward;pval=0.0001;clust=Louvain;m=0.7                         0.825688
# bin=ward;pval=0.0005;clust=Louvain;m=0.6                         0.825481
# bin=ward;pval=0.05;clust=Louvain;m=0.6                           0.823621
# bin=kmeans;pval=0.0001;clust=Louvain;m=0.6                       0.823057
# bin=kmeans;pval=0.001;clust=Louvain;m=0.7                        0.822266
# bin=kmeans;pval=0.0005;clust=Louvain;m=0.7                       0.821835
# bin=ward;pval=0.001;clust=Louvain;m=0.5                          0.820814
# bin=ward;pval=0.01;clust=Louvain;m=0.4                           0.820589
#
#                                             overall_performance_SCMOD2  \
# parameters
# bin=ward;pval=0.0005;clust=Louvain;m=0.9                      0.644551
# bin=ward;pval=0.005;clust=Louvain;m=0.6                       0.607545
# bin=ward;pval=0.0001;clust=Louvain;m=0.7                      0.612192
# bin=ward;pval=0.0005;clust=Louvain;m=0.6                      0.647384
# bin=ward;pval=0.05;clust=Louvain;m=0.6                        0.683741
# bin=kmeans;pval=0.0001;clust=Louvain;m=0.6                    0.613688
# bin=kmeans;pval=0.001;clust=Louvain;m=0.7                     0.626807
# bin=kmeans;pval=0.0005;clust=Louvain;m=0.7                    0.623006
# bin=ward;pval=0.001;clust=Louvain;m=0.5                       0.598334
# bin=ward;pval=0.01;clust=Louvain;m=0.4                        0.639422
#
#                                             overall_performance_IHC      seed  \
# parameters
# bin=ward;pval=0.0005;clust=Louvain;m=0.9                   0.756246  375882.4
# bin=ward;pval=0.005;clust=Louvain;m=0.6                    0.751696  375882.4
# bin=ward;pval=0.0001;clust=Louvain;m=0.7                   0.751839  375882.4
# bin=ward;pval=0.0005;clust=Louvain;m=0.6                   0.750283  375882.4
# bin=ward;pval=0.05;clust=Louvain;m=0.6                     0.750726  375882.4
# bin=kmeans;pval=0.0001;clust=Louvain;m=0.6                 0.750804  375882.4
# bin=kmeans;pval=0.001;clust=Louvain;m=0.7                  0.753206  375882.4
# bin=kmeans;pval=0.0005;clust=Louvain;m=0.7                 0.755766  375882.4
# bin=ward;pval=0.001;clust=Louvain;m=0.5                    0.749454  375882.4
# bin=ward;pval=0.01;clust=Louvain;m=0.4                     0.751298  375882.4
#
#                                             run      time
# parameters
# bin=ward;pval=0.0005;clust=Louvain;m=0.9    2.0  0.028799
# bin=ward;pval=0.005;clust=Louvain;m=0.6     2.0  0.035804
# bin=ward;pval=0.0001;clust=Louvain;m=0.7    2.0  0.029265
# bin=ward;pval=0.0005;clust=Louvain;m=0.6    2.0  0.030850
# bin=ward;pval=0.05;clust=Louvain;m=0.6      2.0  0.036727
# bin=kmeans;pval=0.0001;clust=Louvain;m=0.
# bin=kmeans;pval=0.05;clust=WGCNA;ds=4;dch=0.995                      0.623343
# bin=kmeans;pval=0.01;clust=WGCNA;ds=2;dch=0.995                      0.578419
# bin=kmeans;pval=0.0005;clust=WGCNA;ds=2;dch=0.995                    0.570500
# bin=kmeans;pval=0.01;clust=WGCNA;ds=0;dch=0.995                      0.578511
# bin=kmeans;pval=0.001;clust=WGCNA;ds=2;dch=0.995                     0.574423
# bin=kmeans;pval=0.01;clust=WGCNA;ds=4;dch=0.995                      0.594288
# bin=kmeans;pval=0.005;clust=WGCNA;ds=2;dch=0.995                     0.576982
# bin=kmeans;pval=0.01;clust=WGCNA;ds=1;dch=0.995                      0.577179
# bin=kmeans;pval=0.0005;clust=WGCNA;ds=4;dch=0.995                    0.588384
# bin=kmeans;pval=0.0005;clust=WGCNA;ds=1;dch=0.995                    0.569274
# bin=kmeans;pval=0.01;clust=WGCNA;ds=3;dch=0.995                      0.585064
# bin=kmeans;pval=0.0005;clust=WGCNA;ds=3;dch=0.995                    0.575493
# bin=kmeans;pval=0.001;clust=WGCNA;ds=1;dch=0.995                     0.572096
# bin=kmeans;pval=0.0001;clust=WGCNA;ds=2;dch=0.995                    0.563806
# bin=kmeans;pval=0.001;clust=WGCNA;ds=4;dch=0.995                     0.593036
# bin=kmeans;pval=0.005;clust=WGCNA;ds=3;dch=0.995                     0.581710
# bin=kmeans;pval=0.001;clust=WGCNA;ds=3;dch=0.995                     0.584597
# bin=kmeans;pval=0.0001;clust=WGCNA;ds=3;dch=0.995                    0.571534
# bin=kmeans;pval=0.0001;clust=WGCNA;ds=4;dch=0.995                    0.583818
# bin=kmeans;pval=0.0005;clust=Louvain;m=0                             0.589000
# bin=kmeans;pval=0.005;clust=WGCNA;ds=4;dch=0.995                     0.591911
# bin=kmeans;pval=0.0001;clust=Louvain;m=0.9                           0.586839
# bin=kmeans;pval=0.005;clust=Louvain;m=0.8                            0.591343
# bin=kmeans;pval=0.0001;clust=WGCNA;ds=1;dch=0.995                    0.563432
# bin=ward;pval=0.005;clust=Louvain;m=0.5                              0.581036
# bin=kmeans;pval=0.001;clust=Louvain;m=0                              0.586555
# bin=kmeans;pval=0.0001;clust=Louvain;m=0.7                           0.571199
# bin=kmeans;pval=0.0005;clust=Louvain;m=0.8                           0.587313
# bin=kmeans;pval=0.001;clust=Louvain;m=0.8                            0.590790
# bin=kmeans;pval=0.0001;clust=Louvain;m=0                             0.583002
# bin=kmeans;pval=0.0001;clust=Louvain;m=0.8                           0.581312
# bin=kmeans;pval=0.0005;clust=Louvain;m=0.9                           0.578905
# bin=ward;pval=0.0001;clust=WGCNA;ds=1;dch=0.995                      0.582596
# bin=ward;pval=0.005;clust=Louvain;m=0.3                              0.555552
# bin=GMM;pval=0.01;clust=Louvain;m=0                                  0.622032
# bin=kmeans;pval=0.005;clust=Louvain;m=0                              0.578627
# bin=kmeans;pval=0.05;clust=Louvain;m=0                               0.600282
# bin=kmeans;pval=0.01;clust=Louvain;m=0                               0.580116
# bin=kmeans;pval=0.0005;clust=Louvain;m=0.7                           0.575878
# bin=ward;pval=0.0001;clust=Louvain;m=0.3                             0.551156
# bin=kmeans;pval=0.0001;clust=Louvain;m=0.6                           0.564037
# bin=ward;pval=0.0001;clust=WGCNA;ds=0;dch=0.995                      0.593675
# bin=kmeans;pval=0.05;clust=Louvain;m=0.8                             0.609512
# bin=ward;pval=0.0001;clust=WGCNA;ds=2;dch=0.995                      0.593799
# bin=ward;pval=0.0005;clust=WGCNA;ds=3;dch=0.995                      0.619245
# bin=kmeans;pval=0.01;clust=Louvain;m=0.8                             0.592631
# bin=ward;pval=0.0005;clust=Louvain;m=0                               0.610148
# bin=GMM;pval=0.001;clust=Louvain;m=0                                 0.624747
# bin=ward;pval=0.0001;clust=WGCNA;ds=4;dch=0.995                      0.607925
# bin=GMM;pval=0.005;clust=Louvain;m=0                                 0.623157
# bin=kmeans;pval=0.001;clust=Louvain;m=0.9                            0.574163
#
#                                                    overall_performance_IHC  \
# parameters
# bin=kmeans;pval=0.0001;clust=WGCNA;ds=0;dch=0.995                 0.784318
# bin=kmeans;pval=0.05;clust=WGCNA;ds=0;dch=0.995                   0.791554
# bin=kmeans;pval=0.0005;clust=WGCNA;ds=0;dch=0.995                 0.787604
# bin=kmeans;pval=0.05;clust=WGCNA;ds=1;dch=0.995                   0.795391
# bin=kmeans;pval=0.05;clust=WGCNA;ds=2;dch=0.995                   0.801670
# bin=kmeans;pval=0.005;clust=WGCNA;ds=0;dch=0.995                  0.790341
# bin=kmeans;pval=0.001;clust=WGCNA;ds=0;dch=0.995                  0.790027
# bin=kmeans;pval=0.05;clust=WGCNA;ds=3;dch=0.995                   0.807232
# bin=kmeans;pval=0.005;clust=WGCNA;ds=1;dch=0.995                  0.792588
# bin=kmeans;pval=0.05;clust=WGCNA;ds=4;dch=0.995                   0.810844
# bin=kmeans;pval=0.01;clust=WGCNA;ds=2;dch=0.995                   0.800243
# bin=kmeans;pval=0.0005;clust=WGCNA;ds=2;dch=0.995                 0.800651
# bin=kmeans;pval=0.01;clust=WGCNA;ds=0;dch=0.995                   0.795745
# bin=kmeans;pval=0.001;clust=WGCNA;ds=2;dch=0.995                  0.799511
# bin=kmeans;pval=0.01;clust=WGCNA;ds=4;dch=0.995                   0.805998
# bin=kmeans;pval=0.005;clust=WGCNA;ds=2;dch=0.995                  0.801737
# bin=kmeans;pval=0.01;clust=WGCNA;ds=1;dch=0.995                   0.797140
# bin=kmeans;pval=0.0005;clust=WGCNA;ds=4;dch=0.995                 0.809950
# bin=kmeans;pval=0.0005;clust=WGCNA;ds=1;dch=0.995                 0.797872
# bin=kmeans;pval=0.01;clust=WGCNA;ds=3;dch=0.995                   0.805014
# bin=kmeans;pval=0.0005;clust=WGCNA;ds=3;dch=0.995                 0.807458
# bin=kmeans;pval=0.001;clust=WGCNA;ds=1;dch=0.995                  0.796955
# bin=kmeans;pval=0.0001;clust=WGCNA;ds=2;dch=0.995                 0.801689
# bin=kmeans;pval=0.001;clust=WGCNA;ds=4;dch=0.995                  0.807397
# bin=kmeans;pval=0.005;clust=WGCNA;ds=3;dch=0.995                  0.804878
# bin=kmeans;pval=0.001;clust=WGCNA;ds=3;dch=0.995                  0.804794
# bin=kmeans;pval=0.0001;clust=WGCNA;ds=3;dch=0.995                 0.805894
# bin=kmeans;pval=0.0001;clust=WGCNA;ds=4;dch=0.995                 0.808056
# bin=kmeans;pval=0.0005;clust=Louvain;m=0                          0.807364
# bin=kmeans;pval=0.005;clust=WGCNA;ds=4;dch=0.995                  0.804015
# bin=kmeans;pval=0.0001;clust=Louvain;m=0.9                        0.802472
# bin=kmeans;pval=0.005;clust=Louvain;m=0.8                         0.802285
# bin=kmeans;pval=0.0001;clust=WGCNA;ds=1;dch=0.995                 0.798695
# bin=ward;pval=0.005;clust=Louvain;m=0.5                           0.791251
# bin=kmeans;pval=0.001;clust=Louvain;m=0                           0.800630
# bin=kmeans;pval=0.0001;clust=Louvain;m=0.7                        0.804154
# bin=kmeans;pval=0.0005;clust=Louvain;m=0.8                        0.800917
# bin=kmeans;pval=0.001;clust=Louvain;m=0.8                         0.799279
# bin=kmeans;pval=0.0001;clust=Louvain;m=0                          0.810533
# bin=kmeans;pval=0.0001;clust=Louvain;m=0.8                        0.800289
# bin=kmeans;pval=0.0005;clust=Louvain;m=0.9                        0.801302
# bin=ward;pval=0.0001;clust=WGCNA;ds=1;dch=0.995                   0.808824
# bin=ward;pval=0.005;clust=Louvain;m=0.3                           0.803551
# bin=GMM;pval=0.01;clust=Louvain;m=0                               0.812841
# bin=kmeans;pval=0.005;clust=Louvain;m=0                           0.794954
# bin=kmeans;pval=0.05;clust=Louvain;m=0                            0.794954
# bin=kmeans;pval=0.01;clust=Louvain;m=0                            0.794697
# bin=kmeans;pval=0.0005;clust=Louvain;m=0.7                        0.801167
# bin=ward;pval=0.0001;clust=Louvain;m=0.3                          0.802514
# bin=kmeans;pval=0.0001;clust=Louvain;m=0.6                        0.801317
# bin=ward;pval=0.0001;clust=WGCNA;ds=0;dch=0.995                   0.811403
# bin=kmeans;pval=0.05;clust=Louvain;m=0.8                          0.813450
# bin=ward;pval=0.0001;clust=WGCNA;ds=2;dch=0.995                   0.814663
# bin=ward;pval=0.0005;clust=WGCNA;ds=3;dch=0.995                   0.824053
# bin=kmeans;pval=0.01;clust=Louvain;m=0.8                          0.797784
# bin=ward;pval=0.0005;clust=Louvain;m=0                            0.811738
# bin=GMM;pval=0.001;clust=Louvain;m=0                              0.840842
# bin=ward;pval=0.0001;clust=WGCNA;ds=4;dch=0.995                   0.818534
# bin=GMM;pval=0.005;clust=Louvain;m=0                              0.825291
# bin=kmeans;pval=0.001;clust=Louvain;m=0.9                         0.805944
#
#                                                        seed  run      time  \
# parameters
# bin=kmeans;pval=0.0001;clust=WGCNA;ds=0;dch=0.995  375882.4  2.0  0.039411
# bin=kmeans;pval=0.05;clust=WGCNA;ds=0;dch=0.995    375882.4  2.0  0.047503
# bin=kmeans;pval=0.0005;clust=WGCNA;ds=0;dch=0.995  375882.4  2.0  0.037732
# bin=kmeans;pval=0.05;clust=WGCNA;ds=1;dch=0.995    375882.4  2.0  0.043231
# bin=kmeans;pval=0.05;clust=WGCNA;ds=2;dch=0.995    375882.4  2.0  0.051257
# bin=kmeans;pval=0.005;clust=WGCNA;ds=0;dch=0.995   375882.4  2.0  0.039910
# bin=kmeans;pval=0.001;clust=WGCNA;ds=0;dch=0.995   375882.4  2.0  0.040921
# bin=kmeans;pval=0.05;clust=WGCNA;ds=3;dch=0.995    375882.4  2.0  0.090379
# bin=kmeans;pval=0.005;clust=WGCNA;ds=1;dch=0.995   375882.4  2.0  0.040694
# bin=kmeans;pval=0.05;clust=WGCNA;ds=4;dch=0.995    375882.4  2.0  0.132307
# bin=kmeans;pval=0.01;clust=WGCNA;ds=2;dch=0.995    375882.4  2.0  0.049854
# bin=kmeans;pval=0.0005;clust=WGCNA;ds=2;dch=0.995  375882.4  2.0  0.041385
# bin=kmeans;pval=0.01;clust=WGCNA;ds=0;dch=0.995    375882.4  2.0  0.044270
# bin=kmeans;pval=0.001;clust=WGCNA;ds=2;dch=0.995   375882.4  2.0  0.043727
# bin=kmeans;pval=0.01;clust=WGCNA;ds=4;dch=0.995    375882.4  2.0  0.103329
# bin=kmeans;pval=0.005;clust=WGCNA;ds=2;dch=0.995   375882.4  2.0  0.048303
# bin=kmeans;pval=0.01;clust=WGCNA;ds=1;dch=0.995    375882.4  2.0  0.043743
# bin=kmeans;pval=0.0005;clust=WGCNA;ds=4;dch=0.995  375882.4  2.0  0.091653
# bin=kmeans;pval=0.0005;clust=WGCNA;ds=1;dch=0.995  375882.4  2.0  0.034264
# bin=kmeans;pval=0.01;clust=WGCNA;ds=3;dch=0.995    375882.4  2.0  0.081820
# bin=kmeans;pval=0.0005;clust=WGCNA;ds=3;dch=0.995  375882.4  2.0  0.066526
# bin=kmeans;pval=0.001;clust=WGCNA;ds=1;dch=0.995   375882.4  2.0  9.407138
# bin=kmeans;pval=0.0001;clust=WGCNA;ds=2;dch=0.995  375882.4  2.0  0.037521
# bin=kmeans;pval=0.001;clust=WGCNA;ds=4;dch=0.995   375882.4  2.0  0.105612
# bin=kmeans;pval=0.005;clust=WGCNA;ds=3;dch=0.995   375882.4  2.0  0.070988
# bin=kmeans;pval=0.001;clust=WGCNA;ds=3;dch=0.995   375882.4  2.0  0.067843
# bin=kmeans;pval=0.0001;clust=WGCNA;ds=3;dch=0.995  375882.4  2.0  0.054239
# bin=kmeans;pval=0.0001;clust=WGCNA;ds=4;dch=0.995  375882.4  2.0  0.092551
# bin=kmeans;pval=0.0005;clust=Louvain;m=0           375882.4  2.0  0.038210
# bin=kmeans;pval=0.005;clust=WGCNA;ds=4;dch=0.995   375882.4  2.0  0.096039
# bin=kmeans;pval=0.0001;clust=Louvain;m=0.9         375882.4  2.0  0.037654
# bin=kmeans;pval=0.005;clust=Louvain;m=0.8          375882.4  2.0  0.037748
# bin=kmeans;pval=0.0001;clust=WGCNA;ds=1;dch=0.995  375882.4  2.0  0.035913
# bin=ward;pval=0.005;clust=Louvain;m=0.5            375882.4  2.0  0.034771
# bin=kmeans;pval=0.001;clust=Louvain;m=0            375882.4  2.0  0.034420
# bin=kmeans;pval=0.0001;clust=Louvain;m=0.7         375882.4  2.0  0.035656
# bin=kmeans;pval=0.0005;clust=Louvain;m=0.8         375882.4  2.0  0.036040
# bin=kmeans;pval=0.001;clust=Louvain;m=0.8          375882.4  2.0  0.041017
# bin=kmeans;pval=0.0001;clust=Louvain;m=0           375882.4  2.0  0.032437
# bin=kmeans;pval=0.0001;clust=Louvain;m=0.8         375882.4  2.0  0.039789
# bin=kmeans;pval=0.0005;clust=Louvain;m=0.9         375882.4  2.0  0.036118
# bin=ward;pval=0.0001;clust=WGCNA;ds=1;dch=0.995    375882.4  2.0  0.039429
# bin=ward;pval=0.005;clust=Louvain;m=0.3            375882.4  2.0  0.030022
# bin=GMM;pval=0.01;clust=Louvain;m=0                375882.4  2.0  0.041184
# bin=kmeans;pval=0.005;clust=Louvain;m=0            375882.4  2.0  0.032563
# bin=kmeans;pval=0.05;clust=Louvain;m=0             375882.4  2.0  0.036466
# bin=kmeans;pval=0.01;clust=Louvain;m=0             375882.4  2.0  0.031430
# bin=kmeans;pval=0.0005;clust=Louvain;m=0.7         375882.4  2.0  0.033524
# bin=ward;pval=0.0001;clust=Louvain;m=0.3           375882.4  2.0  0.028566
# bin=kmeans;pval=0.0001;clust=Louvain;m=0.6         375882.4  2.0  0.034239
# bin=ward;pval=0.0001;clust=WGCNA;ds=0;dch=0.995    375882.4  2.0  0.042620
# bin=kmeans;pval=0.05;clust=Louvain;m=0.8           375882.4  2.0  0.040718
# bin=ward;pval=0.0001;clust=WGCNA;ds=2;dch=0.995    375882.4  2.0  0.043624
# bin=ward;pval=0.0005;clust=WGCNA;ds=3;dch=0.995    375882.4  2.0  0.077492
# bin=kmeans;pval=0.01;clust=Louvain;m=0.8           375882.4  2.0  0.040838
# bin=ward;pval=0.0005;clust=Louvain;m=0             375882.4  2.0  0.035900
# bin=GMM;pval=0.001;clust=Louvain;m=0               375882.4  2.0  0.038301
# bin=ward;pval=0.0001;clust=WGCNA;ds=4;dch=0.995    375882.4  2.0  0.092454
# bin=GMM;pval=0.005;clust=Louvain;m=0               375882.4  2.0  0.031154
# bin=kmeans;pval=0.001;clust=Louvain;m=0.9          375882.4  2.0  0.038979
#
#                                                    rank
# parameters
# bin=kmeans;pval=0.0001;clust=WGCNA;ds=0;dch=0.995     0
# bin=kmeans;pval=0.05;clust=WGCNA;ds=0;dch=0.995       1
# bin=kmeans;pval=0.0005;clust=WGCNA;ds=0;dch=0.995     2
# bin=kmeans;pval=0.05;clust=WGCNA;ds=1;dch=0.995       3
# bin=kmeans;pval=0.05;clust=WGCNA;ds=2;dch=0.995       4
# bin=kmeans;pval=0.005;clust=WGCNA;ds=0;dch=0.995      5
# bin=kmeans;pval=0.001;clust=WGCNA;ds=0;dch=0.995      6
# bin=kmeans;pval=0.05;clust=WGCNA;ds=3;dch=0.995       7
# bin=kmeans;pval=0.005;clust=WGCNA;ds=1;dch=0.995      8
# bin=kmeans;pval=0.05;clust=WGCNA;ds=4;dch=0.995       9
# bin=kmeans;pval=0.01;clust=WGCNA;ds=2;dch=0.995      10
# bin=kmeans;pval=0.0005;clust=WGCNA;ds=2;dch=0.995    11
# bin=kmeans;pval=0.01;clust=WGCNA;ds=0;dch=0.995      12
# bin=kmeans;pval=0.001;clust=WGCNA;ds=2;dch=0.995     13
# bin=kmeans;pval=0.01;clust=WGCNA;ds=4;dch=0.995      14
# bin=kmeans;pval=0.005;clust=WGCNA;ds=2;dch=0.995     15
# bin=kmeans;pval=0.01;clust=WGCNA;ds=1;dch=0.995      16
# bin=kmeans;pval=0.0005;clust=WGCNA;ds=4;dch=0.995    17
# bin=kmeans;pval=0.0005;clust=WGCNA;ds=1;dch=0.995    18
# bin=kmeans;pval=0.01;clust=WGCNA;ds=3;dch=0.995      19
# bin=kmeans;pval=0.0005;clust=WGCNA;ds=3;dch=0.995    20
# bin=kmeans;pval=0.001;clust=WGCNA;ds=1;dch=0.995     21
# bin=kmeans;pval=0.0001;clust=WGCNA;ds=2;dch=0.995    22
# bin=kmeans;pval=0.001;clust=WGCNA;ds=4;dch=0.995     23
# bin=kmeans;pval=0.005;clust=WGCNA;ds=3;dch=0.995     24
# bin=kmeans;pval=0.001;clust=WGCNA;ds=3;dch=0.995     25
# bin=kmeans;pval=0.0001;clust=WGCNA;ds=3;dch=0.995    26
# bin=kmeans;pval=0.0001;clust=WGCNA;ds=4;dch=0.995    27
# bin=kmeans;pval=0.0005;clust=Louvain;m=0             28
# bin=kmeans;pval=0.005;clust=WGCNA;ds=4;dch=0.995     29
# bin=kmeans;pval=0.0001;clust=Louvain;m=0.9           30
# bin=kmeans;pval=0.005;clust=Louvain;m=0.8            31
# bin=kmeans;pval=0.0001;clust=WGCNA;ds=1;dch=0.995    32
# bin=ward;pval=0.005;clust=Louvain;m=0.5              33
# bin=kmeans;pval=0.001;clust=Louvain;m=0              34
# bin=kmeans;pval=0.0001;clust=Louvain;m=0.7           35
# bin=kmeans;pval=0.0005;clust=Louvain;m=0.8           36
# bin=kmeans;pval=0.001;clust=Louvain;m=0.8            37
# bin=kmeans;pval=0.0001;clust=Louvain;m=0             38
# bin=kmeans;pval=0.0001;clust=Louvain;m=0.8           39
# bin=kmeans;pval=0.0005;clust=Louvain;m=0.9           40
# bin=ward;pval=0.0001;clust=WGCNA;ds=1;dch=0.995      41
# bin=ward;pval=0.005;clust=Louvain;m=0.3              42
# bin=GMM;pval=0.01;clust=Louvain;m=0                  43
# bin=kmeans;pval=0.005;clust=Louvain;m=0              44
# bin=kmeans;pval=0.05;clust=Louvain;m=0               45
# bin=kmeans;pval=0.01;clust=Louvain;m=0               46
# bin=kmeans;pval=0.0005;clust=Louvain;m=0.7           47
# bin=ward;pval=0.0001;clust=Louvain;m=0.3             48
# bin=kmeans;pval=0.0001;clust=Louvain;m=0.6           49
# bin=ward;pval=0.0001;clust=WGCNA;ds=0;dch=0.995      50
# bin=kmeans;pval=0.05;clust=Louvain;m=0.8             51
# bin=ward;pval=0.0001;clust=WGCNA;ds=2;dch=0.995      52
# bin=ward;pval=0.0005;clust=WGCNA;ds=3;dch=0.995      53
# bin=kmeans;pval=0.01;clust=Louvain;m=0.8             54
# bin=ward;pval=0.0005;clust=Louvain;m=0               55
# bin=GMM;pval=0.001;clust=Louvain;m=0                 56
# bin=ward;pval=0.0001;clust=WGCNA;ds=4;dch=0.995      57
# bin=GMM;pval=0.005;clust=Louvain;m=0                 58
# bin=kmeans;pval=0.001;clust=Louvain;m=0.9            59
#
# [60 rows x 22 columns]

# %%
# Out:
# (234, 22)

# %%
df.loc["bin=kmeans;pval=0.01;clust=WGCNA;ds=0;dch=0.995",:]
# Out:
# Basal                                 0.884920
# LumA                                  0.723474
# Her2                                  0.508427
# LumB                                  0.492807
# Normal                                0.077641
# Luminal                               0.885366
# Claudin-low                           0.108444
# ER-/HER2-                             0.850129
# HER2+                                 0.549617
# ER+/HER2- Low Prolif                  0.714178
# ER+/HER2- High Prolif                 0.499169
# IHC_ER                                0.856127
# IHC_PR                                0.746717
# IHC_TNBC                              0.387198
# IHC_HER2                              0.331488
# overall_performance_Intrinsic         0.794970
# overall_performance_SCMOD2            0.646301
# overall_performance_IHC               0.734865
# seed                             375882.400000
# run                                   2.000000
# time                                  0.040497
# Name: bin=kmeans;pval=0.01;clust=WGCNA;ds=0;dch=0.995, dtype: float64

# %%
df2.loc["bin=kmeans;pval=0.01;clust=WGCNA;ds=0;dch=0.995",:]
# Out:
# Basal                                 0.855987
# LumB                                  0.552651
# LumA                                  0.505270
# Her2                                  0.492839
# Normal                                0.085385
# Luminal                               0.930752
# Claudin-low                           0.159272
# HER2+                                 0.789980
# ER-/HER2-                             0.694705
# ER+/HER2- Low Prolif                  0.562054
# ER+/HER2- High Prolif                 0.470832
# IHC_ER                                0.930804
# IHC_HER2                              0.831263
# IHC_PR                                0.625012
# IHC_TNBC                              0.684830
# overall_performance_Intrinsic         0.811611
# overall_performance_SCMOD2            0.578511
# overall_performance_IHC               0.795745
# seed                             375882.400000
# run                                   2.000000
# time                                  0.044270
# Name: bin=kmeans;pval=0.01;clust=WGCNA;ds=0;dch=0.995, dtype: float64

# %%
pd.DataFrame.from_records(clustering_similarities).to_csv("UnPaSt_similarities.tsv",sep = "\t")
pd.DataFrame.from_records(subt_t).to_csv("UnPaSt_TCGA.tsv",sep = "\t")
pd.DataFrame.from_records(subt_m).to_csv("UnPaSt_METABRIC.tsv",sep = "\t")

# %%
df = pd.read_csv("UnPaSt_TCGA.tsv",sep = "\t",index_col =0).groupby("parameters").agg("mean").sort_values(by= "overall_performance_Intrinsic",ascending=False)
df2 = pd.read_csv("UnPaSt_METABRIC.tsv",sep = "\t",index_col =0).groupby("parameters").agg("mean").sort_values(by= "overall_performance_Intrinsic",ascending=False)

# %%
df2.sort_values(by= "overall_performance_Intrinsic",ascending=False).head(3)
# Out:
#                                                       Basal      LumB  \
# parameters
# bin=kmeans;pval=0.0001;clust=WGCNA;ds=0;dch=0.995  0.849441  0.546428
# bin=kmeans;pval=0.05;clust=WGCNA;ds=0;dch=0.995    0.859728  0.547714
# bin=kmeans;pval=0.0005;clust=WGCNA;ds=0;dch=0.995  0.855674  0.546121
#
#                                                        LumA      Her2  \
# parameters
# bin=kmeans;pval=0.0001;clust=WGCNA;ds=0;dch=0.995  0.466814  0.563183
# bin=kmeans;pval=0.05;clust=WGCNA;ds=0;dch=0.995    0.577181  0.527241
# bin=kmeans;pval=0.0005;clust=WGCNA;ds=0;dch=0.995  0.480255  0.532637
#
#                                                      Normal   Luminal  \
# parameters
# bin=kmeans;pval=0.0001;clust=WGCNA;ds=0;dch=0.995  0.086653  0.930145
# bin=kmeans;pval=0.05;clust=WGCNA;ds=0;dch=0.995    0.084985  0.930618
# bin=kmeans;pval=0.0005;clust=WGCNA;ds=0;dch=0.995  0.084862  0.930028
#
#                                                    Claudin-low     HER2+  \
# parameters
# bin=kmeans;pval=0.0001;clust=WGCNA;ds=0;dch=0.995     0.162624  0.669133
# bin=kmeans;pval=0.05;clust=WGCNA;ds=0;dch=0.995       0.159904  0.719759
# bin=kmeans;pval=0.0005;clust=WGCNA;ds=0;dch=0.995     0.161102  0.721651
#
#                                                    ER-/HER2-  \
# parameters
# bin=kmeans;pval=0.0001;clust=WGCNA;ds=0;dch=0.995   0.686179
# bin=kmeans;pval=0.05;clust=WGCNA;ds=0;dch=0.995     0.693298
# bin=kmeans;pval=0.0005;clust=WGCNA;ds=0;dch=0.995   0.691933
#
#                                                    ER+/HER2- Low Prolif  ...  \
# parameters                                                               ...
# bin=kmeans;pval=0.0001;clust=WGCNA;ds=0;dch=0.995              0.514888  ...
# bin=kmeans;pval=0.05;clust=WGCNA;ds=0;dch=0.995                0.687489  ...
# bin=kmeans;pval=0.0005;clust=WGCNA;ds=0;dch=0.995              0.530134  ...
#
#                                                      IHC_ER  IHC_HER2  \
# parameters
# bin=kmeans;pval=0.0001;clust=WGCNA;ds=0;dch=0.995  0.929429  0.680394
# bin=kmeans;pval=0.05;clust=WGCNA;ds=0;dch=0.995    0.934630  0.755871
# bin=kmeans;pval=0.0005;clust=WGCNA;ds=0;dch=0.995  0.929310  0.746905
#
#                                                      IHC_PR  IHC_TNBC  \
# parameters
# bin=kmeans;pval=0.0001;clust=WGCNA;ds=0;dch=0.995  0.630800  0.676319
# bin=kmeans;pval=0.05;clust=WGCNA;ds=0;dch=0.995    0.625107  0.683256
# bin=kmeans;pval=0.0005;clust=WGCNA;ds=0;dch=0.995  0.624203  0.679674
#
#                                                    overall_performance_Intrinsic  \
# parameters
# bin=kmeans;pval=0.0001;clust=WGCNA;ds=0;dch=0.995                       0.819198
# bin=kmeans;pval=0.05;clust=WGCNA;ds=0;dch=0.995                         0.816212
# bin=kmeans;pval=0.0005;clust=WGCNA;ds=0;dch=0.995                       0.816022
#
#                                                    overall_performance_SCMOD2  \
# parameters
# bin=kmeans;pval=0.0001;clust=WGCNA;ds=0;dch=0.995                    0.548141
# bin=kmeans;pval=0.05;clust=WGCNA;ds=0;dch=0.995                      0.612929
# bin=kmeans;pval=0.0005;clust=WGCNA;ds=0;dch=0.995                    0.559676
#
#                                                    overall_performance_IHC  \
# parameters
# bin=kmeans;pval=0.0001;clust=WGCNA;ds=0;dch=0.995                 0.784318
# bin=kmeans;pval=0.05;clust=WGCNA;ds=0;dch=0.995                   0.791554
# bin=kmeans;pval=0.0005;clust=WGCNA;ds=0;dch=0.995                 0.787604
#
#                                                        seed  run      time
# parameters
# bin=kmeans;pval=0.0001;clust=WGCNA;ds=0;dch=0.995  375882.4  2.0  0.039411
# bin=kmeans;pval=0.05;clust=WGCNA;ds=0;dch=0.995    375882.4  2.0  0.047503
# bin=kmeans;pval=0.0005;clust=WGCNA;ds=0;dch=0.995  375882.4  2.0  0.037732
#
# [3 rows x 21 columns]

# %%
df2.sort_values(by= "overall_performance_IHC",ascending=False).head(3)
# Out:
#                                           Basal      LumB      LumA      Her2  \
# parameters
# bin=GMM;pval=0.001;clust=Louvain;m=0   0.823901  0.601145  0.579131  0.470930
# bin=GMM;pval=0.0005;clust=Louvain;m=0  0.823901  0.601145  0.576046  0.468109
# bin=GMM;pval=0.0001;clust=Louvain;m=0  0.823901  0.601145  0.570273  0.468109
#
#                                          Normal   Luminal  Claudin-low  \
# parameters
# bin=GMM;pval=0.001;clust=Louvain;m=0   0.085714  0.928415     0.168358
# bin=GMM;pval=0.0005;clust=Louvain;m=0  0.085714  0.927636     0.168358
# bin=GMM;pval=0.0001;clust=Louvain;m=0  0.084907  0.927636     0.168358
#
#                                           HER2+  ER-/HER2-  \
# parameters
# bin=GMM;pval=0.001;clust=Louvain;m=0   0.764259   0.721841
# bin=GMM;pval=0.0005;clust=Louvain;m=0  0.754978   0.721841
# bin=GMM;pval=0.0001;clust=Louvain;m=0  0.754978   0.721841
#
#                                        ER+/HER2- Low Prolif  ...    IHC_ER  \
# parameters                                                   ...
# bin=GMM;pval=0.001;clust=Louvain;m=0               0.687527  ...  0.947443
# bin=GMM;pval=0.0005;clust=Louvain;m=0              0.683590  ...  0.945113
# bin=GMM;pval=0.0001;clust=Louvain;m=0              0.670538  ...  0.945113
#
#                                        IHC_HER2    IHC_PR  IHC_TNBC  \
# parameters
# bin=GMM;pval=0.001;clust=Louvain;m=0   0.872180  0.725843  0.684012
# bin=GMM;pval=0.0005;clust=Louvain;m=0  0.865602  0.725843  0.684012
# bin=GMM;pval=0.0001;clust=Louvain;m=0  0.865602  0.725843  0.684012
#
#                                        overall_performance_Intrinsic  \
# parameters
# bin=GMM;pval=0.001;clust=Louvain;m=0                        0.803792
# bin=GMM;pval=0.0005;clust=Louvain;m=0                       0.802913
# bin=GMM;pval=0.0001;clust=Louvain;m=0                       0.802891
#
#                                        overall_performance_SCMOD2  \
# parameters
# bin=GMM;pval=0.001;clust=Louvain;m=0                     0.624747
# bin=GMM;pval=0.0005;clust=Louvain;m=0                    0.622184
# bin=GMM;pval=0.0001;clust=Louvain;m=0                    0.617763
#
#                                        overall_performance_IHC      seed  run  \
# parameters
# bin=GMM;pval=0.001;clust=Louvain;m=0                  0.840842  375882.4  2.0
# bin=GMM;pval=0.0005;clust=Louvain;m=0                 0.839193  375882.4  2.0
# bin=GMM;pval=0.0001;clust=Louvain;m=0                 0.839193  375882.4  2.0
#
#                                            time
# parameters
# bin=GMM;pval=0.001;clust=Louvain;m=0   0.038301
# bin=GMM;pval=0.0005;clust=Louvain;m=0  0.036453
# bin=GMM;pval=0.0001;clust=Louvain;m=0  0.037562
#
# [3 rows x 21 columns]

# %%
df["rank"] = range(df.shape[0])
df2["rank"] = range(df2.shape[0])
r = df["rank"]+df2["rank"]
r.sort_values()
# Out:
# parameters
# bin=kmeans;pval=0.0005;clust=Louvain;m=0       49
# bin=kmeans;pval=0.0001;clust=Louvain;m=0.7     50
# bin=ward;pval=0.005;clust=Louvain;m=0.5        51
# bin=kmeans;pval=0.0001;clust=Louvain;m=0.6     54
# bin=kmeans;pval=0.0005;clust=Louvain;m=0.7     54
#                                              ...
# bin=GMM;pval=0.05;clust=Louvain;m=0.4         452
# bin=GMM;pval=0.001;clust=Louvain;m=0.3        456
# bin=GMM;pval=0.005;clust=Louvain;m=0.3        461
# bin=GMM;pval=0.01;clust=Louvain;m=0.3         463
# bin=GMM;pval=0.05;clust=Louvain;m=0.3         466
# Name: rank, Length: 234, dtype: int64

# %%
#df2.loc["bin=kmeans;pval=0.0005;clust=Louvain;m=0",:]

# %%
s = pd.read_csv("UnPaSt_similarities.tsv",sep = "\t",index_col=0).groupby("parameters").agg("mean")
s["avg_percent_matched"] = (s["percent_matched_1"]+s["percent_matched_2"])*0.5
s.sort_values(by = "avg_percent_matched",ascending = False)
# Out:
#                                                      n_1    n_2  \
# parameters
# bin=kmeans;pval=0.01;clust=WGCNA;ds=0;dch=0.995     41.2   48.8
# bin=kmeans;pval=0.005;clust=WGCNA;ds=0;dch=0.995    46.4   46.6
# bin=kmeans;pval=0.0001;clust=WGCNA;ds=0;dch=0.995   32.8   39.4
# bin=GMM;pval=0.0001;clust=WGCNA;ds=0;dch=0.995      21.8   42.2
# bin=kmeans;pval=0.01;clust=WGCNA;ds=1;dch=0.995     59.4   62.8
# ...                                                  ...    ...
# bin=ward;pval=0.005;clust=WGCNA;ds=4;dch=0.995     352.4  270.0
# bin=ward;pval=0.01;clust=WGCNA;ds=4;dch=0.995      367.0  292.4
# bin=ward;pval=0.001;clust=WGCNA;ds=4;dch=0.995     311.6  251.6
# bin=ward;pval=0.0001;clust=WGCNA;ds=4;dch=0.995    275.6  212.6
# bin=ward;pval=0.05;clust=WGCNA;ds=4;dch=0.995      457.8  337.4
#
#                                                    percent_matched_1  \
# parameters
# bin=kmeans;pval=0.01;clust=WGCNA;ds=0;dch=0.995             0.602776
# bin=kmeans;pval=0.005;clust=WGCNA;ds=0;dch=0.995            0.568464
# bin=kmeans;pval=0.0001;clust=WGCNA;ds=0;dch=0.995           0.562200
# bin=GMM;pval=0.0001;clust=WGCNA;ds=0;dch=0.995              0.649769
# bin=kmeans;pval=0.01;clust=WGCNA;ds=1;dch=0.995             0.548608
# ...                                                              ...
# bin=ward;pval=0.005;clust=WGCNA;ds=4;dch=0.995              0.121451
# bin=ward;pval=0.01;clust=WGCNA;ds=4;dch=0.995               0.117732
# bin=ward;pval=0.001;clust=WGCNA;ds=4;dch=0.995              0.105935
# bin=ward;pval=0.0001;clust=WGCNA;ds=4;dch=0.995             0.103799
# bin=ward;pval=0.05;clust=WGCNA;ds=4;dch=0.995               0.096121
#
#                                                    percent_matched_2  \
# parameters
# bin=kmeans;pval=0.01;clust=WGCNA;ds=0;dch=0.995             0.541623
# bin=kmeans;pval=0.005;clust=WGCNA;ds=0;dch=0.995            0.570817
# bin=kmeans;pval=0.0001;clust=WGCNA;ds=0;dch=0.995           0.543741
# bin=GMM;pval=0.0001;clust=WGCNA;ds=0;dch=0.995              0.449309
# bin=kmeans;pval=0.01;clust=WGCNA;ds=1;dch=0.995             0.503577
# ...                                                              ...
# bin=ward;pval=0.005;clust=WGCNA;ds=4;dch=0.995              0.160050
# bin=ward;pval=0.01;clust=WGCNA;ds=4;dch=0.995               0.145710
# bin=ward;pval=0.001;clust=WGCNA;ds=4;dch=0.995              0.151194
# bin=ward;pval=0.0001;clust=WGCNA;ds=4;dch=0.995             0.147670
# bin=ward;pval=0.05;clust=WGCNA;ds=4;dch=0.995               0.125076
#
#                                                    n_shared_genes_1  \
# parameters
# bin=kmeans;pval=0.01;clust=WGCNA;ds=0;dch=0.995               352.8
# bin=kmeans;pval=0.005;clust=WGCNA;ds=0;dch=0.995              316.6
# bin=kmeans;pval=0.0001;clust=WGCNA;ds=0;dch=0.995             205.2
# bin=GMM;pval=0.0001;clust=WGCNA;ds=0;dch=0.995                192.4
# bin=kmeans;pval=0.01;clust=WGCNA;ds=1;dch=0.995               362.4
# ...                                                             ...
# bin=ward;pval=0.005;clust=WGCNA;ds=4;dch=0.995                214.8
# bin=ward;pval=0.01;clust=WGCNA;ds=4;dch=0.995                 221.6
# bin=ward;pval=0.001;clust=WGCNA;ds=4;dch=0.995                170.4
# bin=ward;pval=0.0001;clust=WGCNA;ds=4;dch=0.995               149.2
# bin=ward;pval=0.05;clust=WGCNA;ds=4;dch=0.995                 222.4
#
#                                                    n_shared_genes_2  \
# parameters
# bin=kmeans;pval=0.01;clust=WGCNA;ds=0;dch=0.995               343.2
# bin=kmeans;pval=0.005;clust=WGCNA;ds=0;dch=0.995              314.0
# bin=kmeans;pval=0.0001;clust=WGCNA;ds=0;dch=0.995             225.4
# bin=GMM;pval=0.0001;clust=WGCNA;ds=0;dch=0.995                255.8
# bin=kmeans;pval=0.01;clust=WGCNA;ds=1;dch=0.995               347.2
# ...                                                             ...
# bin=ward;pval=0.005;clust=WGCNA;ds=4;dch=0.995                233.2
# bin=ward;pval=0.01;clust=WGCNA;ds=4;dch=0.995                 229.8
# bin=ward;pval=0.001;clust=WGCNA;ds=4;dch=0.995                204.6
# bin=ward;pval=0.0001;clust=WGCNA;ds=4;dch=0.995               178.6
# bin=ward;pval=0.05;clust=WGCNA;ds=4;dch=0.995                 225.0
#
#                                                    avg_bm_J_1  avg_bm_J_2  \
# parameters
# bin=kmeans;pval=0.01;clust=WGCNA;ds=0;dch=0.995      0.155471    0.150165
# bin=kmeans;pval=0.005;clust=WGCNA;ds=0;dch=0.995     0.164179    0.160031
# bin=kmeans;pval=0.0001;clust=WGCNA;ds=0;dch=0.995    0.106610    0.098606
# bin=GMM;pval=0.0001;clust=WGCNA;ds=0;dch=0.995       0.154863    0.129065
# bin=kmeans;pval=0.01;clust=WGCNA;ds=1;dch=0.995      0.190632    0.197385
# ...                                                       ...         ...
# bin=ward;pval=0.005;clust=WGCNA;ds=4;dch=0.995       0.301238    0.292877
# bin=ward;pval=0.01;clust=WGCNA;ds=4;dch=0.995        0.320397    0.318961
# bin=ward;pval=0.001;clust=WGCNA;ds=4;dch=0.995       0.330959    0.298815
# bin=ward;pval=0.0001;clust=WGCNA;ds=4;dch=0.995      0.309060    0.282133
# bin=ward;pval=0.05;clust=WGCNA;ds=4;dch=0.995        0.366933    0.378891
#
#                                                        seed  run  \
# parameters
# bin=kmeans;pval=0.01;clust=WGCNA;ds=0;dch=0.995    375882.4  2.0
# bin=kmeans;pval=0.005;clust=WGCNA;ds=0;dch=0.995   375882.4  2.0
# bin=kmeans;pval=0.0001;clust=WGCNA;ds=0;dch=0.995  375882.4  2.0
# bin=GMM;pval=0.0001;clust=WGCNA;ds=0;dch=0.995     375882.4  2.0
# bin=kmeans;pval=0.01;clust=WGCNA;ds=1;dch=0.995    375882.4  2.0
# ...                                                     ...  ...
# bin=ward;pval=0.005;clust=WGCNA;ds=4;dch=0.995     375882.4  2.0
# bin=ward;pval=0.01;clust=WGCNA;ds=4;dch=0.995      375882.4  2.0
# bin=ward;pval=0.001;clust=WGCNA;ds=4;dch=0.995     375882.4  2.0
# bin=ward;pval=0.0001;clust=WGCNA;ds=4;dch=0.995    375882.4  2.0
# bin=ward;pval=0.05;clust=WGCNA;ds=4;dch=0.995      375882.4  2.0
#
#                                                    avg_percent_matched
# parameters
# bin=kmeans;pval=0.01;clust=WGCNA;ds=0;dch=0.995               0.572200
# bin=kmeans;pval=0.005;clust=WGCNA;ds=0;dch=0.995              0.569641
# bin=kmeans;pval=0.0001;clust=WGCNA;ds=0;dch=0.995             0.552971
# bin=GMM;pval=0.0001;clust=WGCNA;ds=0;dch=0.995                0.549539
# bin=kmeans;pval=0.01;clust=WGCNA;ds=1;dch=0.995               0.526093
# ...                                                                ...
# bin=ward;pval=0.005;clust=WGCNA;ds=4;dch=0.995                0.140750
# bin=ward;pval=0.01;clust=WGCNA;ds=4;dch=0.995                 0.131721
# bin=ward;pval=0.001;clust=WGCNA;ds=4;dch=0.995                0.128564
# bin=ward;pval=0.0001;clust=WGCNA;ds=4;dch=0.995               0.125734
# bin=ward;pval=0.05;clust=WGCNA;ds=4;dch=0.995                 0.110598
#
# [234 rows x 11 columns]
