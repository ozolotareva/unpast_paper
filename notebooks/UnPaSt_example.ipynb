# %%
import sys
import numpy as np
import pandas as pd
import random

sys.path.append('/home/olya/TUM/DESMOND/DESMOND2/')
from run_unpast import run

from utils.method import read_bic_table, make_consensus_biclusters, write_bic_table

# %%
exprs_file = "test_data_TCGA200/TCGA_200.exprs_z.tsv"
exprs = pd.read_csv(exprs_file,sep = "\t",index_col=0)
basename = 'TCGA200'
out_dir = "tmp_results2/"

# %%
n_runs = 5
seeds = []
random.seed(0)
for i in range(n_runs):
    seeds.append(random.randint(0,1000000))
#seeds = [264943, 32291, 332446, 551112, 583269]
print("generate ",n_runs," seeds",seeds)
# Out:
# generate  5  seeds [885440, 403958, 794772, 933488, 441001]

# %%
biclusters = []
for seed in seeds:
    results = run(exprs_file, basename,
                          out_dir=out_dir,
                          save=True, load=True,
                          bin_method = "ward",
                          clust_method = "WGCNA",
                          ds = 4, # higher is for sharper clusters 
                          dch = 0.95, # lower is for sharper clusters 
                          # show distributions of these features after binarization
                          show_fits = ["SEZ6","SYP","ESR1","ERBB2","FOXA1","PTH2R"], 
                          seed = seed,
                          verbose = True)
    results.index = ["seed="+str(seed)+"_"+str(x) for x in results.index.values ]
    biclusters.append(results)
# Out:
# Read input from: test_data_TCGA200/TCGA_200.exprs_z.tsv
# 	14986 features x 200 samples
# Standardized expressions will be limited to [-3,3]:
# Mininal number of samples in a bicluster: 5
# Load binarized features from tmp_results2/TCGA200.seed=885440.bin_method=ward.min_ns=5.binarized.tsv
#
#
# Binarization started ....
#
# 		genes processed: 0
# Input is standardized.
# file tmp_results2/TCGA200.seed=885440.bin_method=ward.min_ns=5.binarized.tsv is not found and will be created
# file tmp_results2/TCGA200.seed=885440.bin_method=ward.min_ns=5.binarization_stats.tsv is not found and will be created
# 		genes processed: 1000
# 		genes processed: 2000
# 		genes processed: 3000
# 		genes processed: 4000
# 		genes processed: 5000
# 		genes processed: 6000
# 		genes processed: 7000
# 		genes processed: 8000
# 		genes processed: 9000
# 		genes processed: 10000
# 		genes processed: 11000
# 		genes processed: 12000
# 		genes processed: 13000
# 		genes processed: 14000
# 	Binarization for 14986 features completed in 20.74 s
# 	Generate background distribuition of SNR depending on the bicluster size ...
# 		total samples: 200,
# 		number of samples in a bicluster: 5 - 100,
# 		n_permutations: 10000
# 		snr pval threshold: 0.01
# file tmp_results2/TCGA200.seed=885440.n=10000.min_ns=5.background.tsv is not found and will be created
# 	Background ditribution generated in 0.71 s
# 			LOWESS frac= 0.09
# Binarized gene expressions are saved to tmp_results2/TCGA200.seed=885440.bin_method=ward.min_ns=5.binarized.tsv
# Statistics is saved to tmp_results2/TCGA200.seed=885440.bin_method=ward.min_ns=5.binarization_stats.tsv
# Background sitribution is saved to tmp_results2/TCGA200.seed=885440.n=10000.min_ns=5.background.tsv
# 		UP-regulated features:	1017
# 		DOWN-regulated features:	567
# Clustering features ...
#
# 		WGCNA pre-clustering: True
# 	Running WGCNA for tmp_results2/TCGA200.ward.pval=0.01.seed=885440.DOWN.tmpWGCNA_23.07.11_11:57:27.tsv ...
# 	R command line:
# 	Rscript /home/olya/TUM/DESMOND/DESMOND2/utils/run_WGCNA.R tmp_results2/TCGA200.ward.pval=0.01.seed=885440.DOWN.tmpWGCNA_23.07.11_11:57:27.tsv 4 0.95 signed_hybrid 10 T
# 	WGCNA runtime: modules detected in 13.99 s.
# 	modules: 25, not clustered features 436
# 		WGCNA pre-clustering: True
# 	Running WGCNA for tmp_results2/TCGA200.ward.pval=0.01.seed=885440.UP.tmpWGCNA_23.07.11_11:57:41.tsv ...
# 	R command line:
# 	Rscript /home/olya/TUM/DESMOND/DESMOND2/utils/run_WGCNA.R tmp_results2/TCGA200.ward.pval=0.01.seed=885440.UP.tmpWGCNA_23.07.11_11:57:41.tsv 4 0.95 signed_hybrid 10 T
# b'Warning messages:\n1: replacing previous import \xe2\x80\x98ellipsis::check_dots_unnamed\xe2\x80\x99 by \xe2\x80\x98rlang::check_dots_unnamed\xe2\x80\x99 when loading \xe2\x80\x98tibble\xe2\x80\x99 \n2: replacing previous import \xe2\x80\x98ellipsis::check_dots_used\xe2\x80\x99 by \xe2\x80\x98rlang::check_dots_used\xe2\x80\x99 when loading \xe2\x80\x98tibble\xe2\x80\x99 \n3: replacing previous import \xe2\x80\x98ellipsis::check_dots_empty\xe2\x80\x99 by \xe2\x80\x98rlang::check_dots_empty\xe2\x80\x99 when loading \xe2\x80\x98tibble\xe2\x80\x99 \n4: replacing previous import \xe2\x80\x98ellipsis::check_dots_unnamed\xe2\x80\x99 by \xe2\x80\x98rlang::check_dots_unnamed\xe2\x80\x99 when loading \xe2\x80\x98pillar\xe2\x80\x99 \n5: replacing previous import \xe2\x80\x98ellipsis::check_dots_used\xe2\x80\x99 by \xe2\x80\x98rlang::check_dots_used\xe2\x80\x99 when loading \xe2\x80\x98pillar\xe2\x80\x99 \n6: replacing previous import \xe2\x80\x98ellipsis::check_dots_empty\xe2\x80\x99 by \xe2\x80\x98rlang::check_dots_empty\xe2\x80\x99 when loading \xe2\x80\x98pillar\xe2\x80\x99 \nWarning message:\nexecuting %dopar% sequentially: no parallel backend registered \n'
# 	WGCNA runtime: modules detected in 15.98 s.
# 	modules: 24, not clustered features 955
# 	Jaccard similarities for 49 features computed in 0.01 s.
# b'Warning messages:\n1: replacing previous import \xe2\x80\x98ellipsis::check_dots_unnamed\xe2\x80\x99 by \xe2\x80\x98rlang::check_dots_unnamed\xe2\x80\x99 when loading \xe2\x80\x98tibble\xe2\x80\x99 \n2: replacing previous import \xe2\x80\x98ellipsis::check_dots_used\xe2\x80\x99 by \xe2\x80\x98rlang::check_dots_used\xe2\x80\x99 when loading \xe2\x80\x98tibble\xe2\x80\x99 \n3: replacing previous import \xe2\x80\x98ellipsis::check_dots_empty\xe2\x80\x99 by \xe2\x80\x98rlang::check_dots_empty\xe2\x80\x99 when loading \xe2\x80\x98tibble\xe2\x80\x99 \n4: replacing previous import \xe2\x80\x98ellipsis::check_dots_unnamed\xe2\x80\x99 by \xe2\x80\x98rlang::check_dots_unnamed\xe2\x80\x99 when loading \xe2\x80\x98pillar\xe2\x80\x99 \n5: replacing previous import \xe2\x80\x98ellipsis::check_dots_used\xe2\x80\x99 by \xe2\x80\x98rlang::check_dots_used\xe2\x80\x99 when loading \xe2\x80\x98pillar\xe2\x80\x99 \n6: replacing previous import \xe2\x80\x98ellipsis::check_dots_empty\xe2\x80\x99 by \xe2\x80\x98rlang::check_dots_empty\xe2\x80\x99 when loading \xe2\x80\x98pillar\xe2\x80\x99 \nWarning message:\nexecuting %dopar% sequentially: no parallel backend registered \n'
# No biclusters to merge
# tmp_results2/TCGA200.seed=885440.bin=ward,pval=0.01,clust=WGCNA,direction=DOWN-UP,ds=4,dch=0.95,max_power=10,precluster=True.biclusters.tsv
# Total runtime: 60.03 s
# Read input from: test_data_TCGA200/TCGA_200.exprs_z.tsv
# 	14986 features x 200 samples
# Standardized expressions will be limited to [-3,3]:
# Mininal number of samples in a bicluster: 5
# Load binarized features from tmp_results2/TCGA200.seed=403958.bin_method=ward.min_ns=5.binarized.tsv
#
#
# Binarization started ....
#
# 		genes processed: 0
# Input is standardized.
# file tmp_results2/TCGA200.seed=403958.bin_method=ward.min_ns=5.binarized.tsv is not found and will be created
# file tmp_results2/TCGA200.seed=403958.bin_method=ward.min_ns=5.binarization_stats.tsv is not found and will be created
# 		genes processed: 1000
# 		genes processed: 2000
# 		genes processed: 3000
# 		genes processed: 4000
# 		genes processed: 5000
# 		genes processed: 6000
# 		genes processed: 7000
# 		genes processed: 8000
# 		genes processed: 9000
# 		genes processed: 10000
# 		genes processed: 11000
# 		genes processed: 12000
# 		genes processed: 13000
# 		genes processed: 14000
# 	Binarization for 14986 features completed in 21.25 s
# 	Generate background distribuition of SNR depending on the bicluster size ...
# 		total samples: 200,
# 		number of samples in a bicluster: 5 - 100,
# 		n_permutations: 10000
# 		snr pval threshold: 0.01
# file tmp_results2/TCGA200.seed=403958.n=10000.min_ns=5.background.tsv is not found and will be created
# 	Background ditribution generated in 0.77 s
# 			LOWESS frac= 0.09
# Binarized gene expressions are saved to tmp_results2/TCGA200.seed=403958.bin_method=ward.min_ns=5.binarized.tsv
# Statistics is saved to tmp_results2/TCGA200.seed=403958.bin_method=ward.min_ns=5.binarization_stats.tsv
# Background sitribution is saved to tmp_results2/TCGA200.seed=403958.n=10000.min_ns=5.background.tsv
# 		UP-regulated features:	1016
# 		DOWN-regulated features:	567
# Clustering features ...
#
# 		WGCNA pre-clustering: True
# 	Running WGCNA for tmp_results2/TCGA200.ward.pval=0.01.seed=403958.DOWN.tmpWGCNA_23.07.11_11:58:27.tsv ...
# 	R command line:
# 	Rscript /home/olya/TUM/DESMOND/DESMOND2/utils/run_WGCNA.R tmp_results2/TCGA200.ward.pval=0.01.seed=403958.DOWN.tmpWGCNA_23.07.11_11:58:27.tsv 4 0.95 signed_hybrid 10 T
# 	WGCNA runtime: modules detected in 14.61 s.
# 	modules: 18, not clustered features 496
# 		WGCNA pre-clustering: True
# 	Running WGCNA for tmp_results2/TCGA200.ward.pval=0.01.seed=403958.UP.tmpWGCNA_23.07.11_11:58:42.tsv ...
# 	R command line:
# 	Rscript /home/olya/TUM/DESMOND/DESMOND2/utils/run_WGCNA.R tmp_results2/TCGA200.ward.pval=0.01.seed=403958.UP.tmpWGCNA_23.07.11_11:58:42.tsv 4 0.95 signed_hybrid 10 T
# b'Warning messages:\n1: replacing previous import \xe2\x80\x98ellipsis::check_dots_unnamed\xe2\x80\x99 by \xe2\x80\x98rlang::check_dots_unnamed\xe2\x80\x99 when loading \xe2\x80\x98tibble\xe2\x80\x99 \n2: replacing previous import \xe2\x80\x98ellipsis::check_dots_used\xe2\x80\x99 by \xe2\x80\x98rlang::check_dots_used\xe2\x80\x99 when loading \xe2\x80\x98tibble\xe2\x80\x99 \n3: replacing previous import \xe2\x80\x98ellipsis::check_dots_empty\xe2\x80\x99 by \xe2\x80\x98rlang::check_dots_empty\xe2\x80\x99 when loading \xe2\x80\x98tibble\xe2\x80\x99 \n4: replacing previous import \xe2\x80\x98ellipsis::check_dots_unnamed\xe2\x80\x99 by \xe2\x80\x98rlang::check_dots_unnamed\xe2\x80\x99 when loading \xe2\x80\x98pillar\xe2\x80\x99 \n5: replacing previous import \xe2\x80\x98ellipsis::check_dots_used\xe2\x80\x99 by \xe2\x80\x98rlang::check_dots_used\xe2\x80\x99 when loading \xe2\x80\x98pillar\xe2\x80\x99 \n6: replacing previous import \xe2\x80\x98ellipsis::check_dots_empty\xe2\x80\x99 by \xe2\x80\x98rlang::check_dots_empty\xe2\x80\x99 when loading \xe2\x80\x98pillar\xe2\x80\x99 \nWarning message:\nexecuting %dopar% sequentially: no parallel backend registered \n'
# 	WGCNA runtime: modules detected in 15.85 s.
# 	modules: 24, not clustered features 953
# 	Jaccard similarities for 42 features computed in 0.01 s.
# No biclusters to merge
# b'Warning messages:\n1: replacing previous import \xe2\x80\x98ellipsis::check_dots_unnamed\xe2\x80\x99 by \xe2\x80\x98rlang::check_dots_unnamed\xe2\x80\x99 when loading \xe2\x80\x98tibble\xe2\x80\x99 \n2: replacing previous import \xe2\x80\x98ellipsis::check_dots_used\xe2\x80\x99 by \xe2\x80\x98rlang::check_dots_used\xe2\x80\x99 when loading \xe2\x80\x98tibble\xe2\x80\x99 \n3: replacing previous import \xe2\x80\x98ellipsis::check_dots_empty\xe2\x80\x99 by \xe2\x80\x98rlang::check_dots_empty\xe2\x80\x99 when loading \xe2\x80\x98tibble\xe2\x80\x99 \n4: replacing previous import \xe2\x80\x98ellipsis::check_dots_unnamed\xe2\x80\x99 by \xe2\x80\x98rlang::check_dots_unnamed\xe2\x80\x99 when loading \xe2\x80\x98pillar\xe2\x80\x99 \n5: replacing previous import \xe2\x80\x98ellipsis::check_dots_used\xe2\x80\x99 by \xe2\x80\x98rlang::check_dots_used\xe2\x80\x99 when loading \xe2\x80\x98pillar\xe2\x80\x99 \n6: replacing previous import \xe2\x80\x98ellipsis::check_dots_empty\xe2\x80\x99 by \xe2\x80\x98rlang::check_dots_empty\xe2\x80\x99 when loading \xe2\x80\x98pillar\xe2\x80\x99 \nWarning message:\nexecuting %dopar% sequentially: no parallel backend registered \n'
# tmp_results2/TCGA200.seed=403958.bin=ward,pval=0.01,clust=WGCNA,direction=DOWN-UP,ds=4,dch=0.95,max_power=10,precluster=True.biclusters.tsv
# Total runtime: 60.67 s
# Read input from: test_data_TCGA200/TCGA_200.exprs_z.tsv
# 	14986 features x 200 samples
# Standardized expressions will be limited to [-3,3]:
# Mininal number of samples in a bicluster: 5
# Load binarized features from tmp_results2/TCGA200.seed=794772.bin_method=ward.min_ns=5.binarized.tsv
#
#
# Binarization started ....
#
# 		genes processed: 0
# Input is standardized.
# file tmp_results2/TCGA200.seed=794772.bin_method=ward.min_ns=5.binarized.tsv is not found and will be created
# file tmp_results2/TCGA200.seed=794772.bin_method=ward.min_ns=5.binarization_stats.tsv is not found and will be created
# 		genes processed: 1000
# 		genes processed: 2000
# 		genes processed: 3000
# 		genes processed: 4000
# 		genes processed: 5000
# 		genes processed: 6000
# 		genes processed: 7000
# 		genes processed: 8000
# 		genes processed: 9000
# 		genes processed: 10000
# 		genes processed: 11000
# 		genes processed: 12000
# 		genes processed: 13000
# 		genes processed: 14000
# 	Binarization for 14986 features completed in 25.41 s
# 	Generate background distribuition of SNR depending on the bicluster size ...
# 		total samples: 200,
# 		number of samples in a bicluster: 5 - 100,
# 		n_permutations: 10000
# 		snr pval threshold: 0.01
# file tmp_results2/TCGA200.seed=794772.n=10000.min_ns=5.background.tsv is not found and will be created
# 	Background ditribution generated in 0.89 s
# 			LOWESS frac= 0.09
# Binarized gene expressions are saved to tmp_results2/TCGA200.seed=794772.bin_method=ward.min_ns=5.binarized.tsv
# Statistics is saved to tmp_results2/TCGA200.seed=794772.bin_method=ward.min_ns=5.binarization_stats.tsv
# Background sitribution is saved to tmp_results2/TCGA200.seed=794772.n=10000.min_ns=5.background.tsv
# 		UP-regulated features:	1036
# 		DOWN-regulated features:	582
# Clustering features ...
#
# 		WGCNA pre-clustering: True
# 	Running WGCNA for tmp_results2/TCGA200.ward.pval=0.01.seed=794772.DOWN.tmpWGCNA_23.07.11_11:59:34.tsv ...
# 	R command line:
# 	Rscript /home/olya/TUM/DESMOND/DESMOND2/utils/run_WGCNA.R tmp_results2/TCGA200.ward.pval=0.01.seed=794772.DOWN.tmpWGCNA_23.07.11_11:59:34.tsv 4 0.95 signed_hybrid 10 T
# 	WGCNA runtime: modules detected in 16.80 s.
# 	modules: 31, not clustered features 226
# 		WGCNA pre-clustering: True
# 	Running WGCNA for tmp_results2/TCGA200.ward.pval=0.01.seed=794772.UP.tmpWGCNA_23.07.11_11:59:51.tsv ...
# 	R command line:
# 	Rscript /home/olya/TUM/DESMOND/DESMOND2/utils/run_WGCNA.R tmp_results2/TCGA200.ward.pval=0.01.seed=794772.UP.tmpWGCNA_23.07.11_11:59:51.tsv 4 0.95 signed_hybrid 10 T
# b'Warning messages:\n1: replacing previous import \xe2\x80\x98ellipsis::check_dots_unnamed\xe2\x80\x99 by \xe2\x80\x98rlang::check_dots_unnamed\xe2\x80\x99 when loading \xe2\x80\x98tibble\xe2\x80\x99 \n2: replacing previous import \xe2\x80\x98ellipsis::check_dots_used\xe2\x80\x99 by \xe2\x80\x98rlang::check_dots_used\xe2\x80\x99 when loading \xe2\x80\x98tibble\xe2\x80\x99 \n3: replacing previous import \xe2\x80\x98ellipsis::check_dots_empty\xe2\x80\x99 by \xe2\x80\x98rlang::check_dots_empty\xe2\x80\x99 when loading \xe2\x80\x98tibble\xe2\x80\x99 \n4: replacing previous import \xe2\x80\x98ellipsis::check_dots_unnamed\xe2\x80\x99 by \xe2\x80\x98rlang::check_dots_unnamed\xe2\x80\x99 when loading \xe2\x80\x98pillar\xe2\x80\x99 \n5: replacing previous import \xe2\x80\x98ellipsis::check_dots_used\xe2\x80\x99 by \xe2\x80\x98rlang::check_dots_used\xe2\x80\x99 when loading \xe2\x80\x98pillar\xe2\x80\x99 \n6: replacing previous import \xe2\x80\x98ellipsis::check_dots_empty\xe2\x80\x99 by \xe2\x80\x98rlang::check_dots_empty\xe2\x80\x99 when loading \xe2\x80\x98pillar\xe2\x80\x99 \nWarning message:\nexecuting %dopar% sequentially: no parallel backend registered \n'
# 	WGCNA runtime: modules detected in 16.54 s.
# 	modules: 24, not clustered features 972
# 	Jaccard similarities for 55 features computed in 0.02 s.
# b'Warning messages:\n1: replacing previous import \xe2\x80\x98ellipsis::check_dots_unnamed\xe2\x80\x99 by \xe2\x80\x98rlang::check_dots_unnamed\xe2\x80\x99 when loading \xe2\x80\x98tibble\xe2\x80\x99 \n2: replacing previous import \xe2\x80\x98ellipsis::check_dots_used\xe2\x80\x99 by \xe2\x80\x98rlang::check_dots_used\xe2\x80\x99 when loading \xe2\x80\x98tibble\xe2\x80\x99 \n3: replacing previous import \xe2\x80\x98ellipsis::check_dots_empty\xe2\x80\x99 by \xe2\x80\x98rlang::check_dots_empty\xe2\x80\x99 when loading \xe2\x80\x98tibble\xe2\x80\x99 \n4: replacing previous import \xe2\x80\x98ellipsis::check_dots_unnamed\xe2\x80\x99 by \xe2\x80\x98rlang::check_dots_unnamed\xe2\x80\x99 when loading \xe2\x80\x98pillar\xe2\x80\x99 \n5: replacing previous import \xe2\x80\x98ellipsis::check_dots_used\xe2\x80\x99 by \xe2\x80\x98rlang::check_dots_used\xe2\x80\x99 when loading \xe2\x80\x98pillar\xe2\x80\x99 \n6: replacing previous import \xe2\x80\x98ellipsis::check_dots_empty\xe2\x80\x99 by \xe2\x80\x98rlang::check_dots_empty\xe2\x80\x99 when loading \xe2\x80\x98pillar\xe2\x80\x99 \nWarning message:\nexecuting %dopar% sequentially: no parallel backend registered \n'
# No biclusters to merge
# tmp_results2/TCGA200.seed=794772.bin=ward,pval=0.01,clust=WGCNA,direction=DOWN-UP,ds=4,dch=0.95,max_power=10,precluster=True.biclusters.tsv
# Total runtime: 70.11 s
# Read input from: test_data_TCGA200/TCGA_200.exprs_z.tsv
# 	14986 features x 200 samples
# Standardized expressions will be limited to [-3,3]:
# Mininal number of samples in a bicluster: 5
# Load binarized features from tmp_results2/TCGA200.seed=933488.bin_method=ward.min_ns=5.binarized.tsv
#
#
# Binarization started ....
#
# 		genes processed: 0
# Input is standardized.
# file tmp_results2/TCGA200.seed=933488.bin_method=ward.min_ns=5.binarized.tsv is not found and will be created
# file tmp_results2/TCGA200.seed=933488.bin_method=ward.min_ns=5.binarization_stats.tsv is not found and will be created
# 		genes processed: 1000
# 		genes processed: 2000
# 		genes processed: 3000
# 		genes processed: 4000
# 		genes processed: 5000
# 		genes processed: 6000
# 		genes processed: 7000
# 		genes processed: 8000
# 		genes processed: 9000
# 		genes processed: 10000
# 		genes processed: 11000
# 		genes processed: 12000
# 		genes processed: 13000
# 		genes processed: 14000
# 	Binarization for 14986 features completed in 25.59 s
# 	Generate background distribuition of SNR depending on the bicluster size ...
# 		total samples: 200,
# 		number of samples in a bicluster: 5 - 100,
# 		n_permutations: 10000
# 		snr pval threshold: 0.01
# file tmp_results2/TCGA200.seed=933488.n=10000.min_ns=5.background.tsv is not found and will be created
# 	Background ditribution generated in 0.81 s
# 			LOWESS frac= 0.09
# Binarized gene expressions are saved to tmp_results2/TCGA200.seed=933488.bin_method=ward.min_ns=5.binarized.tsv
# Statistics is saved to tmp_results2/TCGA200.seed=933488.bin_method=ward.min_ns=5.binarization_stats.tsv
# Background sitribution is saved to tmp_results2/TCGA200.seed=933488.n=10000.min_ns=5.background.tsv
# 		UP-regulated features:	1041
# 		DOWN-regulated features:	586
# Clustering features ...
#
# 		WGCNA pre-clustering: True
# 	Running WGCNA for tmp_results2/TCGA200.ward.pval=0.01.seed=933488.DOWN.tmpWGCNA_23.07.11_12:00:44.tsv ...
# 	R command line:
# 	Rscript /home/olya/TUM/DESMOND/DESMOND2/utils/run_WGCNA.R tmp_results2/TCGA200.ward.pval=0.01.seed=933488.DOWN.tmpWGCNA_23.07.11_12:00:44.tsv 4 0.95 signed_hybrid 10 T
# 	WGCNA runtime: modules detected in 16.11 s.
# 	modules: 29, not clustered features 213
# 		WGCNA pre-clustering: True
# 	Running WGCNA for tmp_results2/TCGA200.ward.pval=0.01.seed=933488.UP.tmpWGCNA_23.07.11_12:01:00.tsv ...
# 	R command line:
# 	Rscript /home/olya/TUM/DESMOND/DESMOND2/utils/run_WGCNA.R tmp_results2/TCGA200.ward.pval=0.01.seed=933488.UP.tmpWGCNA_23.07.11_12:01:00.tsv 4 0.95 signed_hybrid 10 T
# b'Warning messages:\n1: replacing previous import \xe2\x80\x98ellipsis::check_dots_unnamed\xe2\x80\x99 by \xe2\x80\x98rlang::check_dots_unnamed\xe2\x80\x99 when loading \xe2\x80\x98tibble\xe2\x80\x99 \n2: replacing previous import \xe2\x80\x98ellipsis::check_dots_used\xe2\x80\x99 by \xe2\x80\x98rlang::check_dots_used\xe2\x80\x99 when loading \xe2\x80\x98tibble\xe2\x80\x99 \n3: replacing previous import \xe2\x80\x98ellipsis::check_dots_empty\xe2\x80\x99 by \xe2\x80\x98rlang::check_dots_empty\xe2\x80\x99 when loading \xe2\x80\x98tibble\xe2\x80\x99 \n4: replacing previous import \xe2\x80\x98ellipsis::check_dots_unnamed\xe2\x80\x99 by \xe2\x80\x98rlang::check_dots_unnamed\xe2\x80\x99 when loading \xe2\x80\x98pillar\xe2\x80\x99 \n5: replacing previous import \xe2\x80\x98ellipsis::check_dots_used\xe2\x80\x99 by \xe2\x80\x98rlang::check_dots_used\xe2\x80\x99 when loading \xe2\x80\x98pillar\xe2\x80\x99 \n6: replacing previous import \xe2\x80\x98ellipsis::check_dots_empty\xe2\x80\x99 by \xe2\x80\x98rlang::check_dots_empty\xe2\x80\x99 when loading \xe2\x80\x98pillar\xe2\x80\x99 \nWarning message:\nexecuting %dopar% sequentially: no parallel backend registered \n'
# 	WGCNA runtime: modules detected in 16.02 s.
# 	modules: 24, not clustered features 978
# 	Jaccard similarities for 53 features computed in 0.01 s.
# b'Warning messages:\n1: replacing previous import \xe2\x80\x98ellipsis::check_dots_unnamed\xe2\x80\x99 by \xe2\x80\x98rlang::check_dots_unnamed\xe2\x80\x99 when loading \xe2\x80\x98tibble\xe2\x80\x99 \n2: replacing previous import \xe2\x80\x98ellipsis::check_dots_used\xe2\x80\x99 by \xe2\x80\x98rlang::check_dots_used\xe2\x80\x99 when loading \xe2\x80\x98tibble\xe2\x80\x99 \n3: replacing previous import \xe2\x80\x98ellipsis::check_dots_empty\xe2\x80\x99 by \xe2\x80\x98rlang::check_dots_empty\xe2\x80\x99 when loading \xe2\x80\x98tibble\xe2\x80\x99 \n4: replacing previous import \xe2\x80\x98ellipsis::check_dots_unnamed\xe2\x80\x99 by \xe2\x80\x98rlang::check_dots_unnamed\xe2\x80\x99 when loading \xe2\x80\x98pillar\xe2\x80\x99 \n5: replacing previous import \xe2\x80\x98ellipsis::check_dots_used\xe2\x80\x99 by \xe2\x80\x98rlang::check_dots_used\xe2\x80\x99 when loading \xe2\x80\x98pillar\xe2\x80\x99 \n6: replacing previous import \xe2\x80\x98ellipsis::check_dots_empty\xe2\x80\x99 by \xe2\x80\x98rlang::check_dots_empty\xe2\x80\x99 when loading \xe2\x80\x98pillar\xe2\x80\x99 \nWarning message:\nexecuting %dopar% sequentially: no parallel backend registered \n'
# No biclusters to merge
# tmp_results2/TCGA200.seed=933488.bin=ward,pval=0.01,clust=WGCNA,direction=DOWN-UP,ds=4,dch=0.95,max_power=10,precluster=True.biclusters.tsv
# Total runtime: 68.54 s
# Read input from: test_data_TCGA200/TCGA_200.exprs_z.tsv
# 	14986 features x 200 samples
# Standardized expressions will be limited to [-3,3]:
# Mininal number of samples in a bicluster: 5
# Load binarized features from tmp_results2/TCGA200.seed=441001.bin_method=ward.min_ns=5.binarized.tsv
#
#
# Binarization started ....
#
# 		genes processed: 0
# Input is standardized.
# file tmp_results2/TCGA200.seed=441001.bin_method=ward.min_ns=5.binarized.tsv is not found and will be created
# file tmp_results2/TCGA200.seed=441001.bin_method=ward.min_ns=5.binarization_stats.tsv is not found and will be created
# 		genes processed: 1000
# 		genes processed: 2000
# 		genes processed: 3000
# 		genes processed: 4000
# 		genes processed: 5000
# 		genes processed: 6000
# 		genes processed: 7000
# 		genes processed: 8000
# 		genes processed: 9000
# 		genes processed: 10000
# 		genes processed: 11000
# 		genes processed: 12000
# 		genes processed: 13000
# 		genes processed: 14000
# 	Binarization for 14986 features completed in 25.11 s
# 	Generate background distribuition of SNR depending on the bicluster size ...
# 		total samples: 200,
# 		number of samples in a bicluster: 5 - 100,
# 		n_permutations: 10000
# 		snr pval threshold: 0.01
# file tmp_results2/TCGA200.seed=441001.n=10000.min_ns=5.background.tsv is not found and will be created
# 	Background ditribution generated in 0.82 s
# 			LOWESS frac= 0.09
# Binarized gene expressions are saved to tmp_results2/TCGA200.seed=441001.bin_method=ward.min_ns=5.binarized.tsv
# Statistics is saved to tmp_results2/TCGA200.seed=441001.bin_method=ward.min_ns=5.binarization_stats.tsv
# Background sitribution is saved to tmp_results2/TCGA200.seed=441001.n=10000.min_ns=5.background.tsv
# 		UP-regulated features:	1027
# 		DOWN-regulated features:	574
# Clustering features ...
#
# 		WGCNA pre-clustering: True
# 	Running WGCNA for tmp_results2/TCGA200.ward.pval=0.01.seed=441001.DOWN.tmpWGCNA_23.07.11_12:01:52.tsv ...
# 	R command line:
# 	Rscript /home/olya/TUM/DESMOND/DESMOND2/utils/run_WGCNA.R tmp_results2/TCGA200.ward.pval=0.01.seed=441001.DOWN.tmpWGCNA_23.07.11_12:01:52.tsv 4 0.95 signed_hybrid 10 T
# 	WGCNA runtime: modules detected in 16.34 s.
# 	modules: 33, not clustered features 205
# 		WGCNA pre-clustering: True
# 	Running WGCNA for tmp_results2/TCGA200.ward.pval=0.01.seed=441001.UP.tmpWGCNA_23.07.11_12:02:08.tsv ...
# 	R command line:
# 	Rscript /home/olya/TUM/DESMOND/DESMOND2/utils/run_WGCNA.R tmp_results2/TCGA200.ward.pval=0.01.seed=441001.UP.tmpWGCNA_23.07.11_12:02:08.tsv 4 0.95 signed_hybrid 10 T
# b'Warning messages:\n1: replacing previous import \xe2\x80\x98ellipsis::check_dots_unnamed\xe2\x80\x99 by \xe2\x80\x98rlang::check_dots_unnamed\xe2\x80\x99 when loading \xe2\x80\x98tibble\xe2\x80\x99 \n2: replacing previous import \xe2\x80\x98ellipsis::check_dots_used\xe2\x80\x99 by \xe2\x80\x98rlang::check_dots_used\xe2\x80\x99 when loading \xe2\x80\x98tibble\xe2\x80\x99 \n3: replacing previous import \xe2\x80\x98ellipsis::check_dots_empty\xe2\x80\x99 by \xe2\x80\x98rlang::check_dots_empty\xe2\x80\x99 when loading \xe2\x80\x98tibble\xe2\x80\x99 \n4: replacing previous import \xe2\x80\x98ellipsis::check_dots_unnamed\xe2\x80\x99 by \xe2\x80\x98rlang::check_dots_unnamed\xe2\x80\x99 when loading \xe2\x80\x98pillar\xe2\x80\x99 \n5: replacing previous import \xe2\x80\x98ellipsis::check_dots_used\xe2\x80\x99 by \xe2\x80\x98rlang::check_dots_used\xe2\x80\x99 when loading \xe2\x80\x98pillar\xe2\x80\x99 \n6: replacing previous import \xe2\x80\x98ellipsis::check_dots_empty\xe2\x80\x99 by \xe2\x80\x98rlang::check_dots_empty\xe2\x80\x99 when loading \xe2\x80\x98pillar\xe2\x80\x99 \nWarning message:\nexecuting %dopar% sequentially: no parallel backend registered \n'
# 	WGCNA runtime: modules detected in 15.18 s.
# 	modules: 25, not clustered features 961
# 	Jaccard similarities for 58 features computed in 0.01 s.
# No biclusters to merge
# b'Warning messages:\n1: replacing previous import \xe2\x80\x98ellipsis::check_dots_unnamed\xe2\x80\x99 by \xe2\x80\x98rlang::check_dots_unnamed\xe2\x80\x99 when loading \xe2\x80\x98tibble\xe2\x80\x99 \n2: replacing previous import \xe2\x80\x98ellipsis::check_dots_used\xe2\x80\x99 by \xe2\x80\x98rlang::check_dots_used\xe2\x80\x99 when loading \xe2\x80\x98tibble\xe2\x80\x99 \n3: replacing previous import \xe2\x80\x98ellipsis::check_dots_empty\xe2\x80\x99 by \xe2\x80\x98rlang::check_dots_empty\xe2\x80\x99 when loading \xe2\x80\x98tibble\xe2\x80\x99 \n4: replacing previous import \xe2\x80\x98ellipsis::check_dots_unnamed\xe2\x80\x99 by \xe2\x80\x98rlang::check_dots_unnamed\xe2\x80\x99 when loading \xe2\x80\x98pillar\xe2\x80\x99 \n5: replacing previous import \xe2\x80\x98ellipsis::check_dots_used\xe2\x80\x99 by \xe2\x80\x98rlang::check_dots_used\xe2\x80\x99 when loading \xe2\x80\x98pillar\xe2\x80\x99 \n6: replacing previous import \xe2\x80\x98ellipsis::check_dots_empty\xe2\x80\x99 by \xe2\x80\x98rlang::check_dots_empty\xe2\x80\x99 when loading \xe2\x80\x98pillar\xe2\x80\x99 \nWarning message:\nexecuting %dopar% sequentially: no parallel backend registered \n'
# tmp_results2/TCGA200.seed=441001.bin=ward,pval=0.01,clust=WGCNA,direction=DOWN-UP,ds=4,dch=0.95,max_power=10,precluster=True.biclusters.tsv
# Total runtime: 67.09 s

# %%
for i in range(len(biclusters)):
    print(seeds[i],"n biclusters:", biclusters[i].shape[0] )
# Out:
# 885440 n biclusters: 49
# 403958 n biclusters: 42
# 794772 n biclusters: 55
# 933488 n biclusters: 53
# 441001 n biclusters: 58

# %%
consensus_biclusters = make_consensus_biclusters(biclusters, exprs,frac_runs=1/3, min_n_genes=2,
                                         method = "ward", seed = 42, plot = True,figsize=(10,10))
# Out:
# 3 s for similarity matrix
# 	Running Louvain ...
# 	curve type: increasing
# 	Louvain runtime: modules detected in 0.22 s.
# 	modules: 54, not clustered features 49
# 		similarity cutoff: 0.33 modularity: 0.944
# 1 s for making consensus biclusters from consensus gene sets

# %%
write_bic_table(consensus_biclusters,out_dir+basename+".consensus_seed=42.bin=ward,pval=0.01,clust=WGCNA,direction=DOWN-UP,ds=4,dch=0.95.biclusters.tsv")

# %%
consensus_biclusters
# Out:
#           SNR n_genes n_samples  \
# 0    5.635622       2         8
# 1     2.98157     117        37
# 2    2.686986       6        14
# 3     2.60381       4        18
# 4    2.534845       3        18
# ..        ...     ...       ...
# 98   1.171663       5        54
# 99   1.155158       8        92
# 100  1.101096       8        99
# 101  1.099195       3        74
# 102  1.051647       2        91
#
#                                                  genes  \
# 0                                     {SPRR2D, SPRR2E}
# 1    {SPDEF, ANKRD30B, TSPAN9, SEMA3C, CAPN13, SLC4...
# 2        {LUM, PALM2-AKAP2, ABI3BP, CDH11, DKK2, SV2B}
# 3                         {GRB7, STARD3, PGAP3, ERBB2}
# 4                                 {KRT9, LEMD1, CRYAB}
# ..                                                 ...
# 98            {LUC7L2, SOS2, ISY1-RAB43, GIGYF2, UBR1}
# 99   {MCF2L2, BICC1, TMEM200A, PDGFRA, HLA-DQA2, SO...
# 100  {MCF2L2, SRPX, BICC1, TMEM200A, PDGFRA, B4GALT...
# 101                             {B3GNT3, ADGRF1, FUT3}
# 102                                     {UBR1, MARCH7}
#
#                                                samples  \
# 0    {TCGA-BH-A0C0-01, TCGA-AO-A0JD-01, TCGA-C8-A27...
# 1    {TCGA-E2-A1LS-01, TCGA-AN-A0FL-01, TCGA-B6-A0X...
# 2    {TCGA-E9-A54X-01, TCGA-B6-A0IA-01, TCGA-A2-A3X...
# 3    {TCGA-AR-A0TQ-01, TCGA-LD-A9QF-01, TCGA-A8-A07...
# 4    {TCGA-PL-A8LV-01, TCGA-D8-A147-01, TCGA-AR-A0T...
# ..                                                 ...
# 98   {TCGA-E2-A1LS-01, TCGA-AN-A0FL-01, TCGA-LD-A9Q...
# 99   {TCGA-B6-A0IH-01, TCGA-B6-A0X1-01, TCGA-LD-A9Q...
# 100  {TCGA-E2-A1LS-01, TCGA-E2-A154-01, TCGA-AR-A1A...
# 101  {TCGA-A2-A25E-01, TCGA-E2-A15S-01, TCGA-A2-A0T...
# 102  {TCGA-A2-A25E-01, TCGA-E2-A1LS-01, TCGA-B6-A0I...
#
#                                               genes_up  \
# 0                                     {SPRR2D, SPRR2E}
# 1                                                   {}
# 2                                                   {}
# 3                         {GRB7, STARD3, PGAP3, ERBB2}
# 4                                 {KRT9, LEMD1, CRYAB}
# ..                                                 ...
# 98                                                  {}
# 99   {MCF2L2, BICC1, TMEM200A, PDGFRA, HLA-DQA2, SO...
# 100                                                 {}
# 101                                                 {}
# 102                                     {MARCH7, UBR1}
#
#                                             genes_down  \
# 0                                                   {}
# 1    {SPDEF, ANKRD30B, TSPAN9, SEMA3C, CAPN13, SLC4...
# 2        {LUM, PALM2-AKAP2, ABI3BP, CDH11, DKK2, SV2B}
# 3                                                   {}
# 4                                                   {}
# ..                                                 ...
# 98            {LUC7L2, SOS2, GIGYF2, ISY1-RAB43, UBR1}
# 99                                                  {}
# 100  {MCF2L2, SRPX, BICC1, TMEM200A, PDGFRA, B4GALT...
# 101                             {B3GNT3, ADGRF1, FUT3}
# 102                                                 {}
#
#                                           gene_indexes  \
# 0                                       {12216, 12217}
# 1    {7176, 11785, 5647, 3602, 11795, 11796, 11291,...
# 2                  {7265, 8999, 12519, 2261, 3511, 90}
# 3                            {4114, 5381, 9294, 12367}
# 4                                   {6792, 6901, 2998}
# ..                                                 ...
# 98                    {6282, 13842, 12086, 5083, 7263}
# 99   {864, 1283, 5734, 12519, 9193, 12073, 13133, 7...
# 100  {864, 1283, 9193, 12073, 1163, 13133, 12277, 7...
# 101                                  {296, 4872, 1149}
# 102                                      {7457, 13842}
#
#                                         sample_indexes direction  \
# 0               {66, 100, 136, 106, 114, 179, 116, 90}        UP
# 1    {128, 2, 131, 4, 7, 136, 139, 12, 13, 145, 19,...      DOWN
# 2    {0, 130, 69, 70, 48, 144, 178, 19, 179, 180, 8...      DOWN
# 3    {192, 129, 68, 100, 132, 134, 74, 120, 60, 46,...        UP
# 4    {193, 99, 36, 131, 198, 7, 105, 139, 76, 110, ...        UP
# ..                                                 ...       ...
# 98   {0, 131, 4, 5, 7, 12, 13, 142, 143, 144, 146, ...      DOWN
# 99   {1, 4, 8, 9, 10, 11, 14, 16, 20, 22, 23, 28, 3...        UP
# 100  {0, 2, 3, 5, 7, 13, 15, 17, 19, 21, 24, 25, 26...      DOWN
# 101  {130, 5, 6, 133, 138, 140, 141, 14, 15, 143, 1...      DOWN
# 102  {1, 3, 6, 8, 9, 10, 14, 15, 16, 17, 18, 22, 23...        UP
#
#      detected_n_times
# 0                   5
# 1                   6
# 2                   2
# 3                   5
# 4                   5
# ..                ...
# 98                  1
# 99                  1
# 100                 4
# 101                 1
# 102                 1
#
# [103 rows x 11 columns]

# %%
g = "ERBB2"
b= consensus_biclusters
b[b["genes"].apply(lambda x: g in x)]
# Out:
#        SNR n_genes n_samples                         genes  \
# 3  2.60381       4        18  {GRB7, STARD3, PGAP3, ERBB2}
#
#                                              samples  \
# 3  {TCGA-AR-A0TQ-01, TCGA-LD-A9QF-01, TCGA-A8-A07...
#
#                        genes_up genes_down               gene_indexes  \
# 3  {GRB7, STARD3, PGAP3, ERBB2}         {}  {4114, 5381, 9294, 12367}
#
#                                       sample_indexes direction  \
# 3  {192, 129, 68, 100, 132, 134, 74, 120, 60, 46,...        UP
#
#    detected_n_times
# 3                 5

# %%
g = "ESR1"
b[b["genes"].apply(lambda x: g in x)]
# Out:
#         SNR n_genes n_samples  \
# 17  1.99861      99        61
#
#                                                 genes  \
# 17  {CCDC170, DDO, DNAH5, IGSF9B, GATA3-AS1, CLSTN...
#
#                                               samples genes_up  \
# 17  {TCGA-E2-A1LS-01, TCGA-AN-A0FL-01, TCGA-LD-A9Q...       {}
#
#                                            genes_down  \
# 17  {IGSF9B, DNAH5, CCDC170, DDO, GATA3-AS1, CLSTN...
#
#                                          gene_indexes  \
# 17  {3596, 1038, 13331, 20, 4117, 7192, 7197, 5149...
#
#                                        sample_indexes direction  \
# 17  {0, 128, 2, 129, 4, 131, 132, 7, 134, 135, 136...      DOWN
#
#     detected_n_times
# 17                 5

# %%
g = "FOXA1"
b= consensus_biclusters
b[b["genes"].apply(lambda x: g in x)]
# Out:
#        SNR n_genes n_samples  \
# 1  2.98157     117        37
#
#                                                genes  \
# 1  {SPDEF, ANKRD30B, TSPAN9, SEMA3C, CAPN13, SLC4...
#
#                                              samples genes_up  \
# 1  {TCGA-E2-A1LS-01, TCGA-AN-A0FL-01, TCGA-B6-A0X...       {}
#
#                                           genes_down  \
# 1  {SPDEF, ANKRD30B, TSPAN9, SEMA3C, CAPN13, SLC4...
#
#                                         gene_indexes  \
# 1  {7176, 11785, 5647, 3602, 11795, 11796, 11291,...
#
#                                       sample_indexes direction  \
# 1  {128, 2, 131, 4, 7, 136, 139, 12, 13, 145, 19,...      DOWN
#
#    detected_n_times
# 1                 6

# %%
from utils.figs import draw_heatmap2,draw_heatmap
from utils.method import zscore

# %%
i = [3,1,17]
b = consensus_biclusters.loc[i,:]

show_genes = []
for j in b.index.values:
    show_genes += sorted(b.loc[j,"genes_down"])+sorted(b.loc[j,"genes_up"])
show_genes= sorted(set(show_genes))
print("genes in ",i,"  :",len(show_genes))
tmp = draw_heatmap2(zscore(exprs.loc[show_genes,:]),b,cluster_rows=False,
                    col_labels = False,row_labels = True,
                    figsize = (20,10),bic_prefix = "",)
# Out:
# genes in  [3, 1, 17]   : 218
