# %% [markdown]
# #  Compare biclusters detected in TCGA and METABRIC

# %%
import pandas as pd
from collections import OrderedDict

import sys
sys.path.insert(0, '..')
from unpast.utils.io import read_bic_table
from unpast.utils.eval import evaluate_overlaps_ARI, apply_bh, find_best_matching_biclusters
from unpast.utils.figs import draw_heatmap2


import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# input folders 
data_dir = "../data/breast_cancer/"
# output  olders 
out_dir = "../../Supplementary_tables_and_data/TableS2/"
img_dir = "../../img/"

# %%
# reading expressions and metadata
subt_anno_tcga = pd.read_csv(data_dir+"TCGA-BRCA_1079_17Kgenes.Xena_TCGA_PanCan.subtypes_and_signatures_v6.tsv.gz",sep ="\t",index_col=0)
anno_tcga = pd.read_csv(data_dir+"TCGA-BRCA_1079.Xena_TCGA_PanCan.annotation_v6.tsv.gz",sep ="\t",index_col=0)
anno_tcga = pd.concat([anno_tcga.loc[subt_anno_tcga.index,:], subt_anno_tcga],axis=1)
anno_tcga["stage_34"] = anno_tcga["stage_3"] + anno_tcga["stage_4"] 

subt_anno_meta = pd.read_csv(data_dir+"METABRIC_1904_17Kgenes.subtypes_and_signatures_v6.tsv.gz",sep ="\t",index_col=0)
anno_meta = pd.read_csv(data_dir+"METABRIC_1904.annotation_v6.tsv.gz",sep ="\t",index_col=0)
anno_meta = pd.concat([anno_meta.loc[subt_anno_meta.index,:], subt_anno_meta],axis=1)
anno_meta["stage_34"] = anno_meta["stage_3"] + anno_meta["stage_4"]

exprs_tcga = pd.read_csv(data_dir+"TCGA-BRCA_1079_17Kgenes.Xena_TCGA_PanCan.log2_exprs_z_v6.tsv.gz",sep = "\t",index_col=0)
exprs_meta = pd.read_csv(data_dir+"METABRIC_1904_17Kgenes.log2_exprs_z_v6.tsv.gz",sep = "\t",index_col=0)

# %%
# pre-computed biclusters
analysis_seed = 42
suffix = ".consensus_seed="+str(analysis_seed)+".bin=kmeans,pval=0.01,clust=WGCNA,direction=DOWN-UP,ds=3,dch=0.995,max_power=10,precluster=True.biclusters.tsv"

bics_tcga = read_bic_table("../../outputs/TCGA-BRCA/UnPaSt/optimized/TCGA-BRCA"+suffix)
print("Biclusters in Discovery dataset:", bics_tcga.shape[0])
bics_tcga = bics_tcga.loc[bics_tcga["detected_n_times"]>1,:]
print("\t:", bics_tcga.shape[0])

bics_meta = read_bic_table("../../outputs/METABRIC/UnPaSt/optimized/METABRIC"+suffix)
print("Biclusters in Validation dataset:", bics_meta.shape[0])
bics_meta = bics_meta.loc[bics_meta["detected_n_times"]>1,:]
print("\t:", bics_meta.shape[0])
# Out:
# Biclusters in Discovery dataset: 209
# 	: 209
# Biclusters in Validation dataset: 180
# 	: 180

# %% [markdown]
# # similarity to PAM50 subtypes

# %%
all_samples_meta = set(exprs_meta.columns.values)
subts_meta = {}
subts_meta["Luminal"] = set([])
for subt in set(anno_meta["PAM50"].values):
    #if not subt.startswith("Lum"):
    subts_meta[subt] = set(anno_meta.loc[anno_meta["PAM50"]==subt,:].index.values)
    print(subt, len(subts_meta[subt]))
    if subt.startswith("Lum"):
        subts_meta["Luminal"] |= set(anno_meta.loc[anno_meta["PAM50"]==subt,:].index.values)
    


pvals_meta, is_enriched_meta, ari_meta = evaluate_overlaps_ARI(bics_meta, subts_meta, all_samples_meta)
adj_pvals_meta  = apply_bh(pvals_meta, a = 0.05)
adj_pvals_meta["min_pval_META"] = adj_pvals_meta.min(axis=1)
ari_meta["max_ARI_META"] = ari_meta.max(axis=1)
# Out:
# LumA 598
# LumB 764
# Basal 244
# Normal 54
# Her2 244

# %%
pvals_meta.loc[pvals_meta["LumA"]>0.01,:].sort_values(by='LumB')
# Out:
#            Normal     Basal          Her2      LumA      LumB       Luminal
# 8    4.182916e-02  0.266123  2.674539e-07  0.015884  0.000001  4.649751e-07
# 63   2.575852e-01  0.003394  3.319199e-01  0.016369  0.000002  4.506058e-04
# 1    3.624859e-01  0.000002  1.719605e-04  0.742278  0.000002  2.096358e-06
# 73   4.341467e-07  0.000002  2.059067e-06  0.036337  0.000003  2.929354e-06
# 58   5.593979e-02  0.000002  1.784842e-06  0.051575  0.000003  2.148728e-06
# 27   1.952768e-03  0.000002  2.461274e-06  0.587849  0.000003  2.088950e-06
# 46   3.124443e-03  0.000001  1.078222e-06  0.423842  0.000003  2.207781e-06
# 52   7.534179e-07  0.000003  1.623591e-02  0.094793  0.000003  3.451166e-06
# 166  2.016191e-04  0.000002  1.676166e-04  0.032363  0.000003  3.392825e-06
# 84   4.118725e-06  0.000002  2.279140e-06  0.215586  0.000003  3.392825e-06
# 68   1.262740e-06  0.000002  2.337164e-06  0.041555  0.000004  3.388702e-06
# 98   2.927589e-03  0.000002  5.642803e-01  0.782028  0.000004  3.169286e-06
# 175  7.656742e-06  0.000003  4.921694e-04  0.136096  0.000004  4.043246e-06
# 61   1.186160e-06  0.000003  3.107734e-06  0.273557  0.000004  3.805553e-06
# 17   1.006644e-04  0.000002  5.524311e-01  0.027844  0.000005  3.084490e-06
# 137  2.036736e-06  0.000003  1.701235e-05  0.397806  0.000005  4.012299e-06
# 129  4.599225e-01  0.000003  1.007984e-02  0.427994  0.000005  3.549387e-06
# 109  9.307821e-07  0.000002  2.353741e-06  0.073194  0.000005  4.445560e-06
# 149  8.040718e-03  0.001197  3.354153e-01  0.015227  0.000007  9.301094e-03
# 112  7.183305e-04  0.000003  5.195542e-02  0.051308  0.000008  3.596799e-06
# 69   1.759441e-02  0.000002  1.331678e-04  0.079665  0.000085  1.150043e-02
# 21   6.213083e-01  0.000002  2.098988e-03  0.114335  0.000120  2.133568e-06
# 178  1.949182e-01  0.000002  2.416109e-06  0.895376  0.000140  2.535904e-05
# 83   1.668472e-06  0.000003  3.898931e-06  0.880413  0.000174  1.077786e-04
# 3    6.232938e-01  0.305227  6.121518e-01  0.027222  0.000186  6.091783e-02
# 128  3.138700e-01  0.000002  2.239830e-03  0.365222  0.000202  2.744985e-03
# 38   2.969380e-02  0.000001  3.064640e-02  0.121162  0.000453  1.994675e-06
# 179  1.273207e-06  1.000000  7.847488e-04  0.239120  0.000818  5.945396e-06
# 4    1.123595e-01  0.000020  1.697628e-04  0.035924  0.001095  1.918907e-06
# 10   4.137052e-01  0.000520  7.550852e-02  0.572462  0.001895  6.655765e-06
# 64   4.087011e-01  0.000004  3.028587e-01  0.022890  0.007569  3.488910e-06
# 5    1.000000e+00  0.000211  2.133447e-03  0.104826  0.010065  1.037072e-06
# 159  7.839365e-03  0.000005  8.574271e-03  0.712885  0.036561  8.033138e-03
# 48   3.339329e-01  0.217693  1.189073e-04  0.126004  0.101957  7.966369e-04
# 33   1.084199e-06  0.000002  7.145178e-01  0.035282  0.406845  2.404938e-01
# 124  6.961763e-03  0.000003  3.457181e-06  0.687182  0.567542  8.765767e-01
# 164  7.819179e-01  0.449001  3.709031e-01  0.372329  0.672700  1.535263e-01
# 66   6.758155e-01  0.212647  3.158564e-02  0.764641  0.924725  6.443665e-01
# 156  9.526373e-02  0.001926  5.357528e-01  0.059403  0.925160  3.641186e-02

# %%
all_samples_tcga = set(exprs_tcga.columns.values)

subts_tcga = {}
subts_tcga["Luminal"] = set([])
for subt in set(anno_tcga["PAM50"].values):
    subts_tcga[subt] = set(anno_tcga.loc[anno_tcga["PAM50"]==subt,:].index.values)
    print(subt, len(subts_tcga[subt]))
    if subt.startswith("Lum"):
        subts_tcga["Luminal"] |= set(anno_tcga.loc[anno_tcga["PAM50"]==subt,:].index.values)
    


pvals_tcga, is_enriched, ari_tcga = evaluate_overlaps_ARI(bics_tcga, subts_tcga, all_samples_tcga)
adj_pvals_tcga  = apply_bh(pvals_tcga, a = 0.05)
adj_pvals_tcga["min_pval_TCGA"] = adj_pvals_tcga.min(axis=1)
ari_tcga["max_ARI_TCGA"] = ari_tcga.max(axis=1)
# Out:
# LumA 426
# LumB 318
# Basal 195
# Normal 32
# Her2 108

# %%
bics_tcga["max_ARI"] = ari_tcga.loc[bics_tcga.index,"max_ARI_TCGA"]
bics_meta["max_ARI"] = ari_meta.loc[bics_meta.index,"max_ARI_META"]

# %% [markdown]
# # Best matches
#
# * significant
# * J>=0.1
#
# most interesting - with low max. ARI in TCGA and METABRIC

# %%
b1 = bics_tcga
b2 = bics_meta
print(b1.shape[0],b2.shape[0])
bm = find_best_matching_biclusters(b1,b2,(exprs_tcga.shape[0],0), by="genes")

bics_tcga["bm_id"] = bm.loc[bics_tcga.index,"bm_id"]
bics_tcga["bm_J"] = bm.loc[bics_tcga.index,"J"]
# Out:
# 209 180

# %%
bm = bm.dropna()
print("matched:",bm.shape[0])
bm = bm.loc[bm["J"]>=0.1,:].sort_values("n_shared_genes",ascending =False)
print("matched with J>=0.1:",bm.shape[0])
bm["union_genes"] = bm.apply(lambda row: row["genes"] | row["bm_genes"],axis=1)
bm["n_union_genes"] = bm["union_genes"].apply(len)
cols = [x for x in bm.columns if not "shared_samples" in x]
bm = bm.loc[:,cols]
# Out:
# matched: 75
# matched with J>=0.1: 45

# %%
df = pd.concat([bm,adj_pvals_tcga.loc[bm.index.values,['min_pval_TCGA']],
                ari_tcga.loc[bm.index.values,['max_ARI_TCGA']]], axis=1)
df = df.join(adj_pvals_meta.loc[bm["bm_id"].values,['min_pval_META']], on="bm_id")
df = df.join(ari_meta.loc[bm["bm_id"].values,['max_ARI_META']], on="bm_id")

df = df.drop_duplicates(subset=["bm_id","n_genes","n_samples","n_shared_genes"]).sort_values(by = "n_shared_genes",ascending = False)

# %%
d = df.loc[:,:].copy()
cols = ["genes", "samples","shared_genes","bm_genes","bm_samples"]
for col in cols:
    d[col] = d[col].apply(lambda x: " ".join(sorted(x)) ) 
d.to_csv(out_dir + "45_matched_J0.1.tsv",sep="\t")

# %%
df["max_ARI"] = df.apply(lambda x: max(x["max_ARI_TCGA"],x["max_ARI_META"]),axis=1)
potentially_novel = df.loc[df["max_ARI"]<0.25,:]
print(potentially_novel.shape[0])
potentially_novel
# Out:
# 34
#     bm_id         J adj_pval  \
# 64     35  0.354839      0.0
# 100   163  0.268293      0.0
# 128    60      0.36      0.0
# 5       5  0.186047      0.0
# 36     22  0.106383      0.0
# 63    142  0.142857      0.0
# 140   139  0.142857      0.0
# 55     18       0.4      0.0
# 151    81       0.6      0.0
# 114    55    0.1875      0.0
# 74     35  0.107143      0.0
# 171    85       0.5      0.0
# 181    74  0.272727      0.0
# 112   128      0.75      0.0
# 179    28       0.5      0.0
# 27      3  0.333333      0.0
# 107    24  0.666667      0.0
# 75     20       0.5      0.0
# 124    19  0.133333      0.0
# 7       9       0.4      0.0
# 139    46  0.285714      0.0
# 142    63      0.25      0.0
# 158   100  0.285714      0.0
# 145    98  0.153846      0.0
# 167   108  0.111111      0.0
# 31     13       1.0      0.0
# 178     4  0.666667      0.0
# 60     31       0.5      0.0
# 57    162  0.666667      0.0
# 184    41      0.25      0.0
# 187    84       0.4      0.0
# 196   172       0.2      0.0
# 87    172  0.285714      0.0
# 24    124      0.25      0.0
#
#                                                  genes n_genes n_samples  \
# 64   {CMC2, IST1, KARS1, BRD7, NAE1, AARS1, PSMD7, ...      20       492
# 100  {TRARG1, PRG4, CNTFR, ADH1C, CTSG, CIDEC, PLIN...      18       526
# 128  {IFIT1, IFNL2, MX1, IFI44L, CMPK2, BATF2, IFI2...      16       413
# 5    {GPR148, ACTL6B, CARTPT, HRH3, ELFN2, XKR7, SL...      23        48
# 36   {CFHR4, H2BW1, VCX, SOHLH1, C12orf56, GABRA3, ...      44        93
# 63   {MED30, MTFR1, PABPC1, POP1, SLC52A2, ZNF706, ...      26       439
# 140  {CYP4A11, SP5, WFDC6, HABP2, ABCC11, FAM170A, ...      26       537
# 55     {HOXB-AS3, HOXB5, HOXB6, HOXB1, LGALS9B, HOXB4}       6       268
# 151                          {H1-6, H4C8, H2BC4, H1-2}       4       505
# 114  {CALML3, TP63, KRT14, TENM2, COL17A1, NTF4, KR...       9       417
# 74   {UTP4, CBFB, NIP7, KARS1, NAE1, PSMD7, RFWD3, ...       9       443
# 171                           {TUBA3E, TUBA3D, TUBA3C}       3       390
# 181               {UGT2B28, UGT2B10, ALOX15B, UGT2B11}       4       212
# 112                       {KLK12, KLK14, KLK13, KLK10}       4       357
# 179                         {FGA, FGG, C8B, FGL1, FGB}       5       194
# 27                 {SPANXA2, SPANXB1, SPANXD, SPANXN1}       4        60
# 107                                       {ORM2, ORM1}       2       357
# 75                         {EMX1, SYT1, VSTM2A, CBLN2}       4       455
# 124  {GUCY1B2, CBY2, KRTAP4-1, ALG1L1P, STK31, TYRP...      10       283
# 7                             {CT45A5, CT45A2, CT45A3}       3        30
# 139                 {CST13P, CST9L, CST9, CST11, RBP2}       5       242
# 142            {RNF225, FAM25C, ALOX15, FAM25A, LYZL2}       5       195
# 158                 {CTSG, CPA3, MS4A2, TPSD1, GCSAML}       5       468
# 145  {LINC00052, TMEM150C, MS4A18, IGDCC3, ADORA2A,...      13       483
# 167                                {EGR1, FOSB, NR4A1}       3       437
# 31                                   {S100A7A, S100A7}       2       255
# 178                          {CYP2A7, CYP2A6, CYP2A13}       3       179
# 60                                  {SERPINA6, PPP4R4}       2       362
# 57                                        {PAH, ASCL1}       2       324
# 184    {TDRG1, INTS4, PPFIA1, DQX1, TCL1B, CTTN, LTO1}       7       196
# 187             {RMND1, ARMT1, BRDT, LINC03042, PLCD4}       5       491
# 196            {CST4, ABCC12, BPIFB2, BPIFB6, KAZALD1}       5       358
# 87                                  {SCGB2A1, SCGB1D2}       2       470
# 24              {HOXC11, MNX1, HOTAIR, HOXC13, HOXC10}       5       274
#
#                                                samples  \
# 64   {TCGA-B6-A0WT-01, TCGA-BH-A0BC-01, TCGA-A2-A25...
# 100  {TCGA-AR-A24V-01, TCGA-B6-A0WT-01, TCGA-AO-A03...
# 128  {TCGA-AR-A24V-01, TCGA-BH-A0BC-01, TCGA-AO-A03...
# 5    {TCGA-BH-A1FR-01, TCGA-A8-A08L-01, TCGA-E2-A10...
# 36   {TCGA-A2-A0EY-01, TCGA-A8-A06Z-01, TCGA-AN-A0F...
# 63   {TCGA-AR-A24V-01, TCGA-A2-A25E-01, TCGA-A2-A0C...
# 140  {TCGA-AR-A24V-01, TCGA-A2-A25E-01, TCGA-A2-A0C...
# 55   {TCGA-C8-A12O-01, TCGA-E2-A1B5-01, TCGA-EW-A1P...
# 151  {TCGA-B6-A0WT-01, TCGA-A2-A25E-01, TCGA-A2-A0C...
# 114  {TCGA-A2-A1G4-01, TCGA-E2-A9RU-01, TCGA-WT-AB4...
# 74   {TCGA-A2-A25E-01, TCGA-AR-A0U0-01, TCGA-BH-A6R...
# 171  {TCGA-AR-A24V-01, TCGA-A2-A25E-01, TCGA-A2-A0S...
# 181  {TCGA-GM-A5PV-01, TCGA-BH-A1EN-01, TCGA-E2-A10...
# 112  {TCGA-A2-A0CT-01, TCGA-AR-A0U0-01, TCGA-B6-A0R...
# 179  {TCGA-C8-A12O-01, TCGA-EW-A6S9-01, TCGA-AC-A6I...
# 27   {TCGA-B6-A0IO-01, TCGA-AC-A7VC-01, TCGA-B6-A0R...
# 107  {TCGA-B6-A0WT-01, TCGA-AR-A0U0-01, TCGA-A2-A0S...
# 75   {TCGA-B6-A0WT-01, TCGA-BH-A0BC-01, TCGA-A2-A25...
# 124  {TCGA-E2-A109-01, TCGA-AC-A6IW-01, TCGA-A2-A0E...
# 7    {TCGA-OL-A5RW-01, TCGA-AO-A0J6-01, TCGA-AR-A0U...
# 139  {TCGA-AR-A24V-01, TCGA-GM-A5PV-01, TCGA-AC-A7V...
# 142  {TCGA-C8-A12O-01, TCGA-AC-A7VB-01, TCGA-B6-A0W...
# 158  {TCGA-BH-A0BC-01, TCGA-A2-A25E-01, TCGA-AR-A0U...
# 145  {TCGA-AR-A24V-01, TCGA-B6-A0WT-01, TCGA-AO-A03...
# 167  {TCGA-A2-A25E-01, TCGA-AO-A03L-01, TCGA-A2-A0C...
# 31   {TCGA-C8-A12N-01, TCGA-AO-A0J6-01, TCGA-A2-A0T...
# 178  {TCGA-E2-A1B5-01, TCGA-E2-A109-01, TCGA-AC-A6I...
# 60   {TCGA-BH-A0BC-01, TCGA-A2-A25E-01, TCGA-AO-A03...
# 57   {TCGA-AR-A24V-01, TCGA-B6-A0WT-01, TCGA-BH-A0B...
# 184  {TCGA-C8-A12O-01, TCGA-AR-A24V-01, TCGA-AC-A7V...
# 187  {TCGA-AR-A24V-01, TCGA-B6-A0WT-01, TCGA-BH-A0B...
# 196  {TCGA-BH-A0BC-01, TCGA-B6-A0RO-01, TCGA-B6-A0R...
# 87   {TCGA-AR-A24V-01, TCGA-B6-A0WT-01, TCGA-AO-A03...
# 24   {TCGA-AR-A24V-01, TCGA-B6-A0WT-01, TCGA-A2-A25...
#
#                                           shared_genes n_shared_genes  \
# 64   {CMC2, USB1, NUP93, IST1, KARS1, BRD7, COQ9, A...             11
# 100  {PRG4, CNTFR, CIDEC, PLIN4, FABP4, PLIN1, THRS...             11
# 128  {IFIT1, MX1, IFI44L, BATF2, CMPK2, IFI27, OASL...              9
# 5    {SLITRK1, CHGB, CHGA, SEZ6, ACTL6B, SYT4, CART...              8
# 36              {CSAG2, CTAG2, CSAG1, MAGEA10, MAGEA6}              5
# 63                         {MTFR1, MTERF3, ELOC, SQLE}              4
# 140                  {SOWAHA, SHROOM1, HMGCS2, LRRC31}              4
# 55                     {HOXB4, HOXB-AS3, HOXB6, HOXB5}              4
# 151                                {H1-2, H2BC4, H4C8}              3
# 114                            {CALML3, TP63, COL17A1}              3
# 74                              {KARS1, OGFOD1, RFWD3}              3
# 171                           {TUBA3E, TUBA3C, TUBA3D}              3
# 181                        {UGT2B10, UGT2B11, UGT2B28}              3
# 112                              {KLK12, KLK13, KLK10}              3
# 179                                    {FGA, FGG, FGB}              3
# 27                                   {SPANXA2, SPANXD}              2
# 107                                       {ORM2, ORM1}              2
# 75                                     {VSTM2A, CBLN2}              2
# 124                                   {GNGT1, ALG1L1P}              2
# 7                                     {CT45A5, CT45A3}              2
# 139                                      {CST9L, CST9}              2
# 142                                   {FAM25C, FAM25A}              2
# 158                                      {CPA3, MS4A2}              2
# 145                                    {MS4A8, MS4A15}              2
# 167                                      {FOSB, NR4A1}              2
# 31                                   {S100A7A, S100A7}              2
# 178                                   {CYP2A7, CYP2A6}              2
# 60                                  {SERPINA6, PPP4R4}              2
# 57                                        {ASCL1, PAH}              2
# 184                                     {PPFIA1, LTO1}              2
# 187                                     {RMND1, ARMT1}              2
# 196                                  {KAZALD1, BPIFB2}              2
# 87                                  {SCGB2A1, SCGB1D2}              2
# 24                                    {HOXC10, HOTAIR}              2
#
#                                               bm_genes bm_n_genes  \
# 64   {CMC2, TUBB3, KATNB1, IST1, KARS1, BRD7, AARS1...         22
# 100  {LPL, MAOA, CNTFR, SAA1, THRSP, PLIN4, HSPB6, ...         34
# 128  {IFIT1, MX1, RSAD2, IFI44L, CMPK2, BATF2, IFI2...         18
# 5    {SLC6A17, SCG3, OGDHL, ACTL6B, PCSK1, CARTPT, ...         28
# 36   {MAGEA9B, MAGEA4, CSAG2, CTAG2, DSCR8, CSAG1, ...          8
# 63           {MTFR1, TMEM70, RRS1, MTERF3, SQLE, ELOC}          6
# 140    {FRMPD3, LRRC31, SOWAHA, GDF9, SHROOM1, HMGCS2}          6
# 55   {HOXB-AS3, HOXB5, HOXB7, HOXB6, HOXB4, HOXB3, ...          8
# 151                          {H4C8, H3C4, H2BC4, H1-2}          4
# 114  {CALML3, OPRPN, TP63, DST, MYL7, PAMR1, NSG1, ...         10
# 74   {CMC2, TUBB3, KATNB1, IST1, KARS1, BRD7, AARS1...         22
# 171      {TUBA3D, PDZK1, CITED1, TUBA3C, TUBA3E, LEF1}          6
# 181  {UGT2B7, MBOAT2, UGT2B4, UGT2B10, UGT2A3, UGT2...         10
# 112                              {KLK12, KLK13, KLK10}          3
# 179                               {LBP, FGA, FGG, FGB}          4
# 27                    {SPANXD, SPANXA2, SPANXC, NDST4}          4
# 107                                  {LBP, ORM2, ORM1}          3
# 75                                     {VSTM2A, CBLN2}          2
# 124  {WDR72, VCX, C12orf56, ALG1L1P, GNGT1, VCX3A, ...          7
# 7                     {CT45A5, MAGEA8, CT45A6, CT45A3}          4
# 139                   {COL2A1, LINC03006, CST9L, CST9}          4
# 142             {GDPD3, FAM25C, SYNPO2L, FAM25A, SNCG}          5
# 158                       {CPA3, LTC4S, MS4A2, TPSAB1}          4
# 145                                    {MS4A8, MS4A15}          2
# 167  {RASD1, CXCL2, FOSB, NR4A1, PTGS2, ATF3, CCN1,...         17
# 31                                   {S100A7A, S100A7}          2
# 178                                   {CYP2A7, CYP2A6}          2
# 60                 {SERPINA1, IGSF1, SERPINA6, PPP4R4}          4
# 57                               {PAH, PHACTR3, ASCL1}          3
# 184                             {CLNS1A, PPFIA1, LTO1}          3
# 187                                     {RMND1, ARMT1}          2
# 196  {UNC5A, SCGB1D2, ASRGL1, BPIFB2, SCGB2A1, KAZA...          7
# 87   {UNC5A, SCGB1D2, ASRGL1, BPIFB2, SCGB2A1, KAZA...          7
# 24                {SIX1, HOTAIR, IGSF5, HOXC10, HOXC9}          5
#
#     bm_n_samples                                         bm_samples  \
# 64           853  {MB-6063, MB-6114, MB-0223, MB-2984, MB-2951, ...
# 100          465  {MB-6079, MB-5179, MB-0537, MB-2951, MB-0623, ...
# 128          658  {MB-5179, MB-0537, MB-0223, MB-2984, MB-7019, ...
# 5             66  {MB-4008, MB-5044, MB-7076, MB-3748, MB-5197, ...
# 36            99  {MB-0627, MB-3153, MB-0370, MB-0656, MB-5209, ...
# 63           698  {MB-6079, MB-6114, MB-0872, MB-2984, MB-5197, ...
# 140          492  {MB-5179, MB-4667, MB-0872, MB-2933, MB-5425, ...
# 55           348  {MB-5179, MB-4667, MB-2933, MB-5197, MB-5495, ...
# 151          636  {MB-6079, MB-5533, MB-4651, MB-7028, MB-3005, ...
# 114          458  {MB-0537, MB-0223, MB-0872, MB-2951, MB-5495, ...
# 74           853  {MB-6063, MB-6114, MB-0223, MB-2984, MB-2951, ...
# 171          296  {MB-4950, MB-4626, MB-6204, MB-0223, MB-5014, ...
# 181          295  {MB-0605, MB-4950, MB-0482, MB-0129, MB-5179, ...
# 112          153  {MB-5378, MB-5179, MB-0872, MB-3153, MB-0418, ...
# 179          111  {MB-0605, MB-6063, MB-2984, MB-0542, MB-3031, ...
# 27            35  {MB-5313, MB-5384, MB-5452, MB-7023, MB-0225, ...
# 107          215  {MB-6063, MB-0129, MB-5258, MB-3153, MB-3014, ...
# 75           224  {MB-3351, MB-5334, MB-0180, MB-5211, MB-5224, ...
# 124          136  {MB-0627, MB-6204, MB-5197, MB-5641, MB-6118, ...
# 7             32  {MB-0191, MB-3436, MB-7092, MB-7023, MB-0325, ...
# 139          203  {MB-6079, MB-7006, MB-0223, MB-0600, MB-0480, ...
# 142          125  {MB-3153, MB-5197, MB-0600, MB-6030, MB-5334, ...
# 158          762  {MB-5179, MB-0537, MB-0872, MB-2933, MB-2984, ...
# 145          284  {MB-6079, MB-0627, MB-5425, MB-0418, MB-0584, ...
# 167          448  {MB-0537, MB-0223, MB-0872, MB-5495, MB-5533, ...
# 31           222  {MB-6063, MB-4626, MB-0129, MB-6114, MB-2984, ...
# 178          100  {MB-6079, MB-4626, MB-3328, MB-5211, MB-0336, ...
# 60           308  {MB-5425, MB-0223, MB-5495, MB-4328, MB-7112, ...
# 57           202  {MB-6079, MB-7298, MB-7076, MB-0223, MB-5014, ...
# 184          278  {MB-4626, MB-0168, MB-5014, MB-2951, MB-7142, ...
# 187          495  {MB-6079, MB-0223, MB-7296, MB-3328, MB-7028, ...
# 196          600  {MB-5179, MB-0537, MB-0872, MB-2933, MB-5197, ...
# 87           600  {MB-5179, MB-0537, MB-0872, MB-2933, MB-5197, ...
# 24           765  {MB-6079, MB-6063, MB-5179, MB-4667, MB-0872, ...
#
#                                            union_genes  n_union_genes  \
# 64   {CMC2, TUBB3, KATNB1, IST1, KARS1, BRD7, NAE1,...             31
# 100  {TRARG1, LPL, MAOA, CNTFR, SAA1, THRSP, PLIN4,...             41
# 128  {IFIT1, IFI44L, CMPK2, IFNL1, IFIT2, IFI6, OAS...             25
# 5    {SLC6A17, GPR148, SCG3, OGDHL, ACTL6B, PCSK1, ...             43
# 36   {CFHR4, H2BW1, VCX, SOHLH1, C12orf56, GABRA3, ...             47
# 63   {MED30, MTFR1, PABPC1, POP1, EMC2, TMEM70, NSM...             28
# 140  {CYP4A11, GPR162, SP5, WFDC6, HABP2, LRRC31, A...             28
# 55   {HOXB-AS3, HOXB5, HOXB6, HOXB1, LGALS9B, HOXB4...             10
# 151                    {H1-6, H1-2, H2BC4, H3C4, H4C8}              5
# 114  {NTF4, PIGR, COL17A1, FAT2, DSG3, ECRG4, CALML...             16
# 74   {CMC2, UTP4, TUBB3, USB1, KATNB1, CBFB, IST1, ...             28
# 171      {TUBA3D, PDZK1, CITED1, TUBA3C, TUBA3E, LEF1}              6
# 181  {UGT2B7, MBOAT2, UGT2B4, GNMT, UGT2B10, SLC26A...             11
# 112                       {KLK14, KLK10, KLK12, KLK13}              4
# 179                    {FGA, FGG, FGB, LBP, FGL1, C8B}              6
# 27   {SPANXA2, SPANXD, SPANXN1, NDST4, SPANXC, SPAN...              6
# 107                                  {ORM2, ORM1, LBP}              3
# 75                         {CBLN2, EMX1, SYT1, VSTM2A}              4
# 124  {WDR72, VCX, GUCY1B2, CBY2, C12orf56, KRTAP4-1...             15
# 7             {CT45A5, CT45A2, CT45A6, MAGEA8, CT45A3}              5
# 139  {LINC03006, CST13P, CST9L, CST9, CST11, COL2A1...              7
# 142  {GDPD3, RNF225, ALOX15, FAM25C, SYNPO2L, FAM25...              8
# 158  {TPSAB1, CTSG, CPA3, MS4A2, LTC4S, TPSD1, GCSAML}              7
# 145  {LINC00052, TMEM150C, MS4A18, IGDCC3, ADORA2A,...             13
# 167  {RASD1, FOSB, CCN1, IL6, FOS, RGS2, ZFP36, ADA...             18
# 31                                   {S100A7A, S100A7}              2
# 178                          {CYP2A6, CYP2A7, CYP2A13}              3
# 60                 {SERPINA1, SERPINA6, IGSF1, PPP4R4}              4
# 57                               {PHACTR3, PAH, ASCL1}              3
# 184  {TDRG1, INTS4, PPFIA1, DQX1, TCL1B, CTTN, CLNS...              8
# 187             {BRDT, RMND1, LINC03042, PLCD4, ARMT1}              5
# 196  {SCGB1D2, ASRGL1, ABCC12, CST4, PEBP4, BPIFB2,...             10
# 87   {SCGB1D2, ASRGL1, PEBP4, BPIFB2, SCGB2A1, KAZA...              7
# 24   {SIX1, HOXC11, HOTAIR, MNX1, HOXC13, IGSF5, HO...              8
#
#      min_pval_TCGA  max_ARI_TCGA  min_pval_META  max_ARI_META   max_ARI
# 64        0.000005      0.177823       0.000005      0.206861  0.206861
# 100       0.000005      0.079060       0.000006      0.086055  0.086055
# 128       0.000005      0.072839       0.000005      0.080350  0.080350
# 5         0.001616      0.036731       0.000007      0.010488  0.036731
# 36        0.000007      0.086784       0.000005      0.116247  0.116247
# 63        0.000005      0.160523       0.000005      0.082378  0.160523
# 140       0.000005      0.170886       0.000005      0.075881  0.170886
# 55        0.000005      0.048111       0.000005      0.024702  0.048111
# 151       0.001167      0.011981       0.000005      0.043196  0.043196
# 114       0.000007      0.144174       0.000006      0.238485  0.238485
# 74        0.000005      0.241778       0.000005      0.206861  0.241778
# 171       0.000005      0.066814       0.000005      0.077485  0.077485
# 181       0.000005      0.155983       0.000005      0.106972  0.155983
# 112       0.000005      0.150495       0.000005      0.137162  0.150495
# 179       0.000009      0.137584       0.000007      0.244097  0.244097
# 27        0.003749      0.037172       0.000270      0.009597  0.037172
# 107       0.000012      0.046737       0.000005      0.242748  0.242748
# 75        0.000005      0.126217       0.000005      0.033111  0.126217
# 124       0.000007      0.086756       0.000007      0.091053  0.091053
# 7         0.000582      0.054400       0.001206      0.024461  0.054400
# 139       0.000005      0.081044       0.000005      0.045178  0.081044
# 142       0.000011      0.101889       0.000009      0.025078  0.101889
# 158       0.000005      0.148587       0.000005      0.095257  0.148587
# 145       0.000006      0.109834       0.000005      0.035615  0.109834
# 167       0.000007      0.084067       0.000006      0.079870  0.084067
# 31        0.000007      0.145821       0.000007      0.225907  0.225907
# 178       0.000005      0.044640       0.000007      0.015440  0.044640
# 60        0.000005      0.071607       0.000005      0.062040  0.071607
# 57        0.000005      0.115125       0.000005      0.068802  0.115125
# 184       0.000007      0.159496       0.000008      0.059449  0.159496
# 187       0.000005      0.197158       0.000005      0.143844  0.197158
# 196       0.000005      0.054652       0.000005      0.048412  0.054652
# 87        0.000005      0.061573       0.000005      0.048412  0.061573
# 24        0.000007      0.030148       0.000005      0.043457  0.043457

# %%
d = potentially_novel.loc[:,:].copy()
cols = ["genes", "samples","shared_genes","union_genes","bm_genes","bm_samples"]
for col in cols:
    d[col] = d[col].apply(lambda x: " ".join(sorted(x)) ) 
d.to_csv(out_dir + "28_matched_J0.1_ARI0.25.tsv",sep="\t")

# %% [markdown]
# ### plot top-5 similar biclusters not matching PAM50

# %%
subt_order = ["Her2","Basal","LumA","LumB","Normal"]

color_dict = OrderedDict()

color_dict["PAM50"] = OrderedDict({"Her2":"yellow",
                                   "Basal":"lightblue",
                                   "LumA":"lightgreen",
                                   "LumB":"darkgreen",
                                   "Normal":"grey"})

color_dict["claudin_low"] = OrderedDict({1:"magenta",0:"grey"}) # claudin-low

color_dict["sex"] = OrderedDict({1:"lightpink",0:"lightblue",
                                 "F":"lightpink","M":"lightblue"})
 

# histology
receptors = OrderedDict({'Positive':"red",
                         "Equivocal":"grey",#"orange",
                         'Indeterminate':"grey",#"gold",
                         'Negative':"green",
                         "NA":"lightgrey"})
color_dict["IHC_HER2"] = receptors
color_dict["IHC_ER"] = receptors 
color_dict["IHC_PR"] = receptors

# %%
# show only shared genes
gene_list = set([])
for genes in potentially_novel.head(5)["shared_genes"]:
    gene_list |= genes

# %%
top_n = 5

# %%
w = 8
fs = 12 # Font size
subt_anno = anno_tcga.loc[:,["PAM50"]]
subt_anno = subt_anno.fillna("NA")
subt_anno.head(3)
top_n = 5

bics = bics_tcga.loc[potentially_novel.head(top_n).sort_values(by="n_samples").index.values, :]

sele_bics = bics.index.values
h = min(max(3,bics.loc[sele_bics,"n_genes"].sum()/5),10)
if w>h:
    cr = max(min(0.015,0.05*h/10),0.05)
else:
    cr = min(max(0.015,0.015*h/10),0.05)
fig, samples, colors = draw_heatmap2(exprs_tcga.copy(),
                    bics.loc[sele_bics,:],
                    annot=subt_anno,
                    color_dict=color_dict,
                  bicluster_colors="redblue",
                  figsize = (w,h*0.8), 
                  dendrogram_ratio=(0.1,0.1),
                  colors_ratio=(cr/w*h, cr*1.5),
                  bic_prefix = "b. ",
                  legend_n_cols=0,
                  no_cbar=True,
                  col_labels = False,
                  #highlight_row_labels=highlight_genes,
                  #row_labels = True,
                  no_row_colors = False,
                  cluster_rows=False,
                 )
ax = fig.ax_heatmap
tmp = ax.set_xlabel("TCGA-BRCA, n=%s samples"%subt_anno.shape[0],fontsize=18)
if h>=8:
    tmp = ax.set_yticklabels(ax.get_yticklabels(),fontsize=7)

tmp = fig.ax_col_colors.set_yticklabels(fig.ax_col_colors.get_yticklabels(),fontsize=14)
tmp = fig.ax_row_colors.set_xticklabels(fig.ax_row_colors.get_xticklabels(),fontsize=14)

# %% [markdown]
# ### same genes but clustered

# %%
import seaborn as sns
df = colors[0].copy()
d = {"white":0,"black":1}
df = df.applymap(lambda x:d[x])
df = df[df.sum(axis=1)>0]
df = df.sort_values(by=list(df.columns.values),ascending=False)
fig = sns.clustermap(fig.data2d.loc[list(df.index.values),
                                    samples],
                       col_cluster=True,#row_cluster=True,
                       cmap=sns.color_palette("coolwarm", as_cmap=True),
                       vmin=-3,vmax=3,
                       xticklabels=False, yticklabels=False,
                       col_colors=colors[1],
                       #row_colors=colors[0],
                       figsize=(w,h*0.8), 
                       dendrogram_ratio=(0.1,0.1),
                       colors_ratio=(cr/w*h, cr*1.5),)
fig.cax.set_visible(False)
ax = fig.ax_heatmap
tmp = ax.set_xlabel("TCGA-BRCA, n=%s samples"%subt_anno.shape[0],fontsize=18)
tmp = fig.ax_col_colors.set_yticklabels(fig.ax_col_colors.get_yticklabels(),fontsize=14)
#tmp = fig.ax_row_colors.set_xticklabels(fig.ax_row_colors.get_xticklabels(),fontsize=14)

# %%
from matplotlib.patches import Patch

legend_elements = []
for subt in color_dict["PAM50"].keys():
    p = Patch(facecolor=color_dict["PAM50"][subt], edgecolor='black', label=subt)
    legend_elements.append(p)

# Create the figure
fig, ax = plt.subplots(figsize = (3,3))
legend = ax.legend(
    handles=legend_elements,
    loc='center',
    ncol=3,
    handlelength=5,
    handleheight=4,
    title='',  # Legend title
    fontsize=20  # Legend items font size
)

legend.get_frame().set_alpha(0)

legend.set_title('', prop={'size': 22})

ax.axis('off')

plt.show()

# %% [markdown]
# # top-5 biclusters with the highest number of shared genes

# %%
sns.set(font_scale=0.5)

# %%
subt_anno = anno_tcga.loc[:,["PAM50"]]
subt_anno = subt_anno.fillna("NA")
subt_anno.head(3)

bics = bics_tcga.loc[potentially_novel.head(top_n).sort_values(by="n_samples").index.values, :]

w, h = 4.5,8

tmp = draw_heatmap2(exprs_tcga,
                    bics,
                    figsize = (w,h), 
                    colors_ratio=(cr/w*h/2, cr),
                    dendrogram_ratio=(0.0,0.01),
                    annot=subt_anno,
                    color_dict=color_dict,
                    bicluster_colors="auto",
                    col_labels = False,
                    row_labels =True,
                    no_row_colors = False,
                    legend_n_cols=0,
                    no_cbar = True,
                    cluster_rows=False,
                    highlight_row_labels=list(gene_list),
                   bic_prefix="b.",
                                    )
                
fname = "5bics_TCGA"
ax = tmp[0].ax_heatmap
ax.set_xlabel("TCGA-BRCA, n=%s samples"%exprs_tcga.shape[1], fontsize=12)
tmp[0].ax_row_colors.set_xticklabels([""]*(bics.shape[0]))
tmp[0].ax_row_colors.set_xticks([])
tmp[0].ax_col_colors.set_yticklabels(tmp[0].ax_col_colors.get_yticklabels(),fontsize=10)
tmp[0].ax_heatmap.set_yticklabels(ax.get_yticklabels(),fontsize=6)

for ext in ["png","pdf","svg"]:
    plt.savefig(img_dir+"FigS9/FigS9c_"+fname+"_v4."+ext,format=ext, dpi = 300)
plt.show()
# Out:
# colors: ['#0173b2', '#de8f05', '#029e73', '#d55e00', '#cc78bc']

# %%
subt_anno = anno_meta.loc[:,["PAM50"]]
subt_anno = subt_anno.fillna("NA")
subt_anno.head(3)

bics = bics_meta.loc[potentially_novel.head(top_n).sort_values(by="n_samples")["bm_id"].values, :]

tmp =draw_heatmap2(exprs_meta,
                    bics,
                    figsize = (w,h), 
                    colors_ratio=(cr/w*h/2, cr),
                    dendrogram_ratio=(0.0,0.01),
                    annot=subt_anno,
                    color_dict=color_dict,
                    bicluster_colors="auto",
                    col_labels = False,
                    row_labels =True,
                    no_row_colors = False,
                    legend_n_cols=0,
                    no_cbar = True,
                    cluster_rows=False,
                    highlight_row_labels=list(gene_list),
                   bic_prefix="b.")

fname = "5bics_METABRIC"
ax = tmp[0].ax_heatmap
ax.set_xlabel("METABRIC, n=%s samples"%exprs_meta.shape[1], fontsize=12)
tmp[0].ax_row_colors.set_xticklabels([""]*(bics.shape[0]))
tmp[0].ax_row_colors.set_xticks([])
tmp[0].ax_col_colors.set_yticklabels(tmp[0].ax_col_colors.get_yticklabels(),fontsize=10)
tmp[0].ax_heatmap.set_yticklabels(ax.get_yticklabels(),fontsize=6)

for ext in ["png","pdf","svg"]:
    plt.savefig(img_dir+"FigS9/FigS9d_"+fname+"_v4."+ext,format=ext, dpi = 300)
plt.show()
# Out:
# colors: ['#0173b2', '#de8f05', '#029e73', '#d55e00', '#cc78bc']

# %% [markdown]
# ### same signatures, but only shared genes are shown

# %%
subt_anno = anno_tcga.loc[:,["PAM50"]]
subt_anno = subt_anno.fillna("NA")
subt_anno.head(3)

bics = bics_tcga.loc[potentially_novel.head(top_n).sort_values(by="n_samples").index.values, :]
for col in ["genes","genes_up","genes_down"]:
    bics[col] = bics[col].apply(lambda x: x.intersection(gene_list))

w, h = 4.5,6

tmp = draw_heatmap2(exprs_tcga,
                    bics,
                    figsize = (w,h), 
                    colors_ratio=(cr/w*h, cr*1.25),
                    dendrogram_ratio=(0.0,0.01),
                    annot=subt_anno,
                    color_dict=color_dict,
                    bicluster_colors="auto",
                    col_labels = False,
                    row_labels =True,
                    no_row_colors = False,
                    legend_n_cols=0,
                    no_cbar = True,
                    cluster_rows=False,
                    highlight_row_labels=list(gene_list),
                   bic_prefix="b.",
                                    )
                
fname = "5bics_TCGA_shared_genes"
ax = tmp[0].ax_heatmap
ax.set_xlabel("TCGA-BRCA, n=%s samples"%exprs_tcga.shape[1], fontsize=12)
tmp[0].ax_row_colors.set_xticklabels([""]*(bics.shape[0]))
tmp[0].ax_row_colors.set_xticks([])
tmp[0].ax_col_colors.set_yticklabels(tmp[0].ax_col_colors.get_yticklabels(),fontsize=8)
tmp[0].ax_heatmap.set_yticklabels(ax.get_yticklabels(),fontsize=8)
#tmp[0].fig.text(0.02, 0.03, "", ha='left', va='bottom', fontsize=18)

for ext in ["png","pdf","svg"]:
    plt.savefig(img_dir+"Fig4/Fig4c"+fname+"_v4."+ext,format=ext, dpi = 300)
plt.show()

# %%
subt_anno = anno_meta.loc[:,["PAM50"]]
subt_anno = subt_anno.fillna("NA")
subt_anno.head(3)

bics = bics_meta.loc[potentially_novel.head(top_n).sort_values(by="n_samples")["bm_id"].values, :]
for col in ["genes","genes_up","genes_down"]:
    bics[col] = bics[col].apply(lambda x: x.intersection(gene_list))

w, h = 4.5,6


tmp = draw_heatmap2(exprs_meta,
                    bics,
                    figsize = (w,h), 
                    colors_ratio=(cr/w*h, cr*1.25),
                    dendrogram_ratio=(0.0,0.01),
                    annot=subt_anno,
                    color_dict=color_dict,
                    bicluster_colors="auto",
                    col_labels = False,
                    row_labels =True,
                    no_row_colors = False,
                    legend_n_cols=0,
                    no_cbar = True,
                    cluster_rows=False,
                    highlight_row_labels=list(gene_list),
                   bic_prefix="b.",
                                    )


fname = "5bics_METABRIC_shared_genes"
ax = tmp[0].ax_heatmap
ax.set_xlabel("METABRIC, n=%s samples"%exprs_meta.shape[1], fontsize=12)
tmp[0].ax_row_colors.set_xticklabels([""]*(bics.shape[0]))
tmp[0].ax_row_colors.set_xticks([])
tmp[0].ax_col_colors.set_yticklabels(tmp[0].ax_col_colors.get_yticklabels(),fontsize=8)
tmp[0].ax_heatmap.set_yticklabels(ax.get_yticklabels(),fontsize=8)
#tmp[0].fig.text(0.02, 0.03, "", ha='left', va='bottom', fontsize=18)

for ext in ["png","pdf","svg"]:
    plt.savefig(img_dir+"Fig4/Fig4d"+fname+"_v4."+ext,format=ext, dpi = 300)
plt.show()

# %% [markdown]
# # Legend

# %%
from matplotlib.patches import Patch
ncol = 5


legend_elements = []
colors = ['#0173b2', '#de8f05', '#029e73', '#d55e00', '#cc78bc']
labels = bics.index.values
for i in range(len(labels)):
    p = Patch(facecolor=colors[i], edgecolor='black', label=labels[i])
    legend_elements.append(p)

# Create the figure
fig, ax = plt.subplots(figsize = (10,2)) # 
legend = ax.legend(
    handles=legend_elements,
    loc='center',
    ncol=ncol,
    handlelength=3,
    handleheight=1.5,
    title='',  # Legend title
    fontsize=20  # Legend items font size
)



legend.get_frame().set_alpha(0)

legend.set_title('', prop={'size': 22})

ax.axis('off')
plt.savefig(img_dir+"Fig4/color_legend_bics.svg")

legend_elements = []
for subt in color_dict["PAM50"].keys():
    p = Patch(facecolor=color_dict["PAM50"][subt], edgecolor='black', label=subt)
    legend_elements.append(p)

# Create the figure
fig, ax = plt.subplots(figsize = (10,2)) # 
legend = ax.legend(
    handles=legend_elements,
    loc='center',
    ncol=ncol,
    handlelength=3,
    handleheight=1.5,
    title='',  # Legend title
    fontsize=20  # Legend items font size
)

legend.get_frame().set_alpha(0)

legend.set_title('', prop={'size': 22})

ax.axis('off')


plt.savefig(img_dir+"Fig4/color_legend_PAM50.svg")

plt.show()

# %%
df = potentially_novel.sort_values(by="n_shared_genes",ascending=False)
df["id_TCGA"] = df.index.values
df["id_METABRIC"] = df["bm_id"]
df["Jaccard"] = df["J"].apply(lambda x: round(x,2))
df["n_shared"] = df["shared_genes"].apply(lambda row:len(row))
df["shared"] = df["shared_genes"].apply(lambda row:" ".join(sorted(row)))
df["union"] = df.apply(lambda row: row['genes']|row['bm_genes'],axis=1)
df["n_union"] = df["union"].apply(lambda row:len(row))
df["union"] = df.apply(lambda row:" ".join(sorted(row['union'])),axis=1)
df["n_genes_TCGA"] = df["n_genes"]
df["genes_TCGA"] = df["genes"].apply(lambda row:" ".join(sorted(row)))
df["n_genes_METABRIC"] = df["bm_n_genes"]
df["genes_METABRIC"] = df["bm_genes"].apply(lambda row:" ".join(sorted(row)))
df["n_samples_TCGA"] = df["n_samples"]
df["samples_TCGA"] = df["samples"].apply(lambda row:" ".join(sorted(row)))
df["n_samples_METABRIC"] = df["bm_n_samples"]
df["samples_METABRIC"] = df["bm_samples"].apply(lambda row:" ".join(sorted(row)))
cols = ["id_TCGA","id_METABRIC","Jaccard","n_shared","shared","n_union","union",
       "n_genes_TCGA","genes_TCGA","n_genes_METABRIC","genes_METABRIC",
       "n_samples_TCGA","samples_TCGA","n_samples_METABRIC","samples_METABRIC"]
df = df.loc[:,cols]
df = df.sort_values(by=["n_shared","n_union"],ascending=[False,False])
df.index = range(df.shape[0])
df.index.name = "pair_id"
df.to_csv(out_dir+'TableS2_potentially_novel.tsv',sep = "\t")
df
